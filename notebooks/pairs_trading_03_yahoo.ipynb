# %% [markdown]
# # Dynamic Hedge Pairs Trading — *without* Benjamini-Hochberg
# ## `pairs_trading_03_yahoo.ipynb`
#
# Identical pipeline to `pairs_trading_02_yahoo.ipynb` — cointegration screen → Kalman hedge → walk-forward pair selection → in-sample & out-of-sample backtests with performance metrics → limitations — with **one deliberate change: no Benjamini-Hochberg FDR correction** on the cointegration screen (`fdr_method="none"`, raw p-values).
#
# The intent is to isolate the effect of dropping multiple-testing control. **It still does not, and the
# reason is worth more than the intended result.**
#
# The correction now visibly bites on the screen: under Benjamini-Hochberg **279** of 118,828 pairs clear
# the dual gate, and without it **6,102** do — twenty-two times as many. That difference is real and it is
# printed below. Yet this notebook still reproduces `pairs_trading_02_yahoo.ipynb` exactly: same selected
# pair, same in-sample Sharpe, same trades.
#
# The filters are **nested**. Benjamini-Hochberg removes the pairs with the *weakest* p-values; the shortlist
# is the top 200 by a blended Engle-Granger/Johansen *rank*, which keeps the *strongest*. Since
# $200 \le 279 \le 6{,}102$ and both pools are ordered the same way, the top 200 of the corrected pool and
# the top 200 of the uncorrected pool are the **same 200 pairs**. Every pair the correction removes was
# already going to be discarded one line later.
#
# So the ablation can only bite under one of two conditions, neither of which holds here:
#
# * the shortlist is **larger** than the number of survivors — take the top 500 and the corrected pool runs
#   out at 279, forcing it to stop where the uncorrected one keeps going; or
# * selection is **not ordered by p-value** — if the shortlist were drawn by any other criterion, the
#   correction would change which pairs are available to it.
#
# That is the honest lesson, and it generalizes past this notebook: **a significance filter placed upstream
# of a stricter ranking filter is decorative.** It changes a reported count and nothing else. Notebook 11
# finds FDR control worth +0.40 Sharpe against −0.41 for distance selection precisely because there the
# survivors *are* the selection, with no tighter cut behind them.

# %% [markdown]
# ## 0. Environment setup

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent           # notebooks/ → repo root
sys.path.insert(0, str(repo_root))

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pairs
print("pairs version:", pairs.__version__)
print("pairs path   :", Path(pairs.__file__).relative_to(repo_root))
# Out:
# pairs version: 0.1.0
# pairs path   : pairs/__init__.py

# %%
# Install the package (editable) if running in a fresh environment
# %pip install -e "..[notebooks]"  # uncomment if needed

# %% [markdown]
# # 1. Data Loading & Quality Filtering
#
# We load daily OHLCV prices for the combined S&P 500 + NASDAQ-100 universe
# (~517 tickers) over the **training window 2020-01-01 → 2025-12-31**, then
# drop tickers whose coverage does not span the full period.

# %%
from pairs import load_universe, load_prices

tickers = load_universe("spx_ndx_combined")
print(f"Universe: {len(tickers)} tickers")
# Out:
# Universe: 517 tickers

# %%
# ── Load training prices ──────────────────────────────────────────────────────
start_date = "2020-01-01"
end_date   = "2025-12-31"

# Prices are cached on first run so the notebook is reproducible offline afterwards.
# This matters more than it looks: Yahoo re-bases its adjusted close after every
# corporate action, so a fresh download months later returns different *levels*
# for any name that has since split or spun off. Pinning the file freezes the basis.
CACHE = Path("cache"); CACHE.mkdir(exist_ok=True)
# the window is part of the key: change the dates and it re-downloads
_px_cache = CACHE / f"nb03_train_{start_date}_{end_date}.parquet"
if _px_cache.exists():
    df_train, failed = pd.read_parquet(_px_cache), []
else:
    df_train, failed = load_prices('openbb', tickers, start_date, end_date, return_failed=True)
    df_train.to_parquet(_px_cache)

print(f"Loaded {len(df_train):,} rows for {df_train.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# Loaded 753,000 rows for 505 tickers

# %%
# ── Quality filter: keep only full-coverage tickers ──────────────────────────
lvl_names      = list(df_train.index.names)
time_lvl_name  = 'datetime' if 'datetime' in lvl_names else lvl_names[1]

full_start = df_train.index.get_level_values(time_lvl_name).min()
full_end   = df_train.index.get_level_values(time_lvl_name).max()

starts = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).min())
ends   = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).max())

tickers_to_keep = starts[(starts == full_start) & (ends == full_end)].index
df_filtered     = df_train.loc[pd.IndexSlice[tickers_to_keep, :]]

n_orig    = df_train.index.get_level_values('ticker').nunique()
n_kept    = df_filtered.index.get_level_values('ticker').nunique()
dropped   = set(tickers) - set(tickers_to_keep)
print(f"Tickers: {n_orig} total → {n_kept} kept ({n_orig - n_kept} dropped for incomplete coverage)")
print(f"Dropped: {sorted(dropped)}")
# Out:
# Tickers: 505 total → 488 kept (17 dropped for incomplete coverage)
# Dropped: ['ABNB', 'APP', 'ARM', 'AVB', 'BK', 'CARR', 'CEG', 'COIN', 'CTRA', 'DASH', 'DAY', 'EA', 'EQR', 'EXE', 'FI', 'GEHC', 'GEV', 'GFS', 'HOLX', 'IPG', 'K', 'KVUE', 'MMC', 'OTIS', 'PARA', 'PLTR', 'SOLV', 'VLTO', 'WBA']

# %% [markdown]
# # 2. Cointegration Screening
#
# ## 2.1 Dual-gate screening (Engle-Granger + Johansen)
#
# We test all $\binom{n}{2}$ pairs simultaneously using two cointegration tests.
# A pair advances only if **both** tests reject the null of no cointegration.

# %%
from pairs import find_cointegrated_pairs_dualgate

# fdr_method="none" — NO Benjamini-Hochberg correction (raw EG p-value gate).
summary_dual = find_cointegrated_pairs_dualgate(
    df_filtered,
    alpha_eg=0.05, eg_trend="c",
    alpha_joh=0.05, joh_det_order=0, joh_k_ar_diff=1, joh_stat="trace",
    fdr_method="none",      # ← raw p-values, no multiple-testing correction
    n_workers=16, chunksize=8, show_progress=True,
)
print(f"\nTotal pairs screened : {len(summary_dual):,}")
print(f"Dual-gate pass (verdict=='pass'): {(summary_dual['verdict']=='pass').sum()}")
summary_dual.head(5)[["eg_t", "eg_p", "eg_pass", "joh_stat", "joh_pass", "verdict"]]
# Out:
# Dual-gate cointegration (EG + Johansen):   0%|          | 0/118828 [00:00<?, ?it/s]
# Dual-gate cointegration (EG + Johansen):   1%|          | 1265/118828 [00:00<00:09, 12570.44it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2523/118828 [00:02<01:55, 1006.03it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3077/118828 [00:03<02:18, 837.91it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3405/118828 [00:03<02:28, 774.87it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3626/118828 [00:04<02:33, 751.35it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3791/118828 [00:04<02:42, 710.04it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3918/118828 [00:04<02:49, 677.45it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4021/118828 [00:04<02:53, 661.29it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4109/118828 [00:04<02:49, 675.62it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4194/118828 [00:05<03:06, 613.66it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4273/118828 [00:05<03:05, 618.52it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4343/118828 [00:05<03:04, 619.82it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4411/118828 [00:05<03:10, 601.04it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4481/118828 [00:05<03:11, 598.01it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4545/118828 [00:05<03:09, 604.56it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4617/118828 [00:05<03:00, 631.25it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4682/118828 [00:05<03:00, 634.09it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4747/118828 [00:05<03:10, 598.28it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4825/118828 [00:06<03:12, 591.76it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4889/118828 [00:06<03:09, 601.07it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4953/118828 [00:06<03:12, 592.35it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5041/118828 [00:06<03:01, 627.11it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5104/118828 [00:06<03:23, 558.15it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5185/118828 [00:06<03:13, 586.61it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5245/118828 [00:06<03:31, 537.01it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5321/118828 [00:06<03:12, 588.62it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5385/118828 [00:07<03:16, 578.37it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5449/118828 [00:07<03:13, 587.07it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5509/118828 [00:07<03:35, 525.19it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5564/118828 [00:07<04:47, 394.53it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5657/118828 [00:07<03:52, 487.53it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5721/118828 [00:07<03:56, 478.96it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5801/118828 [00:07<03:27, 544.19it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5860/118828 [00:08<04:01, 466.87it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5937/118828 [00:08<03:40, 512.20it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 5993/118828 [00:08<04:14, 444.21it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6073/118828 [00:08<03:43, 504.35it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6128/118828 [00:08<04:24, 426.63it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6209/118828 [00:08<03:41, 508.50it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6266/118828 [00:09<04:29, 417.76it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6361/118828 [00:09<03:47, 495.01it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6417/118828 [00:09<03:41, 507.28it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6497/118828 [00:09<03:29, 535.50it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6601/118828 [00:09<03:06, 601.10it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6664/118828 [00:09<03:12, 581.99it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6729/118828 [00:09<03:09, 591.76it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6793/118828 [00:09<03:07, 598.21it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6857/118828 [00:09<03:05, 604.89it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6919/118828 [00:10<03:03, 608.22it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6985/118828 [00:10<03:00, 620.54it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7048/118828 [00:10<03:02, 612.55it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7113/118828 [00:10<03:04, 603.98it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7185/118828 [00:10<03:10, 584.90it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7265/118828 [00:10<02:56, 631.07it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7345/118828 [00:10<02:59, 622.60it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7408/118828 [00:10<03:16, 567.99it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7489/118828 [00:11<03:02, 609.56it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7551/118828 [00:11<03:24, 544.73it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7649/118828 [00:11<02:57, 626.45it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7729/118828 [00:11<03:18, 560.99it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7793/118828 [00:11<03:16, 564.79it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7889/118828 [00:11<03:05, 596.94it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7961/118828 [00:11<02:57, 624.97it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8025/118828 [00:11<03:19, 555.21it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8105/118828 [00:12<03:01, 611.26it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8169/118828 [00:12<03:10, 580.04it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8241/118828 [00:12<03:08, 586.06it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8301/118828 [00:12<03:09, 581.95it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8369/118828 [00:12<03:06, 591.19it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8429/118828 [00:12<03:13, 569.96it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8487/118828 [00:12<03:40, 501.44it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8577/118828 [00:12<03:16, 560.52it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8673/118828 [00:13<03:04, 596.00it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8737/118828 [00:13<03:11, 573.99it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8809/118828 [00:13<03:10, 577.70it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8867/118828 [00:13<03:32, 516.89it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 8961/118828 [00:13<03:07, 587.41it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9033/118828 [00:13<03:22, 540.99it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9105/118828 [00:13<03:10, 576.50it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9177/118828 [00:14<03:24, 535.79it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9265/118828 [00:14<03:04, 594.16it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9345/118828 [00:14<02:57, 615.44it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9409/118828 [00:14<02:58, 612.27it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9497/118828 [00:14<02:53, 631.65it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9561/118828 [00:14<02:56, 619.59it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9625/118828 [00:14<02:56, 620.28it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9689/118828 [00:14<03:03, 596.29it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9753/118828 [00:14<03:07, 580.91it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9817/118828 [00:15<03:06, 583.94it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9897/118828 [00:15<03:06, 583.39it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9993/118828 [00:15<02:47, 650.32it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 10059/118828 [00:15<03:00, 602.85it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10137/118828 [00:15<02:49, 639.37it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10202/118828 [00:15<03:06, 582.47it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10273/118828 [00:15<03:01, 597.17it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10334/118828 [00:15<03:19, 544.51it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10441/118828 [00:16<02:52, 626.54it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10529/118828 [00:16<02:40, 672.82it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10598/118828 [00:16<02:50, 635.51it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10665/118828 [00:16<02:55, 616.44it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10745/118828 [00:16<02:48, 639.86it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10810/118828 [00:16<02:49, 636.89it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10874/118828 [00:16<02:50, 632.20it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10938/118828 [00:16<02:53, 620.48it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11009/118828 [00:16<02:53, 621.29it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11072/118828 [00:17<02:55, 613.22it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11134/118828 [00:17<03:10, 563.97it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11201/118828 [00:17<03:16, 548.21it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11273/118828 [00:17<03:48, 470.27it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11337/118828 [00:17<03:42, 483.37it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11457/118828 [00:17<02:57, 603.36it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11561/118828 [00:17<02:46, 642.84it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11641/118828 [00:18<02:56, 608.08it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11737/118828 [00:18<02:44, 650.29it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11809/118828 [00:18<02:41, 662.72it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11877/118828 [00:18<02:57, 603.14it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 11961/118828 [00:18<02:44, 649.23it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12028/118828 [00:18<03:01, 587.19it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12113/118828 [00:18<02:53, 614.35it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12177/118828 [00:18<02:52, 618.70it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12241/118828 [00:19<02:55, 608.95it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12303/118828 [00:19<03:00, 589.18it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12377/118828 [00:19<03:12, 552.67it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12465/118828 [00:19<02:59, 593.22it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12525/118828 [00:19<03:10, 558.76it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12582/118828 [00:19<03:33, 498.78it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12665/118828 [00:19<03:23, 522.95it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12745/118828 [00:19<03:14, 546.31it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12801/118828 [00:20<03:28, 509.19it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12873/118828 [00:20<03:10, 555.87it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12930/118828 [00:20<03:12, 551.28it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13001/118828 [00:20<03:08, 560.89it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13058/118828 [00:20<03:16, 537.20it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13137/118828 [00:20<03:04, 573.18it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13217/118828 [00:20<02:50, 621.07it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13289/118828 [00:20<02:53, 608.62it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13351/118828 [00:21<03:17, 534.77it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13441/118828 [00:21<02:52, 611.30it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13513/118828 [00:21<02:46, 634.24it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13579/118828 [00:21<03:14, 541.95it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13681/118828 [00:21<03:00, 583.08it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13769/118828 [00:21<02:46, 630.17it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13834/118828 [00:21<03:02, 576.33it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13913/118828 [00:21<02:59, 583.38it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13993/118828 [00:22<02:46, 628.32it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14058/118828 [00:22<02:49, 618.38it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14129/118828 [00:22<02:47, 624.93it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14193/118828 [00:22<02:53, 604.20it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14257/118828 [00:22<02:56, 593.02it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14337/118828 [00:22<02:43, 638.24it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14417/118828 [00:22<02:40, 650.63it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14483/118828 [00:22<03:00, 576.54it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14553/118828 [00:23<02:52, 605.29it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14641/118828 [00:23<02:39, 653.94it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14708/118828 [00:23<02:55, 593.09it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14785/118828 [00:23<02:52, 603.58it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 14865/118828 [00:23<02:52, 603.12it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 14945/118828 [00:23<02:39, 650.16it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15012/118828 [00:23<02:44, 632.55it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15077/118828 [00:23<02:50, 609.91it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15139/118828 [00:23<02:54, 595.38it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15201/118828 [00:24<02:58, 580.78it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15289/118828 [00:24<02:43, 634.67it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15353/118828 [00:24<02:47, 619.27it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15425/118828 [00:24<02:44, 628.55it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15488/118828 [00:24<02:49, 611.16it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15553/118828 [00:24<02:48, 611.28it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15617/118828 [00:24<02:51, 601.09it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15689/118828 [00:24<02:46, 617.67it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15753/118828 [00:24<02:51, 601.24it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15825/118828 [00:25<02:49, 607.06it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15905/118828 [00:25<02:39, 645.90it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15970/118828 [00:25<02:47, 613.23it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16049/118828 [00:25<02:45, 620.49it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16129/118828 [00:25<02:43, 626.83it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16201/118828 [00:25<02:42, 632.18it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16265/118828 [00:25<02:52, 595.69it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16345/118828 [00:25<02:43, 626.01it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16408/118828 [00:26<02:50, 599.81it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16489/118828 [00:26<02:42, 628.82it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16577/118828 [00:26<02:35, 658.51it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16643/118828 [00:26<02:48, 606.97it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16721/118828 [00:26<02:40, 636.23it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16786/118828 [00:26<02:47, 608.25it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16865/118828 [00:26<02:43, 622.66it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16928/118828 [00:26<02:44, 619.45it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16991/118828 [00:26<02:49, 601.31it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17057/118828 [00:27<02:48, 602.49it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17129/118828 [00:27<02:40, 633.05it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17193/118828 [00:27<02:46, 611.43it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17273/118828 [00:27<02:46, 611.02it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17335/118828 [00:27<02:54, 580.29it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17409/118828 [00:27<02:51, 591.06it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17489/118828 [00:27<02:48, 602.19it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17553/118828 [00:27<02:54, 580.27it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17633/118828 [00:28<02:48, 599.81it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17705/118828 [00:28<02:48, 601.52it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17766/118828 [00:28<02:50, 594.44it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17826/118828 [00:28<02:59, 564.04it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17883/118828 [00:28<03:14, 518.71it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17936/118828 [00:28<03:33, 473.25it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18033/118828 [00:28<03:01, 555.55it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18089/118828 [00:28<03:12, 523.15it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18161/118828 [00:29<03:00, 558.69it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18241/118828 [00:29<02:56, 570.53it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18321/118828 [00:29<02:42, 618.62it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18385/118828 [00:29<02:42, 618.11it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18449/118828 [00:29<02:43, 612.75it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18511/118828 [00:29<02:44, 609.69it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18577/118828 [00:29<02:45, 606.19it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18641/118828 [00:29<02:43, 613.06it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18705/118828 [00:29<02:46, 602.01it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18777/118828 [00:30<02:46, 599.22it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18857/118828 [00:30<02:36, 638.20it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18937/118828 [00:30<02:29, 667.92it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19004/118828 [00:30<02:44, 607.81it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19081/118828 [00:30<02:39, 624.82it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19145/118828 [00:30<02:45, 603.87it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19209/118828 [00:30<02:42, 613.30it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19273/118828 [00:30<02:53, 573.25it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19337/118828 [00:30<02:50, 582.11it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19425/118828 [00:31<02:35, 640.57it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19490/118828 [00:31<02:44, 604.75it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19577/118828 [00:31<02:26, 675.24it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19646/118828 [00:31<02:55, 565.43it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19713/118828 [00:31<02:52, 573.68it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19801/118828 [00:31<02:38, 624.70it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19866/118828 [00:31<02:48, 586.32it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19953/118828 [00:31<02:31, 651.97it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20021/118828 [00:32<02:45, 597.52it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20089/118828 [00:32<02:40, 615.91it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20153/118828 [00:32<02:48, 586.78it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20225/118828 [00:32<03:24, 482.13it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20353/118828 [00:32<02:34, 635.64it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20449/118828 [00:32<02:23, 684.87it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20522/118828 [00:32<02:35, 633.85it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20593/118828 [00:32<02:39, 617.37it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20657/118828 [00:33<02:39, 615.38it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20729/118828 [00:33<02:38, 618.37it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20817/118828 [00:33<02:33, 638.94it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20882/118828 [00:33<02:44, 594.90it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20969/118828 [00:33<02:32, 642.91it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21035/118828 [00:33<02:48, 578.89it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21113/118828 [00:33<02:45, 590.97it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21177/118828 [00:33<02:42, 601.38it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21241/118828 [00:34<02:46, 585.70it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21337/118828 [00:34<02:28, 658.46it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21404/118828 [00:34<02:31, 644.11it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21469/118828 [00:34<02:33, 634.64it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21537/118828 [00:34<02:42, 600.07it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21617/118828 [00:34<02:41, 601.43it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21681/118828 [00:34<02:43, 595.60it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21745/118828 [00:34<02:44, 590.00it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21809/118828 [00:34<02:51, 566.06it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21897/118828 [00:35<02:35, 621.70it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21960/118828 [00:35<02:45, 584.02it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22073/118828 [00:35<02:24, 670.52it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22140/118828 [00:35<02:30, 641.16it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22209/118828 [00:35<02:38, 608.80it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22305/118828 [00:35<02:20, 685.79it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22375/118828 [00:35<02:31, 638.44it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22440/118828 [00:35<02:33, 628.06it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22504/118828 [00:36<02:36, 614.13it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22577/118828 [00:36<02:31, 634.70it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22641/118828 [00:36<02:36, 613.19it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22713/118828 [00:36<02:35, 616.49it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22777/118828 [00:36<02:34, 621.93it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22841/118828 [00:36<02:41, 595.84it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22905/118828 [00:36<02:38, 605.57it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22977/118828 [00:36<02:46, 574.55it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23057/118828 [00:37<02:51, 558.41it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23161/118828 [00:37<02:30, 635.59it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23233/118828 [00:37<02:37, 605.35it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23305/118828 [00:37<02:32, 628.07it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23369/118828 [00:37<02:33, 620.08it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23449/118828 [00:37<02:23, 662.79it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23516/118828 [00:37<02:33, 619.58it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23593/118828 [00:37<02:41, 590.65it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23697/118828 [00:37<02:24, 658.86it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23764/118828 [00:38<02:40, 593.13it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23849/118828 [00:38<02:26, 646.59it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23916/118828 [00:38<02:37, 603.56it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23985/118828 [00:38<02:34, 612.32it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24048/118828 [00:38<02:34, 613.27it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24113/118828 [00:38<02:33, 618.47it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24176/118828 [00:38<02:46, 567.98it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24249/118828 [00:38<02:37, 599.47it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24321/118828 [00:39<02:30, 629.08it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24385/118828 [00:39<02:38, 597.38it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24457/118828 [00:39<02:30, 626.34it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24521/118828 [00:39<02:35, 605.81it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24601/118828 [00:39<02:35, 605.51it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24665/118828 [00:39<02:40, 588.39it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24737/118828 [00:39<02:37, 598.42it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24817/118828 [00:39<02:28, 634.85it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24881/118828 [00:39<02:46, 565.19it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24953/118828 [00:40<02:39, 589.28it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25033/118828 [00:40<02:38, 590.90it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25121/118828 [00:40<02:33, 609.49it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25201/118828 [00:40<02:33, 608.82it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25265/118828 [00:40<02:35, 603.53it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25329/118828 [00:40<02:41, 578.53it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25401/118828 [00:40<02:32, 611.40it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25463/118828 [00:40<02:33, 607.91it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25529/118828 [00:41<02:39, 584.35it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25593/118828 [00:41<02:43, 570.18it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25681/118828 [00:41<02:33, 608.41it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25753/118828 [00:41<02:36, 592.89it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25833/118828 [00:41<02:25, 637.92it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25898/118828 [00:41<02:32, 609.49it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25969/118828 [00:41<02:31, 613.13it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26031/118828 [00:41<02:37, 588.25it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26113/118828 [00:42<03:15, 474.64it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26241/118828 [00:42<02:24, 642.35it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26314/118828 [00:42<02:31, 610.14it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26385/118828 [00:42<02:33, 601.88it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26473/118828 [00:42<02:18, 665.51it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26544/118828 [00:42<02:24, 636.90it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26617/118828 [00:42<02:40, 573.12it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26697/118828 [00:42<02:27, 625.84it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26763/118828 [00:43<02:39, 575.73it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26841/118828 [00:43<02:29, 617.30it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26906/118828 [00:43<02:35, 592.98it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26969/118828 [00:43<03:17, 464.72it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27105/118828 [00:43<02:22, 642.39it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27185/118828 [00:43<02:17, 667.91it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27258/118828 [00:43<02:44, 555.64it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27353/118828 [00:44<02:28, 615.94it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27421/118828 [00:44<02:38, 576.83it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27505/118828 [00:44<02:35, 587.86it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27585/118828 [00:44<02:29, 608.35it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27648/118828 [00:44<02:31, 600.81it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27710/118828 [00:44<02:31, 600.44it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27772/118828 [00:44<02:38, 574.18it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27849/118828 [00:44<02:30, 606.35it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27913/118828 [00:45<02:30, 602.83it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 27985/118828 [00:45<02:24, 627.15it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28049/118828 [00:45<02:26, 618.86it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28113/118828 [00:45<02:27, 615.46it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28177/118828 [00:45<02:28, 608.79it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28249/118828 [00:45<02:34, 586.77it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28309/118828 [00:45<02:36, 577.04it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28385/118828 [00:45<02:27, 613.90it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28447/118828 [00:45<02:53, 522.08it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28537/118828 [00:46<02:27, 610.40it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28617/118828 [00:46<02:35, 578.86it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28681/118828 [00:46<02:35, 581.28it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28753/118828 [00:46<02:27, 609.19it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28825/118828 [00:46<02:28, 607.34it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28887/118828 [00:46<02:27, 608.63it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28953/118828 [00:46<02:35, 578.14it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29017/118828 [00:46<02:35, 577.00it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29081/118828 [00:47<02:37, 570.06it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29161/118828 [00:47<02:22, 627.05it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29225/118828 [00:47<02:33, 583.47it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29297/118828 [00:47<02:39, 561.43it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29355/118828 [00:47<03:06, 478.51it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29465/118828 [00:47<02:32, 587.88it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29537/118828 [00:47<02:34, 578.25it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29633/118828 [00:47<02:19, 638.37it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29699/118828 [00:48<02:24, 618.88it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29762/118828 [00:48<02:30, 592.03it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29833/118828 [00:48<02:29, 595.21it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29897/118828 [00:48<02:26, 605.00it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29961/118828 [00:48<02:28, 599.15it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30025/118828 [00:48<02:32, 582.75it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30089/118828 [00:48<02:35, 569.51it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30153/118828 [00:48<02:33, 575.81it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30217/118828 [00:49<02:52, 513.47it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30289/118828 [00:49<03:00, 491.65it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30393/118828 [00:49<02:24, 613.82it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30458/118828 [00:49<03:05, 476.35it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30553/118828 [00:49<02:39, 553.24it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30615/118828 [00:49<02:36, 562.95it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30681/118828 [00:49<02:37, 558.14it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30745/118828 [00:49<02:40, 548.92it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30833/118828 [00:50<02:27, 596.30it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30895/118828 [00:50<02:28, 591.89it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30956/118828 [00:50<02:29, 586.54it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31025/118828 [00:50<02:26, 597.40it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31086/118828 [00:50<02:29, 587.01it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31161/118828 [00:50<02:29, 586.00it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31225/118828 [00:50<02:27, 591.96it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31289/118828 [00:50<02:29, 586.91it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31348/118828 [00:50<02:36, 557.92it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31425/118828 [00:51<02:48, 519.25it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31505/118828 [00:51<02:31, 577.63it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31565/118828 [00:51<02:34, 564.31it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31623/118828 [00:51<02:44, 529.45it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31681/118828 [00:51<02:43, 533.05it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31735/118828 [00:51<02:47, 520.78it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31809/118828 [00:51<02:56, 494.34it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31865/118828 [00:52<03:01, 477.90it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31937/118828 [00:52<02:50, 509.52it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31989/118828 [00:52<02:50, 510.05it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32049/118828 [00:52<02:52, 503.41it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32129/118828 [00:52<02:36, 555.24it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32185/118828 [00:52<02:42, 531.58it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32257/118828 [00:52<02:49, 511.83it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32309/118828 [00:52<02:52, 501.38it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32369/118828 [00:52<02:50, 507.42it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32425/118828 [00:53<02:54, 493.83it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32475/118828 [00:53<03:55, 367.07it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32585/118828 [00:53<02:57, 487.14it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32638/118828 [00:53<03:01, 474.63it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32721/118828 [00:53<02:35, 553.53it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32781/118828 [00:53<02:39, 538.43it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32838/118828 [00:53<03:09, 453.80it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32961/118828 [00:54<02:19, 615.78it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33029/118828 [00:54<02:25, 588.90it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33097/118828 [00:54<02:26, 584.23it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33161/118828 [00:54<02:23, 597.97it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33223/118828 [00:54<02:26, 585.68it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33284/118828 [00:54<02:25, 588.97it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33353/118828 [00:54<02:19, 611.18it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33415/118828 [00:54<02:23, 596.13it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33476/118828 [00:55<02:31, 564.87it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33537/118828 [00:55<02:45, 515.96it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33625/118828 [00:55<02:22, 598.75it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33687/118828 [00:55<02:27, 576.93it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33753/118828 [00:55<02:35, 545.38it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33833/118828 [00:55<02:21, 602.35it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33895/118828 [00:55<02:22, 594.28it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33961/118828 [00:55<02:21, 600.18it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34022/118828 [00:55<02:29, 565.51it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34105/118828 [00:56<02:15, 626.95it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34169/118828 [00:56<02:39, 530.95it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34241/118828 [00:56<02:27, 575.34it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34302/118828 [00:56<02:29, 563.87it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34377/118828 [00:56<02:25, 580.28it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34449/118828 [00:56<02:19, 602.96it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34511/118828 [00:56<02:22, 590.51it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34571/118828 [00:56<02:33, 548.72it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34641/118828 [00:57<02:25, 579.20it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34700/118828 [00:57<02:30, 559.22it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34785/118828 [00:57<02:15, 617.98it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34848/118828 [00:57<02:23, 586.96it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34921/118828 [00:57<02:25, 577.32it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 35001/118828 [00:57<02:37, 530.64it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35081/118828 [00:57<02:24, 580.81it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35153/118828 [00:57<02:17, 607.92it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35216/118828 [00:58<02:28, 564.31it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35274/118828 [00:58<02:30, 556.03it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35345/118828 [00:58<02:24, 578.12it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35433/118828 [00:58<02:10, 636.94it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35498/118828 [00:58<02:27, 563.76it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35577/118828 [00:58<02:33, 541.79it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35657/118828 [00:58<02:26, 567.62it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35715/118828 [00:58<02:32, 546.74it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35817/118828 [00:59<02:19, 593.33it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35877/118828 [00:59<02:21, 584.91it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35953/118828 [00:59<02:17, 603.46it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36017/118828 [00:59<02:20, 590.65it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36081/118828 [00:59<02:21, 583.67it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36153/118828 [00:59<02:20, 586.57it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36212/118828 [00:59<02:31, 546.23it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36281/118828 [00:59<02:26, 564.31it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36345/118828 [01:00<02:36, 527.73it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36433/118828 [01:00<02:23, 573.09it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36513/118828 [01:00<02:24, 570.90it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36593/118828 [01:00<02:13, 617.19it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36656/118828 [01:00<02:19, 587.11it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36737/118828 [01:00<02:07, 643.75it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36803/118828 [01:00<02:30, 545.07it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36881/118828 [01:00<02:24, 568.07it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36941/118828 [01:01<02:27, 555.05it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 37009/118828 [01:01<02:22, 575.65it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 37068/118828 [01:01<02:21, 577.73it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███▏      | 37137/118828 [01:01<02:19, 584.93it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███▏      | 37197/118828 [01:01<02:27, 555.31it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███▏      | 37273/118828 [01:01<02:16, 598.46it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███▏      | 37334/118828 [01:01<02:17, 593.62it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███▏      | 37401/118828 [01:01<02:19, 582.43it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37460/118828 [01:01<02:21, 576.76it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37529/118828 [01:02<02:15, 598.39it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37590/118828 [01:02<02:16, 596.79it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37657/118828 [01:02<02:15, 598.34it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37729/118828 [01:02<02:10, 621.24it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37792/118828 [01:02<02:15, 596.03it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37873/118828 [01:02<02:11, 613.70it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 37935/118828 [01:02<02:20, 573.75it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38025/118828 [01:02<02:10, 620.33it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38088/118828 [01:02<02:30, 535.01it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38161/118828 [01:03<02:21, 571.28it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38220/118828 [01:03<02:40, 502.62it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38313/118828 [01:03<02:14, 598.54it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38377/118828 [01:03<02:35, 516.91it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38449/118828 [01:03<02:28, 542.80it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38537/118828 [01:03<02:13, 603.14it/s]
# Dual-gate cointegration (EG + Johansen):  32%|███▏      | 38601/118828 [01:03<02:23, 558.37it/s]
# Dual-gate cointegration (EG + Johansen):  33%|███▎      | 38673/118828 [01:04<02:29, 537.55it/s]
# Dual-gate cointegration (EG + Johansen):  33%|███▎      | 38745/118828 [01:04<02:28, 538.24it/s]
# Dual-gate cointegration (EG + Johansen):  33%|███▎      | 38809/118828 [01:04<02:26, 547.20it/s]
# Dual-gate cointegration (EG + Johansen):  33%|███▎      | 38873/118828 [01:04<02:21, 565.92it/s]
# ...
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108106/118828 [03:11<00:19, 562.65it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108185/118828 [03:11<00:17, 597.28it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108245/118828 [03:11<00:18, 569.94it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108321/118828 [03:11<00:17, 593.06it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108381/118828 [03:11<00:17, 590.06it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108457/118828 [03:11<00:17, 601.34it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108518/118828 [03:11<00:17, 579.64it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108576/118828 [03:12<00:18, 540.79it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108665/118828 [03:12<00:16, 628.88it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108729/118828 [03:12<00:17, 574.86it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108801/118828 [03:12<00:17, 588.35it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108861/118828 [03:12<00:17, 582.72it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108937/118828 [03:12<00:15, 618.45it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109000/118828 [03:12<00:17, 566.86it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109073/118828 [03:12<00:17, 562.35it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109130/118828 [03:13<00:18, 515.84it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109217/118828 [03:13<00:15, 603.64it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109280/118828 [03:13<00:16, 568.43it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109345/118828 [03:13<00:16, 588.91it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109417/118828 [03:13<00:16, 574.42it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109476/118828 [03:13<00:17, 540.72it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109569/118828 [03:13<00:14, 629.71it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109634/118828 [03:13<00:16, 561.28it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109713/118828 [03:14<00:16, 557.34it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109793/118828 [03:14<00:14, 602.50it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109855/118828 [03:14<00:15, 572.05it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 109929/118828 [03:14<00:14, 611.08it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 109992/118828 [03:14<00:15, 561.06it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110073/118828 [03:14<00:15, 573.88it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110132/118828 [03:14<00:15, 575.01it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110201/118828 [03:14<00:14, 604.69it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110263/118828 [03:14<00:14, 575.42it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110329/118828 [03:15<00:14, 582.20it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110388/118828 [03:15<00:14, 575.96it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110465/118828 [03:15<00:13, 602.51it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110526/118828 [03:15<00:14, 581.00it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110593/118828 [03:15<00:13, 594.76it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110653/118828 [03:15<00:13, 585.87it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110713/118828 [03:15<00:14, 575.29it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110771/118828 [03:15<00:14, 542.26it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110841/118828 [03:15<00:13, 583.61it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110900/118828 [03:16<00:13, 576.82it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110961/118828 [03:16<00:13, 573.51it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111025/118828 [03:16<00:13, 570.94it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111089/118828 [03:16<00:13, 579.80it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111153/118828 [03:16<00:13, 573.72it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111217/118828 [03:16<00:13, 581.96it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111281/118828 [03:16<00:12, 584.17it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111345/118828 [03:16<00:12, 578.22it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111417/118828 [03:16<00:12, 599.62it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111478/118828 [03:17<00:12, 594.24it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111545/118828 [03:17<00:12, 602.55it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111609/118828 [03:17<00:12, 563.55it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111681/118828 [03:17<00:11, 605.10it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111743/118828 [03:17<00:11, 600.18it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111809/118828 [03:17<00:11, 608.62it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111871/118828 [03:17<00:12, 559.46it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111945/118828 [03:17<00:12, 567.09it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112009/118828 [03:17<00:11, 580.03it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112073/118828 [03:18<00:11, 563.07it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112161/118828 [03:18<00:10, 623.79it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112224/118828 [03:18<00:11, 594.66it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112297/118828 [03:18<00:10, 630.23it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112361/118828 [03:18<00:12, 532.01it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112449/118828 [03:18<00:11, 541.98it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112545/118828 [03:18<00:10, 610.31it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112608/118828 [03:18<00:10, 594.59it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112689/118828 [03:19<00:09, 638.03it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112755/118828 [03:19<00:11, 531.44it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112833/118828 [03:19<00:10, 583.22it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112913/118828 [03:19<00:10, 569.97it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112973/118828 [03:19<00:10, 564.58it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113057/118828 [03:19<00:09, 629.68it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113123/118828 [03:19<00:10, 548.57it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113209/118828 [03:19<00:09, 614.96it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113274/118828 [03:20<00:09, 589.60it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113345/118828 [03:20<00:09, 575.37it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113417/118828 [03:20<00:08, 609.66it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113480/118828 [03:20<00:08, 607.40it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113542/118828 [03:20<00:09, 566.57it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113617/118828 [03:20<00:08, 582.62it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113677/118828 [03:20<00:08, 577.16it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113737/118828 [03:20<00:08, 570.27it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113801/118828 [03:21<00:08, 574.95it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113865/118828 [03:21<00:08, 581.27it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113924/118828 [03:21<00:08, 583.49it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113985/118828 [03:21<00:08, 581.78it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114049/118828 [03:21<00:08, 578.44it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114121/118828 [03:21<00:07, 602.02it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114185/118828 [03:21<00:07, 590.63it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114257/118828 [03:21<00:07, 584.70it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114316/118828 [03:21<00:07, 578.80it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114385/118828 [03:22<00:07, 577.86it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114443/118828 [03:22<00:07, 567.49it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114513/118828 [03:22<00:07, 584.60it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114572/118828 [03:22<00:07, 570.20it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114633/118828 [03:22<00:07, 577.96it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114691/118828 [03:22<00:07, 577.27it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114761/118828 [03:22<00:06, 592.96it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114821/118828 [03:22<00:07, 559.71it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114897/118828 [03:22<00:06, 566.75it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114954/118828 [03:23<00:08, 458.11it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115049/118828 [03:23<00:06, 569.79it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115137/118828 [03:23<00:06, 566.91it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115201/118828 [03:23<00:06, 583.70it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115273/118828 [03:23<00:05, 609.42it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115337/118828 [03:23<00:06, 559.08it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115409/118828 [03:23<00:05, 584.45it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115470/118828 [03:23<00:06, 525.53it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115561/118828 [03:24<00:05, 597.86it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115623/118828 [03:24<00:05, 561.88it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115705/118828 [03:24<00:05, 612.95it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115768/118828 [03:24<00:05, 578.36it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115841/118828 [03:24<00:05, 526.22it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115913/118828 [03:24<00:05, 567.60it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115972/118828 [03:24<00:05, 540.44it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116033/118828 [03:24<00:05, 535.98it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116105/118828 [03:25<00:04, 570.12it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116169/118828 [03:25<00:04, 587.33it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116241/118828 [03:25<00:04, 612.82it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116304/118828 [03:25<00:04, 551.52it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116377/118828 [03:25<00:04, 593.93it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116438/118828 [03:25<00:04, 569.33it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116505/118828 [03:25<00:03, 582.18it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116577/118828 [03:25<00:03, 611.70it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116639/118828 [03:25<00:03, 576.87it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116713/118828 [03:26<00:03, 610.98it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116775/118828 [03:26<00:03, 590.89it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116835/118828 [03:26<00:03, 589.41it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116895/118828 [03:26<00:03, 524.35it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116969/118828 [03:26<00:03, 567.01it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 117033/118828 [03:26<00:03, 560.85it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117097/118828 [03:26<00:02, 580.14it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117156/118828 [03:26<00:02, 569.70it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117225/118828 [03:26<00:02, 585.66it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117297/118828 [03:27<00:02, 583.75it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117356/118828 [03:27<00:02, 573.89it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117425/118828 [03:27<00:02, 588.97it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117489/118828 [03:27<00:02, 600.00it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117553/118828 [03:27<00:02, 587.07it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117617/118828 [03:27<00:02, 581.18it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117676/118828 [03:27<00:02, 529.55it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117761/118828 [03:27<00:01, 550.68it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117865/118828 [03:28<00:01, 599.06it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117937/118828 [03:28<00:01, 593.34it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118009/118828 [03:28<00:01, 591.14it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118081/118828 [03:28<00:01, 594.77it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118141/118828 [03:28<00:01, 505.05it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118257/118828 [03:28<00:00, 584.84it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118337/118828 [03:28<00:00, 606.20it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118399/118828 [03:29<00:00, 588.86it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118465/118828 [03:29<00:00, 599.41it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118526/118828 [03:29<00:00, 559.70it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118609/118828 [03:29<00:00, 622.94it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118673/118828 [03:29<00:00, 552.48it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118769/118828 [03:29<00:00, 619.96it/s]
# Total pairs screened : 118,828
# Dual-gate pass (verdict=='pass'): 6102
#                      eg_t          eg_p  eg_pass   joh_stat  joh_pass verdict
# ticker1 ticker2
# NCLH    SHOP    -6.892330  1.544746e-08     True  37.268515      True    pass
#         TRMB    -6.774412  2.923744e-08     True  42.340817      True    pass
#         ZBRA    -6.725933  3.793752e-08     True  36.397732      True    pass
#         XYZ     -6.691579  4.559848e-08     True  34.453662      True    pass
#         SBUX    -6.533492  1.055287e-07     True  38.528619      True    pass

# %% [markdown]
# ## 2.2 Pre-scoring: rank candidates for Kalman filtering
#
# We rank all pairs by a composite rank score (EG p-value + Johansen statistic) and
# take the top 200 as candidates for the computationally expensive Kalman step.

# %%
tmp = summary_dual.copy()
# Gate on the FDR survivors BEFORE the rank cut. Benjamini-Hochberg is a monotone
# transform of the sorted p-values, so it cannot reorder a rank -- which is why
# correcting and not correcting used to give byte-identical shortlists. Filtering
# on the verdict is what makes the correction bind on anything downstream.
_passed = tmp["eg_pass_fdr"] & tmp["joh_pass"] if "eg_pass_fdr" in tmp.columns else tmp["verdict"].eq("pass")
print(f"dual-gate survivors under the correction: {int(_passed.sum()):,} of {len(tmp):,}")
tmp = tmp.loc[_passed] if int(_passed.sum()) >= 20 else tmp
tmp["rank_eg"]  = tmp["eg_p"].rank(method="average", ascending=True)
tmp["rank_joh"] = tmp["joh_stat"].rank(method="average", ascending=False)
tmp["pre_score"] = 0.5 * (tmp["rank_eg"] / tmp["rank_eg"].max()
                         + tmp["rank_joh"] / tmp["rank_joh"].max())
prelim     = tmp.sort_values("pre_score", ascending=True)
candidates = prelim.head(200).index.to_list()
print(f"Candidates selected for Kalman filtering: {len(candidates)}")
# Out:
# dual-gate survivors under the correction: 6,102 of 118,828
# Candidates selected for Kalman filtering: 200

# %% [markdown]
# # 3. Kalman Filter Hedge Estimation & Stationarity Scoring
#
# ## 3.1 Kalman filter model overview
#
# We estimate a **time-varying** hedge ratio $\beta_t$ via a linear Gaussian state-space model.
#
# **State (random walk):**
# $$
# \theta_t = \begin{bmatrix}\beta_t \\ \alpha_t\end{bmatrix}, \qquad
# \theta_t = \theta_{t-1} + w_t, \quad w_t \sim \mathcal{N}(0, Q)
# $$
#
# **Observation:**
# $$
# y_t = \alpha_t + \beta_t x_t + v_t, \quad v_t \sim \mathcal{N}(0, R)
# $$
#
# Parameters $Q$ and $R$ are learned by EM; the recursion is then run in **filter mode**
# (the causal forward pass) for both the in-sample residuals and the OOS evaluation. The RTS
# smoother is never used: it conditions the state at bar $t$ on the whole sample, which would
# leak the future into the residual a signal reads.

# %%
from pairs import fit_kalman_hedge, summarize_spread_stationarity_joblib

states_tr, params_tr = fit_kalman_hedge(
    df_train,
    pairs=candidates,
    mode="filter",   # causal: the smoother would let each state see the future
    em_iters=5,
    q=1e-5,
    n_workers=None,
    chunksize=100,
    show_progress=True,
    return_params=True,
)
print(f"Kalman states computed for {len(states_tr)} pairs")
# Out:
# Kalman (α_t, β_t):   0%|          | 0/200 [00:00<?, ?it/s]
# Kalman (α_t, β_t):   1%|          | 2/200 [00:03<05:09,  1.56s/it]
# Kalman (α_t, β_t):   7%|▋         | 14/200 [00:03<00:31,  5.84it/s]
# Kalman (α_t, β_t):  12%|█▏        | 24/200 [00:03<00:15, 11.35it/s]
# Kalman (α_t, β_t):  16%|█▋        | 33/200 [00:04<00:15, 10.53it/s]
# Kalman (α_t, β_t):  20%|██        | 41/200 [00:04<00:10, 14.76it/s]
# Kalman (α_t, β_t):  24%|██▎       | 47/200 [00:04<00:09, 16.63it/s]
# Kalman (α_t, β_t):  26%|██▌       | 52/200 [00:05<00:12, 11.41it/s]
# Kalman (α_t, β_t):  28%|██▊       | 57/200 [00:05<00:10, 14.20it/s]
# Kalman (α_t, β_t):  31%|███       | 62/200 [00:05<00:08, 16.00it/s]
# Kalman (α_t, β_t):  33%|███▎      | 66/200 [00:06<00:12, 10.32it/s]
# Kalman (α_t, β_t):  36%|███▌      | 72/200 [00:06<00:09, 14.02it/s]
# Kalman (α_t, β_t):  38%|███▊      | 77/200 [00:06<00:07, 16.76it/s]
# Kalman (α_t, β_t):  40%|████      | 81/200 [00:07<00:11, 10.12it/s]
# Kalman (α_t, β_t):  43%|████▎     | 86/200 [00:07<00:08, 13.10it/s]
# Kalman (α_t, β_t):  46%|████▌     | 92/200 [00:08<00:06, 17.38it/s]
# Kalman (α_t, β_t):  48%|████▊     | 96/200 [00:08<00:06, 15.80it/s]
# Kalman (α_t, β_t):  50%|████▉     | 99/200 [00:09<00:09, 10.54it/s]
# Kalman (α_t, β_t):  53%|█████▎    | 106/200 [00:09<00:05, 15.86it/s]
# Kalman (α_t, β_t):  55%|█████▌    | 110/200 [00:09<00:06, 14.49it/s]
# Kalman (α_t, β_t):  56%|█████▋    | 113/200 [00:10<00:08, 10.20it/s]
# Kalman (α_t, β_t):  59%|█████▉    | 118/200 [00:10<00:06, 13.66it/s]
# Kalman (α_t, β_t):  62%|██████▏   | 123/200 [00:10<00:04, 17.74it/s]
# Kalman (α_t, β_t):  64%|██████▎   | 127/200 [00:10<00:04, 14.69it/s]
# Kalman (α_t, β_t):  65%|██████▌   | 130/200 [00:11<00:06, 10.69it/s]
# Kalman (α_t, β_t):  66%|██████▋   | 133/200 [00:11<00:05, 12.59it/s]
# Kalman (α_t, β_t):  69%|██████▉   | 138/200 [00:11<00:03, 16.82it/s]
# Kalman (α_t, β_t):  70%|███████   | 141/200 [00:11<00:03, 17.36it/s]
# Kalman (α_t, β_t):  72%|███████▏  | 144/200 [00:12<00:04, 13.81it/s]
# Kalman (α_t, β_t):  74%|███████▎  | 147/200 [00:12<00:04, 10.62it/s]
# Kalman (α_t, β_t):  75%|███████▌  | 150/200 [00:12<00:04, 12.26it/s]
# Kalman (α_t, β_t):  78%|███████▊  | 155/200 [00:12<00:02, 15.88it/s]
# Kalman (α_t, β_t):  79%|███████▉  | 158/200 [00:13<00:02, 14.13it/s]
# Kalman (α_t, β_t):  80%|████████  | 160/200 [00:13<00:02, 14.19it/s]
# Kalman (α_t, β_t):  81%|████████  | 162/200 [00:13<00:03, 10.19it/s]
# Kalman (α_t, β_t):  83%|████████▎ | 166/200 [00:13<00:02, 12.90it/s]
# Kalman (α_t, β_t):  85%|████████▌ | 170/200 [00:13<00:01, 16.75it/s]
# Kalman (α_t, β_t):  86%|████████▋ | 173/200 [00:14<00:02, 13.27it/s]
# Kalman (α_t, β_t):  88%|████████▊ | 176/200 [00:14<00:01, 14.92it/s]
# Kalman (α_t, β_t):  89%|████████▉ | 178/200 [00:14<00:02, 10.60it/s]
# Kalman (α_t, β_t):  91%|█████████ | 182/200 [00:14<00:01, 13.17it/s]
# Kalman (α_t, β_t):  94%|█████████▎| 187/200 [00:15<00:00, 16.89it/s]
# Kalman (α_t, β_t):  95%|█████████▌| 190/200 [00:15<00:00, 14.96it/s]
# Kalman (α_t, β_t):  96%|█████████▋| 193/200 [00:15<00:00, 12.68it/s]
# Kalman (α_t, β_t):  98%|█████████▊| 197/200 [00:15<00:00, 16.32it/s]
# Kalman (α_t, β_t): 100%|██████████| 200/200 [00:15<00:00, 17.75it/s]
# Kalman states computed for 200 pairs

# %% [markdown]
# ## 3.2 Spread stationarity diagnostics
#
# For each pair we run:
# 1. **ADF** (Augmented Dickey-Fuller) — reject $H_0$ of unit root → spread is I(0)
# 2. **KPSS** — fail to reject $H_0$ of stationarity → spread is I(0)
#
# **Verdict**: `stationary` if ADF rejects AND KPSS does not reject; `non-stationary` if vice versa;
# `inconclusive` otherwise.
#
# Additional diagnostics: **half-life** (AR(1) proxy for mean-reversion speed) and
# **residual sigma** (spread volatility).

# %%
summary_stationarity = summarize_spread_stationarity_joblib(
    states_tr, alpha=0.05, regression="c", chunksize=256, show_progress=True
)
print(f"\n{len(summary_stationarity)} pairs tested")
summary_stationarity.head(10)
# Out:
# Testing stationarity:   0%|          | 0/200 [00:00<?, ?it/s]
# Testing stationarity:   1%|          | 2/200 [00:00<01:20,  2.47it/s]
# Testing stationarity:  26%|██▌       | 52/200 [00:00<00:01, 76.95it/s]
# Testing stationarity:  70%|██████▉   | 139/200 [00:01<00:00, 216.32it/s]
# 200 pairs tested
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# NCLH    ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
#         VICI    -12.742477  8.883603e-24   0.554256  0.029447  1.525712
# CCL     NWS     -10.183337  6.606414e-18   0.907258  0.010000  2.153599
#         NWSA     -9.949875  2.531373e-17   0.929327  0.010000  2.286437
# NCLH    WY       -9.567755  2.332259e-16   0.562237  0.027649  1.378453
# CCL     GM       -9.044586  5.026671e-15   0.691584  0.014311  0.927928
#         COF      -8.909964  1.111177e-14   0.852376  0.010000  0.733056
#         DLR      -8.896328  1.204185e-14   0.465979  0.049329  0.613365
# NCLH    TDY      -8.631832  5.727872e-14   0.465533  0.049430  0.602453
# CCL     EQIX     -8.606261  6.659842e-14   0.555863  0.029085  0.645483
#
#                  resid_sigma    shapre       verdict
# ticker1 ticker2
# NCLH    ZBH         0.272626 -0.013607  inconclusive
#         VICI        0.703102 -0.056798  inconclusive
# CCL     NWS         0.772486 -0.077707  inconclusive
#         NWSA        0.798079 -0.080570  inconclusive
# NCLH    WY          0.645115 -0.048115  inconclusive
# CCL     GM          0.380726  0.012253  inconclusive
#         COF         0.276555 -0.015717  inconclusive
#         DLR         0.215440 -0.041952  inconclusive
# NCLH    TDY         0.235948 -0.017003  inconclusive
# CCL     EQIX        0.226906 -0.026816  inconclusive

# %% [markdown]
# ## 3.3 Composite scoring
#
# Convert heterogeneous metrics into comparable z-scores (higher = better), then take a
# weighted sum:
#
# | Metric | Transform | Direction |
# |--------|-----------|-----------|
# | ADF p-value | $-\log_{10}(p)$ then $Z(\cdot)$ | smaller p → better |
# | KPSS p-value | $Z(p)$ | larger p → better |
# | Half-life | $-\log(1+\text{hl})$ then $Z(\cdot)$ | shorter → better |
# | Residual sigma | $Z(-\sigma)$ | smaller → better |
# | Sharpe (train) | $Z(\text{Sharpe})$ | higher → better |
#
# > ℹ️ **All five rows contribute.** The summary function emits the column under the misspelling
# > `shapre`. The scoring cell used to read `sharpe_train` through `.get(..., 0.0)`, so the lookup
# > returned a constant zero and the ranking ran on four metrics; it now reads `shapre` directly.
# > The shortlist moved when this was fixed.

# %%
from pairs.stats import Z

final_df = summary_stationarity.copy()
for col in ["adf_p", "kpss_p", "halflife", "resid_sigma", "shapre"]:
    if col in final_df.columns:
        final_df[col] = pd.to_numeric(final_df[col], errors="coerce")

# the summary function emits this column as "shapre"; reading "sharpe_train"
# silently returned a constant 0.0, so this term contributed nothing at all
sharpe_series = final_df.get("shapre", pd.Series(0.0, index=final_df.index))
p_adf   = final_df["adf_p"].clip(lower=1e-300, upper=1.0)
p_kpss  = final_df["kpss_p"].clip(lower=1e-300, upper=1.0)
hl_safe = final_df["halflife"].clip(lower=0)

components = {
    "adf":    Z(-np.log10(p_adf)),
    "kpss":   Z(p_kpss),
    "hl":     Z(-np.log1p(hl_safe)),
    "sigma":  Z(-final_df["resid_sigma"]),
    "sharpe": Z(sharpe_series),
}
weights = {k: 1.0 for k in components}
final_df["score"] = sum(weights[k] * components[k] for k in components)
ranked = final_df.sort_values("score", ascending=False)
ranked.head(10)
# Out:
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# BKNG    MA      -26.184819  0.000000e+00   0.107466  0.100000  0.374708
# AVGO    RL      -20.604764  0.000000e+00   0.038229  0.100000  0.461536
# HSIC    PLD     -20.181146  0.000000e+00   0.026152  0.100000  0.827721
# NCLH    REG     -23.778528  0.000000e+00   0.244832  0.100000  0.886268
#         ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
# BA      JKHY    -20.661471  0.000000e+00   0.197209  0.100000  0.670420
# CRM     EQIX    -17.680054  3.611653e-30   0.036575  0.100000  0.204733
# NCLH    SBAC     -9.112234  3.375238e-15   0.339735  0.100000  0.564747
#         NTRS     -7.356914  9.725985e-11   0.245896  0.100000  0.725062
# HSIC    JBHT     -9.291383  1.177221e-15   0.035744  0.100000  0.736163
#
#                  resid_sigma    shapre       verdict     score
# ticker1 ticker2
# BKNG    MA          0.363197 -0.001418    stationary  9.113378
# AVGO    RL          0.540440 -0.009011    stationary  8.415701
# HSIC    PLD         0.547642 -0.006295    stationary  7.727495
# NCLH    REG         0.384512 -0.032411    stationary  7.269940
#         ZBH         0.272626 -0.013607  inconclusive  6.984557
# BA      JKHY        1.547649 -0.002096    stationary  6.384682
# CRM     EQIX        0.306883 -0.001555    stationary  4.200154
# NCLH    SBAC        0.202152 -0.022734    stationary  2.696865
#         NTRS        0.300283 -0.002925    stationary  2.595763
# HSIC    JBHT        0.475680 -0.001816    stationary  2.394623

# %%
ranked['score'].reset_index(drop=True).plot(
    figsize=(12, 4), grid=True,
    title="Composite score — candidates ranked best → worst",
    xlabel="Rank", ylabel="Score",
)
plt.axhline(-3, color="red", linestyle="--", lw=1.5, label="threshold = −3")
plt.legend(); plt.tight_layout(); plt.show()

# %%
ranked_positive = ranked[ranked["score"] > -3]
robust_pairs    = ranked_positive.index
print(f"Candidates: {len(candidates)}  →  Robust pairs (score > −3): {len(robust_pairs)}")
# Out:
# Candidates: 200  →  Robust pairs (score > −3): 184

# %% [markdown]
# ## 3.4 Pre-filter candidates (composite score)
#
# The composite score from §3.3 is **only a cheap pre-filter** — it narrows the robust pairs down to a short list of candidates. It does **not** pick the traded pair: selecting the single best *in-sample* score is exactly the overfitting trap we want to avoid.
#
# The final pair is chosen in **§3.5** by **walk-forward cross-fold stability**, using only training-span data (2020–2025). The 2026 window (§4b) is never consulted for selection — it stays a genuine held-out test.

# %%
# Composite score is a CHEAP PRE-FILTER only — it does NOT pick the final pair.
# Take the top-N robust candidates; the walk-forward driver in §3.5 selects among them.
N_CANDIDATES = 15
wf_candidates = list(robust_pairs[:N_CANDIDATES])

print(f"Pre-filtered to top {len(wf_candidates)} candidates by composite score "
      f"(of {len(robust_pairs)} robust pairs). Final pick is deferred to §3.5.")
for i, (t1, t2) in enumerate(wf_candidates, 1):
    print(f"  {i:2d}. {t1:6s}/{t2:6s}  score={ranked.loc[(t1, t2), 'score']:.3f}")
# Out:
# Pre-filtered to top 15 candidates by composite score (of 184 robust pairs). Final pick is deferred to §3.5.
#    1. BKNG  /MA      score=9.113
#    2. AVGO  /RL      score=8.416
#    3. HSIC  /PLD     score=7.727
#    4. NCLH  /REG     score=7.270
#    5. NCLH  /ZBH     score=6.985
#    6. BA    /JKHY    score=6.385
#    7. CRM   /EQIX    score=4.200
#    8. NCLH  /SBAC    score=2.697
#    9. NCLH  /NTRS    score=2.596
#   10. HSIC  /JBHT    score=2.395
#   11. NCLH  /WAT     score=2.384
#   12. NCLH  /WTW     score=2.369
#   13. NCLH  /SPG     score=2.360
#   14. NCLH  /VRSN    score=2.259
#   15. NCLH  /PSX     score=2.252

# %% [markdown]
# ## 3.5 Walk-forward selection driver  ← *this* picks the traded pair
#
# We run walk-forward validation (rolling train/test folds over the 2020–2025 training span) on **each** pre-filtered candidate and rank by the **median per-fold Sharpe**. Median rewards pairs whose edge is *consistent across folds* rather than pairs that got one lucky window. `MIN_TOTAL_TRADES` screens out pairs too inactive to judge.
#
# This is the holdout principle done correctly for time series: **selection happens on validation folds**; the 2026 test set in §4b is never touched here. The top-ranked pair becomes `ticker1, ticker2` for everything downstream.
#
# The z-score look-back for each test fold is estimated from the *training* fold's residual, which also warms up the rolling window — the test fold never informs its own z-score (no in-fold look-ahead).

# %%
# === Walk-forward selection driver (parallel across candidates) =============
# Each candidate's walk-forward run is independent, so we fan them out with joblib.
# walk_forward_backtest is itself serial (no nested parallelism) and the fit uses the
# single-pair _kalman_dynamic_hedge (no internal process pool) — so the only thing to
# guard against is BLAS thread oversubscription. Pin threads to 1 (as the Kalman module
# does internally) before the worker processes are spawned.
import os
for _v in ("OPENBLAS_NUM_THREADS", "MKL_NUM_THREADS", "NUMEXPR_NUM_THREADS", "OMP_NUM_THREADS"):
    os.environ.setdefault(_v, "1")

from joblib import Parallel, delayed
from pairs import walk_forward_backtest, filter_kf_on_new
from pairs.models.kalman import _kalman_dynamic_hedge
from pairs.strategies.signals import generate_pair_signals, estimate_halflife_window
from pairs.strategies.evaluate import evaluate_pair_signals

MIN_TOTAL_TRADES = 12   # skip candidates too inactive to rank reliably
N_JOBS = -1             # -1 = all cores; each job is one candidate's walk-forward

prices_wide_tr = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values("datetime"),
    columns=df_filtered.index.get_level_values("ticker"),
    values="close",
)

def _sel_fit_fn(df_train):
    # Filtered (causal) states so the residual history handed to the test fold has the same
    # statistical properties as the causal test-fold residual; the EM fit and the exported
    # end state are unaffected by the choice of mode.
    _, _, states, params = _kalman_dynamic_hedge(
        "P1", "P2", df_train, q=1e-5, em_iters=5, mode="filter", return_params=True)
    if states is None or params is None:
        return None
    # The z-score look-back is chosen from the TRAINING residual, and that residual is carried
    # along as warm-up history — the test fold never informs its own z-score (no look-ahead).
    params = dict(params)
    params["z_window"]  = estimate_halflife_window(states["resid"])
    params["z_history"] = states["resid"]
    return params

def _sel_signal_fn(df_test, params):
    frozen = {"F": params["F"], "Q": params["Q"], "R": params["R"]}
    last_state = (params["last_state_mean"], params["last_state_cov"])
    states_te, _ = filter_kf_on_new(
        df_test["P1"], df_test["P2"],
        frozen=frozen, last_state=last_state, mode="filter")  # causal, no look-ahead
    df_pair_fold = df_test[["P1", "P2"]].join(states_te[["beta", "resid"]], how="inner")
    return generate_pair_signals(
        df_pair_fold, z_method="robust",
        z_window=params["z_window"], z_history=params["z_history"],   # from the training fold
        z_entry=2.0, z_exit=0.5, z_stop=4.0, capital_per_pair=10_000)

def _sel_eval_fn(df_test, signals):
    _, _, summary = evaluate_pair_signals(
        df_test[["P1", "P2"]], signals,
        cost_bps=1, borrow_bps_per_year=50, days_per_year=252, bars_per_year=252)
    return summary

def _wf_one(t1, t2, df_wf_c, score):
    """Run walk-forward for one candidate; return ('ok', row) / ('error', ...) / None."""
    try:
        res = walk_forward_backtest(
            df_wf_c, train_bars=504, test_bars=126, step_bars=63,
            fit_fn=_sel_fit_fn, signal_fn=_sel_signal_fn, eval_fn=_sel_eval_fn,
            verbose=False)
    except Exception as e:
        return ("error", t1, t2, str(e))
    if res is None or len(res) == 0:
        return None
    s = res["sharpe"].to_numpy(dtype=float)
    n_tr = res["n_trades"].to_numpy(dtype=float)
    return ("ok", {
        "ticker1": t1, "ticker2": t2,
        "wf_sharpe_median": np.nanmedian(s),
        "wf_sharpe_mean":   np.nanmean(s),
        "wf_sharpe_std":    np.nanstd(s),
        "pct_pos_folds":    float(np.mean(s > 0)) if np.isfinite(s).any() else np.nan,
        "wf_trades_total":  int(np.nansum(n_tr)),
        "n_folds":          int(np.isfinite(s).sum()),
        "composite_score":  float(score),
    }, res)

# Build the (small) per-candidate inputs up front; skip pairs with too little history.
_tasks = []
for (t1, t2) in wf_candidates:
    df_wf_c = prices_wide_tr[[t1, t2]].rename(columns={t1: "P1", t2: "P2"}).dropna()
    if len(df_wf_c) < 504 + 126:        # not enough history for even one fold
        continue
    _tasks.append((t1, t2, df_wf_c, float(ranked.loc[(t1, t2), "score"])))

_results = Parallel(n_jobs=N_JOBS, prefer="processes")(
    delayed(_wf_one)(t1, t2, df_wf_c, score) for (t1, t2, df_wf_c, score) in _tasks
)

rows = []
wf_by_pair = {}            # keep each candidate's full per-fold results for reuse
for r in _results:
    if r is None:
        continue
    if r[0] == "error":
        print(f"  skip {r[1]}/{r[2]}: {r[3]}")
        continue
    rows.append(r[1])
    wf_by_pair[(r[1]["ticker1"], r[1]["ticker2"])] = r[2]

wf_selection = pd.DataFrame(rows).set_index(["ticker1", "ticker2"])
wf_selection = wf_selection[wf_selection["wf_trades_total"] >= MIN_TOTAL_TRADES]
wf_selection = wf_selection.sort_values("wf_sharpe_median", ascending=False)

print(f"Ranked {len(wf_selection)} candidates by walk-forward median fold Sharpe "
      f"(>= {MIN_TOTAL_TRADES} total trades):\n")
print(wf_selection.head(10).to_string(float_format="{:.3f}".format))

ticker1, ticker2 = wf_selection.index[0]
wf_results = wf_by_pair[(ticker1, ticker2)]   # winner's folds, for the detail plot below
print(f"\nWalk-forward-selected pair: {ticker1} / {ticker2}")
print("(Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)")
# Out:
# Ranked 15 candidates by walk-forward median fold Sharpe (>= 12 total trades):
#
#                  wf_sharpe_median  wf_sharpe_mean  wf_sharpe_std  pct_pos_folds  wf_trades_total  n_folds  composite_score
# ticker1 ticker2
# BKNG    MA                  1.222           1.027          1.263          0.750              124       16            9.113
# NCLH    REG                 0.891           0.480          1.539          0.750              114       16            7.270
#         SPG                 0.629           0.527          1.126          0.688              118       16            2.360
#         NTRS                0.346           0.410          1.518          0.562              136       16            2.596
# AVGO    RL                  0.305           0.400          0.937          0.688              107       16            8.416
# NCLH    PSX                 0.300           0.006          1.367          0.562              116       16            2.252
#         WAT                 0.248           0.277          1.425          0.500              128       16            2.384
# CRM     EQIX                0.148           0.249          0.917          0.562              119       16            4.200
# NCLH    ZBH                -0.034          -0.037          1.358          0.500              120       16            6.985
# HSIC    JBHT               -0.150          -0.240          1.690          0.500              118       16            2.395
#
# Walk-forward-selected pair: BKNG / MA
# (Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)

# %% [markdown]
# ### 3.5.1 Walk-forward detail for the selected pair
#
# §3.5 ranked the shortlist by **median per-fold Sharpe** and selected the pair above. Below is that pair's full per-fold walk-forward distribution — the validation evidence behind the choice, reusing the folds already computed (no recomputation). A tight, mostly-positive distribution is what we want; one that swings sign across folds means the edge is fragile.

# %%
# Per-fold walk-forward detail for the SELECTED pair — reuses wf_results from §3.5
# (no recomputation). nan-robust stats (a zero-trade fold yields a NaN Sharpe).
from pairs.validation.walk_forward import summarize_walk_forward

print(f"=== Walk-forward folds for selected pair {ticker1}/{ticker2} ===\n")
print(summarize_walk_forward(wf_results).to_string(float_format="{:.3f}".format))

fig, axes = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle(f"Walk-Forward Validation: {ticker1}/{ticker2}  "
             f"(train=504d, test=126d, step=63d)", fontsize=13)

sharpes  = wf_results["sharpe"].to_numpy(dtype=float)
ann_rets = wf_results["ann_return"].to_numpy(dtype=float) * 100
dds      = wf_results["max_drawdown_pct"].abs().to_numpy(dtype=float) * 100
n_trades = wf_results["n_trades"].to_numpy(dtype=float)
folds    = wf_results.index.values

def _bar(ax, vals, title, ylabel, pos_neg=True):
    colors = ["green" if v > 0 else "red" for v in vals] if pos_neg else "salmon"
    ax.bar(folds, vals, color=colors, alpha=0.75, edgecolor="white")
    ax.axhline(0, color="black", lw=0.8)
    ax.axhline(np.nanmean(vals), color="navy", linestyle="--", lw=1.5,
               label=f"Mean={np.nanmean(vals):.2f}")
    ax.set_xlabel("Fold"); ax.set_ylabel(ylabel); ax.set_title(title); ax.legend()

_bar(axes[0, 0], sharpes,  "Per-Fold Sharpe Ratio",      "Sharpe")
_bar(axes[0, 1], ann_rets, "Per-Fold Annualized Return", "Ann. Return (%)")
_bar(axes[1, 0], dds,      "Per-Fold Max Drawdown",      "Max Drawdown (%)", pos_neg=False)
_bar(axes[1, 1], n_trades, "Per-Fold Trade Count",       "Trades", pos_neg=False)
plt.tight_layout(); plt.show()

pct_pos = float(np.mean(sharpes > 0)) * 100
print(f"\nFolds with positive Sharpe : {pct_pos:.0f}%  ({int((sharpes > 0).sum())}/{len(sharpes)})")
print(f"Median fold Sharpe         : {np.nanmedian(sharpes):.2f}")
print(f"Mean fold Sharpe           : {np.nanmean(sharpes):.2f}  (std={np.nanstd(sharpes):.2f})")
# Out:
# === Walk-forward folds for selected pair BKNG/MA ===
#
#                   mean   std  median    min    max
# sharpe           1.027 1.304   1.222 -1.099  3.054
# ann_return       0.058 0.081   0.065 -0.097  0.175
# max_drawdown_pct 0.025 0.022   0.018  0.008  0.102
# n_trades         7.750 2.352   8.000  4.000 12.000
# hit_rate         0.718 0.161   0.732  0.333  1.000
# profit_factor      inf   NaN   3.274  0.186    inf
# Folds with positive Sharpe : 75%  (12/16)
# Median fold Sharpe         : 1.22
# Mean fold Sharpe           : 1.03  (std=1.26)

# %% [markdown]
# # 4. In-Sample Signal Generation & Evaluation (2020–2025)
#
# ## 4.1 Build the pair-aligned DataFrame

# %%
df_kf = states_tr[(ticker1, ticker2)]

prices = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values('datetime'),
    columns=df_filtered.index.get_level_values('ticker'),
    values='close',
)

df_pair = pd.DataFrame({
    'P1': prices[ticker1],
    'P2': prices[ticker2],
}).join(df_kf[['beta', 'resid']])

print(f"Training pair frame: {df_pair.index[0].date()} → {df_pair.index[-1].date()}, "
      f"{len(df_pair):,} bars")
df_pair.tail(3)
# Out:
# Training pair frame: 2020-01-02 → 2025-12-31, 1,508 bars
#                     P1          P2      beta     resid
# datetime
# 2025-12-29  217.653198  577.900024  0.343690  0.062141
# 2025-12-30  217.085999  577.419983  0.343163 -0.035799
# 2025-12-31  214.213196  570.880005  0.342126 -0.071359

# %% [markdown]
# ## 4.2 Generate trading signals
#
# Signal logic:
# - **Entry**: |z| > `z_entry` (default 2.0) — spread is extreme
# - **Exit** : |z| < `z_exit`  (default 0.5) — spread has mean-reverted
# - **Stop** : |z| > `z_stop`  (default 4.0) — spread is diverging
#
# Z-score is computed with the *robust* method (median/MAD) which is less sensitive to outliers.

# %%
from pairs.strategies import generate_pair_signals

signals = generate_pair_signals(
    df_pair,
    z_method="robust",
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
    max_hold_bars=None,
    cooldown_bars=0,
)
signals.tail(5)
# Out:
#                    z  pos   n1   n2  entry   exit   stop
# datetime
# 2025-12-24 -0.428719    0  0.0  0.0  False  False  False
# 2025-12-26 -0.191140    0  0.0  0.0  False  False  False
# 2025-12-29 -0.015958    0  0.0  0.0  False  False  False
# 2025-12-30 -0.196630    0  0.0  0.0  False  False  False
# 2025-12-31 -0.362246    0  0.0  0.0  False  False  False

# %% [markdown]
# ## 4.3 Visualize in-sample trades

# %%
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair, signals,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4.4 In-sample performance metrics

# %%
from pairs import evaluate_pair_signals

daily_tr, trades_tr, summary_tr = evaluate_pair_signals(
    df_pair, signals,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== In-Sample Performance (2020-01-02 → 2025-12-31) ===")
print(pd.Series(summary_tr).to_string())
# Out:
# === In-Sample Performance (2020-01-02 → 2025-12-31) ===
# start                       2020-01-02 00:00:00
# end                         2025-12-31 00:00:00
# bars                                       1508
# capital_base                        10004.60448
# gross_pnl                           1992.901453
# net_pnl                             1794.505533
# ann_return                              0.02869
# sharpe                                 0.515717
# max_drawdown                         872.099587
# max_drawdown_pct                       0.084032
# avg_gross_exposure                  1698.151802
# avg_exposure_utilization               0.999857
# turnover_annualized                   28.824608
# n_trades                                     85
# hit_rate                                    0.6
# avg_win                               96.568933
# avg_loss                             -92.073825
# profit_factor                          1.573231
# avg_hold_bars                          3.011765
# med_hold_bars                               2.0
# ann_vol                                0.058121
# sortino                                0.805237
# gross_return_chain                     1.208153
# net_return_chain                       1.184438
# avg_daily_dollars_traded            1144.360333
# impact_cost_total                           0.0

# %%
# Equity curve with drawdown shading
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(13, 7), sharex=True,
                                gridspec_kw={"height_ratios": [3, 1]})

ax1.plot(daily_tr.index, daily_tr["equity"], color="steelblue", lw=1.5, label="Equity")
ax1.fill_between(daily_tr.index, daily_tr["equity"],
                 daily_tr["equity"] + daily_tr["drawdown"],   # drawdown is negative
                 alpha=0.25, color="red", label="Drawdown")
ax1.set_ylabel("Equity ($)"); ax1.set_title(f"In-Sample Equity Curve — {ticker1}/{ticker2}")
ax1.legend()

ax2.fill_between(daily_tr.index, daily_tr["drawdown_pct"] * 100, 0,
                 alpha=0.6, color="red")
ax2.set_ylabel("Drawdown (%)"); ax2.set_xlabel("Date")
plt.tight_layout(); plt.show()

# %% [markdown]
# # 4b. Out-of-Sample Evaluation (2026-01-01 → 2026-06-25)
#
# ## 4b.1 Download OOS price data

# %%
start_test = "2026-01-01"
end_test   = "2026-06-25"

_oos_cache = CACHE / f"nb03_oos_{ticker1}_{ticker2}_{start_test}_{end_test}.parquet"
if _oos_cache.exists():
    df_test, failed = pd.read_parquet(_oos_cache), []
else:
    df_test, failed = load_prices('openbb', [ticker1, ticker2], start_test, end_test, return_failed=True)
    df_test.to_parquet(_oos_cache)
print(f"OOS data: {len(df_test):,} rows, {df_test.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# OOS data: 240 rows, 2 tickers

# %% [markdown]
# ## 4b.2 Continue Kalman filter on OOS window (no look-ahead)
#
# We freeze the parameters $(F, Q, R)$ learned during training and **continue filtering**
# from the last train state.  The smoother is NOT used on OOS data — only the causal filter.
#
# The OOS z-score uses a look-back chosen from — and warmed up on — the causal *training-window* residual under the same frozen parameters, so the OOS window never informs its own z-score.

# %%
from pairs import filter_kf_on_new

pair = (ticker1, ticker2)
frozen = {k: params_tr[pair][k] for k in ("F", "Q", "R")}
last_state = (params_tr[pair]["last_state_mean"], params_tr[pair]["last_state_cov"])

P1_new = df_test.loc[(ticker1,), 'close']
P2_new = df_test.loc[(ticker2,), 'close']

states_te, _ = filter_kf_on_new(
    P1_new, P2_new,
    frozen=frozen,
    last_state=last_state,
    init_cov=1e6,
    mode="filter",
)

prices_te = df_test.pivot_table(
    index=df_test.index.get_level_values("datetime"),
    columns=df_test.index.get_level_values("ticker"),
    values="close",
)
df_pair_te = states_te.join(
    prices_te[[ticker1, ticker2]].rename(columns={ticker1: "P1", ticker2: "P2"}),
    how="inner",
)
print(f"OOS pair frame: {df_pair_te.index[0].date()} → {df_pair_te.index[-1].date()}, "
      f"{len(df_pair_te):,} bars")
# Out:
# OOS pair frame: 2026-01-02 → 2026-06-25, 120 bars

# %%
# z-score look-back and warm-up history from the causal TRAINING residual under the frozen
# parameters — the OOS window never informs its own z-score (no in-window look-ahead).
states_hist, _ = filter_kf_on_new(
    df_pair["P1"], df_pair["P2"],
    frozen=frozen, last_state=None, init_cov=1e6, mode="filter",
)
z_window_tr = estimate_halflife_window(states_hist["resid"])
print(f"z-score window from training residual: {z_window_tr} bars")

signals_te = generate_pair_signals(
    df_pair_te,
    z_method="robust",
    z_window=z_window_tr, z_history=states_hist["resid"],
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
)
daily_te, trades_te, summary_te = evaluate_pair_signals(
    df_pair_te[["P1", "P2"]], signals_te,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===")
print(pd.Series(summary_te).to_string())
# Out:
# z-score window from training residual: 30 bars
# === Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===
# start                       2026-01-02 00:00:00
# end                         2026-06-25 00:00:00
# bars                                        120
# capital_base                        9989.325853
# gross_pnl                            692.138223
# net_pnl                              664.302195
# ann_return                              0.14823
# sharpe                                  2.64203
# max_drawdown                         243.954955
# max_drawdown_pct                        0.02313
# avg_gross_exposure                  2249.102743
# avg_exposure_utilization               1.000669
# turnover_annualized                   52.771994
# n_trades                                     12
# hit_rate                                   0.75
# avg_win                               88.373177
# avg_loss                             -66.854738
# profit_factor                          3.965606
# avg_hold_bars                          2.166667
# med_hold_bars                               2.0
# ann_vol                                0.052858
# sortino                                5.014127
# gross_return_chain                     1.071009
# net_return_chain                       1.068034
# avg_daily_dollars_traded            2091.891429
# impact_cost_total                           0.0

# %% [markdown]
# ## 4b.3 Visualize OOS trades
#
# The same view as the in-sample plot (§4.3), now on the 2026 held-out window. Reading it next to §4.3 makes the shorter window concrete: 13 holding periods here against 85 across the five-year training span — though over only 120 bars, so the *rate* of trading is actually higher out of sample.

# %%
# Same plot as in-sample (§4.3), applied to the OOS pair frame & signals.
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair_te, signals_te,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4b.4 In-sample vs OOS comparison
#
# > ⚠️ **Caution**: The OOS window contains only **13 trades** over 120 bars. A hit rate of
# > 84.6% on 13 observations is statistically uninformative — the 95% binomial CI spans roughly
# > (55%, 98%). Note the direction: the OOS Sharpe (3.50) is *higher* than the in-sample figure
# > (0.52), which is not evidence that the strategy improved. The standard error of an annualized
# > Sharpe over 120 bars is about 1.4, so 3.50 is a high-variance draw, not a result.

# %%
comparison = pd.DataFrame({
    "In-sample (2020-2025)": pd.Series(summary_tr),
    "OOS (2026)":            pd.Series(summary_te),
}).loc[["sharpe", "ann_return", "max_drawdown_pct", "n_trades", "hit_rate", "profit_factor"]]
comparison.loc["ann_return"] = comparison.loc["ann_return"] * 100   # → %
comparison.index = ["Sharpe", "Ann. Return (%)", "Max Drawdown (%)", "Trades", "Hit Rate", "Profit Factor"]
print(comparison.to_string(float_format="{:.3f}".format))
# Out:
#                  In-sample (2020-2025) OOS (2026)
# Sharpe                           0.516      2.642
# Ann. Return (%)                  2.869     14.823
# Max Drawdown (%)                 0.084      0.023
# Trades                              85         12
# Hit Rate                         0.600      0.750
# Profit Factor                    1.573      3.966

# %% [markdown]
# # 8. Limitations and Honest Assessment
#
# ## 8.1 What the results cannot tell us
#
# The traded pair was chosen (§3.5) from a shortlist that itself survived a composite stationarity filter over a very large number of simultaneously-tested pairs. Read the performance with these caveats:
#
# - **Selection bias (identical to nb02, not amplified).** Dropping Benjamini-Hochberg marks far more pairs `pass`, but the candidate set is a rank cut on raw p-values that BH does not reorder, so this notebook's shortlist, selected pair and results match `pairs_trading_02_yahoo.ipynb` exactly (§0). The selection bias is real and is the same in both. To make the ablation bite, gate candidates on `verdict` before the rank cut.
# - **Low OOS trade count.** The OOS window produces only a handful of trades (13 for the selected BKNG/MA pair) — far below the ~50 needed for statistical power. A high hit rate on a few trades is uninformative.
# - **Single-window Sharpe is noise in both directions.** In-sample Sharpe is systematically optimistic, so the OOS figure is *usually* lower — but in this run it is higher (0.52 → 3.50) on 13 trades in half a year. Neither single window is informative: the fold distribution in §3.5 is.
# - **Optimistic cost model.** The in-sample/OOS evaluation uses a flat `cost_bps` with no market impact, fill/queue uncertainty, or borrow-availability variability.
# - **Single-pair analysis.** A live strategy trades a *portfolio* of pairs — introducing cross-pair residual correlation, portfolio-level drawdown management, and signal interaction effects not captured here.
#
# ## 8.2 What the evidence does support
#
# 1. A working end-to-end pipeline (data → cointegration → Kalman hedge → signals → evaluation) with **causal OOS continuation** (no look-ahead: the Kalman state is carried forward, and the z-score look-back and its warm-up come from training data, never from the window being scored).
# 2. **Honest pair selection**: the traded pair is chosen by walk-forward cross-fold stability (§3.5), not by in-sample ranking — and the held-out window is never used for selection.
# 3. **Multiple-testing _not_ corrected**: this variant omits BH FDR (the deliberate difference from nb02), so statistically spurious pairs that BH would remove stay in the candidate set.
# 4. **Honest degradation disclosure**: the OOS Sharpe is reported, not hidden, and the walk-forward distribution (§3.5.1) shows the spread across folds rather than one window.
#
# ## 8.3 Gap-to-production
#
# | Gap | Required mitigation |
# |-----|---------------------|
# | Selection bias | Strict hold-out from inception; **add BH FDR** (omitted here — see nb02) + walk-forward selection |
# | Low OOS N | Longer OOS window; portfolio of 10+ pairs |
# | No market impact | Square-root impact model + capacity analysis |
# | Single-regime OOS | Rolling re-estimation in live trading |
# | No portfolio risk mgmt | Residual-vol position sizing; cross-pair correlation |
# | Borrow / execution | Pre-borrow checks; limit-order fill model |
