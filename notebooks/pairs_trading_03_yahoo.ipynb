# %% [markdown]
# # Dynamic Hedge Pairs Trading — *without* Benjamini-Hochberg
# ## `pairs_trading_03_yahoo.ipynb`
#
# Identical pipeline to `pairs_trading_02_yahoo.ipynb` — cointegration screen → Kalman hedge → walk-forward pair selection → in-sample & out-of-sample backtests with performance metrics → limitations — with **one deliberate change: no Benjamini-Hochberg FDR correction** on the cointegration screen (`fdr_method="none"`, raw p-values).
#
# The intent is to isolate the effect of dropping multiple-testing control. **As currently wired, it does
# not:** this notebook reproduces `pairs_trading_02_yahoo.ipynb` exactly — same selected pair (BKNG/MA),
# same in-sample Sharpe (0.516), same OOS Sharpe (3.500), same 85 and 13 trades.
#
# The reason is worth more than the intended result. The screen's `verdict` column does change — without
# correction far more pairs are marked `pass` — but nothing downstream reads it. The candidate shortlist is
# a rank cut, `prelim.head(200)` over **all** screened pairs ranked on raw `eg_p` and `joh_stat` (§2.2), and
# Benjamini-Hochberg is a monotone transform of the sorted p-values, so it cannot change that ordering. The
# top 200 are identical either way.
#
# So the honest lesson of this ablation is structural: **FDR control only changes anything if some later
# step gates on it.** Here nothing does, in either notebook. Making the ablation bite would mean filtering
# candidates on `verdict` before the rank cut — a code change that would alter the traded pair, so it is
# left undone and recorded in §8.1.
#
# Re-run from top to bottom; self-contained.

# %% [markdown]
# ## 0. Environment setup

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent           # notebooks/ → repo root
sys.path.insert(0, str(repo_root))

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pairs
print("pairs version:", pairs.__version__)
print("pairs path   :", Path(pairs.__file__).relative_to(repo_root))
# Out:
# pairs version: 0.1.0
# pairs path   : pairs/__init__.py

# %%
# Install the package (editable) if running in a fresh environment
# %pip install -e "..[notebooks]"  # uncomment if needed

# %% [markdown]
# # 1. Data Loading & Quality Filtering
#
# We load daily OHLCV prices for the combined S&P 500 + NASDAQ-100 universe
# (~517 tickers) over the **training window 2020-01-01 → 2025-12-31**, then
# drop tickers whose coverage does not span the full period.

# %%
from pairs import load_universe, load_prices

tickers = load_universe("spx_ndx_combined")
print(f"Universe: {len(tickers)} tickers")
# Out:
# Universe: 517 tickers

# %%
# ── Load training prices ──────────────────────────────────────────────────────
start_date = "2020-01-01"
end_date   = "2025-12-31"

# Prices are cached on first run so the notebook is reproducible offline afterwards.
# This matters more than it looks: Yahoo re-bases its adjusted close after every
# corporate action, so a fresh download months later returns different *levels*
# for any name that has since split or spun off. Pinning the file freezes the basis.
CACHE = Path("cache"); CACHE.mkdir(exist_ok=True)
# the window is part of the key: change the dates and it re-downloads
_px_cache = CACHE / f"nb03_train_{start_date}_{end_date}.parquet"
if _px_cache.exists():
    df_train, failed = pd.read_parquet(_px_cache), []
else:
    df_train, failed = load_prices('openbb', tickers, start_date, end_date, return_failed=True)
    df_train.to_parquet(_px_cache)

print(f"Loaded {len(df_train):,} rows for {df_train.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# Loaded 753,000 rows for 505 tickers

# %%
# ── Quality filter: keep only full-coverage tickers ──────────────────────────
lvl_names      = list(df_train.index.names)
time_lvl_name  = 'datetime' if 'datetime' in lvl_names else lvl_names[1]

full_start = df_train.index.get_level_values(time_lvl_name).min()
full_end   = df_train.index.get_level_values(time_lvl_name).max()

starts = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).min())
ends   = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).max())

tickers_to_keep = starts[(starts == full_start) & (ends == full_end)].index
df_filtered     = df_train.loc[pd.IndexSlice[tickers_to_keep, :]]

n_orig    = df_train.index.get_level_values('ticker').nunique()
n_kept    = df_filtered.index.get_level_values('ticker').nunique()
dropped   = set(tickers) - set(tickers_to_keep)
print(f"Tickers: {n_orig} total → {n_kept} kept ({n_orig - n_kept} dropped for incomplete coverage)")
print(f"Dropped: {sorted(dropped)}")
# Out:
# Tickers: 505 total → 488 kept (17 dropped for incomplete coverage)
# Dropped: ['ABNB', 'APP', 'ARM', 'AVB', 'BK', 'CARR', 'CEG', 'COIN', 'CTRA', 'DASH', 'DAY', 'EA', 'EQR', 'EXE', 'FI', 'GEHC', 'GEV', 'GFS', 'HOLX', 'IPG', 'K', 'KVUE', 'MMC', 'OTIS', 'PARA', 'PLTR', 'SOLV', 'VLTO', 'WBA']

# %% [markdown]
# # 2. Cointegration Screening
#
# ## 2.1 Dual-gate screening (Engle-Granger + Johansen)
#
# We test all $\binom{n}{2}$ pairs simultaneously using two cointegration tests.
# A pair advances only if **both** tests reject the null of no cointegration.

# %%
from pairs import find_cointegrated_pairs_dualgate

# fdr_method="none" — NO Benjamini-Hochberg correction (raw EG p-value gate).
summary_dual = find_cointegrated_pairs_dualgate(
    df_filtered,
    alpha_eg=0.05, eg_trend="c",
    alpha_joh=0.05, joh_det_order=0, joh_k_ar_diff=1, joh_stat="trace",
    fdr_method="none",      # ← raw p-values, no multiple-testing correction
    n_workers=16, chunksize=8, show_progress=True,
)
print(f"\nTotal pairs screened : {len(summary_dual):,}")
print(f"Dual-gate pass (verdict=='pass'): {(summary_dual['verdict']=='pass').sum()}")
summary_dual.head(5)[["eg_t", "eg_p", "eg_pass", "joh_stat", "joh_pass", "verdict"]]
# Out:
# Dual-gate cointegration (EG + Johansen):   0%|          | 0/118828 [00:00<?, ?it/s]
# Dual-gate cointegration (EG + Johansen):   1%|          | 1081/118828 [00:00<00:24, 4727.86it/s]
# Dual-gate cointegration (EG + Johansen):   1%|▏         | 1554/118828 [00:00<01:23, 1396.20it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 1788/118828 [00:01<01:44, 1123.59it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 1945/118828 [00:01<01:59, 981.54it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2064/118828 [00:01<02:12, 882.33it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2161/118828 [00:01<02:26, 797.97it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2243/118828 [00:02<02:36, 744.74it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2337/118828 [00:02<02:30, 772.79it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2416/118828 [00:02<02:45, 704.10it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2487/118828 [00:02<02:57, 656.94it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2585/118828 [00:02<02:49, 683.83it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2654/118828 [00:02<03:13, 600.36it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2737/118828 [00:02<03:19, 581.94it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2833/118828 [00:03<02:58, 650.79it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2901/118828 [00:03<03:08, 613.72it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 2993/118828 [00:03<03:28, 554.42it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3113/118828 [00:03<02:59, 644.54it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3180/118828 [00:03<03:04, 627.30it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3249/118828 [00:03<03:16, 588.39it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3313/118828 [00:03<03:12, 599.16it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3377/118828 [00:04<03:30, 549.73it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3481/118828 [00:04<02:54, 661.31it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3550/118828 [00:04<03:07, 615.11it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3625/118828 [00:04<03:03, 628.51it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3690/118828 [00:04<03:08, 611.56it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3753/118828 [00:04<03:12, 596.30it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3814/118828 [00:04<03:23, 566.14it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3872/118828 [00:04<03:23, 564.03it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3929/118828 [00:04<03:29, 549.34it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4017/118828 [00:05<03:13, 594.26it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4089/118828 [00:05<03:06, 615.16it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4151/118828 [00:05<03:07, 613.11it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4213/118828 [00:05<03:07, 612.51it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4275/118828 [00:05<03:26, 555.04it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4361/118828 [00:05<03:09, 605.57it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4425/118828 [00:05<03:29, 545.25it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4505/118828 [00:05<03:10, 601.07it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4567/118828 [00:06<03:13, 591.01it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4641/118828 [00:06<03:02, 626.21it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4705/118828 [00:06<04:09, 457.04it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4833/118828 [00:06<02:58, 638.68it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4909/118828 [00:06<03:05, 613.96it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4979/118828 [00:06<03:07, 605.96it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5049/118828 [00:06<03:04, 616.59it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5121/118828 [00:06<02:58, 637.11it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5188/118828 [00:07<03:26, 549.15it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5273/118828 [00:07<03:08, 601.32it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5337/118828 [00:07<03:18, 572.90it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5441/118828 [00:07<03:08, 601.53it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5503/118828 [00:07<03:07, 603.93it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5577/118828 [00:07<03:15, 579.69it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5673/118828 [00:07<02:50, 663.08it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5742/118828 [00:08<03:24, 553.80it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5833/118828 [00:08<03:02, 618.65it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5899/118828 [00:08<03:07, 601.01it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 5962/118828 [00:08<03:05, 608.26it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6025/118828 [00:08<03:19, 566.72it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6097/118828 [00:08<03:27, 544.10it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6193/118828 [00:08<03:00, 624.74it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6258/118828 [00:08<03:12, 583.96it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6337/118828 [00:08<02:57, 635.27it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6403/118828 [00:09<03:09, 594.06it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6473/118828 [00:09<03:23, 552.40it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6537/118828 [00:09<03:22, 555.79it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6601/118828 [00:09<03:16, 571.09it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6673/118828 [00:09<03:15, 574.98it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6737/118828 [00:09<03:31, 530.34it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6833/118828 [00:09<03:12, 580.48it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6897/118828 [00:09<03:13, 578.13it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6977/118828 [00:10<03:05, 602.36it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7065/118828 [00:10<02:56, 633.00it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7137/118828 [00:10<02:53, 642.65it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7202/118828 [00:10<02:53, 644.44it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7273/118828 [00:10<02:52, 648.56it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7338/118828 [00:10<03:17, 563.47it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7417/118828 [00:10<03:00, 617.33it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7481/118828 [00:10<03:08, 590.09it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7553/118828 [00:11<03:09, 586.55it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7617/118828 [00:11<03:07, 592.22it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7697/118828 [00:11<02:58, 620.99it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7760/118828 [00:11<03:18, 558.27it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7833/118828 [00:11<03:35, 515.45it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7905/118828 [00:11<03:23, 544.72it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7961/118828 [00:11<03:25, 538.69it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8033/118828 [00:11<03:09, 583.67it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8105/118828 [00:12<03:02, 605.19it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8167/118828 [00:12<03:11, 577.52it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8241/118828 [00:12<03:06, 593.20it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8301/118828 [00:12<03:14, 566.82it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8377/118828 [00:12<03:00, 610.32it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8439/118828 [00:12<03:28, 530.07it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8521/118828 [00:12<03:11, 575.76it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8593/118828 [00:12<03:09, 581.12it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8657/118828 [00:13<03:24, 538.83it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8713/118828 [00:13<03:27, 530.27it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8801/118828 [00:13<03:12, 571.50it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8881/118828 [00:13<03:03, 598.42it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 8942/118828 [00:13<03:12, 571.67it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9049/118828 [00:13<02:43, 670.52it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9117/118828 [00:13<03:08, 580.79it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9185/118828 [00:13<03:19, 550.74it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9273/118828 [00:14<02:58, 614.33it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9337/118828 [00:14<02:59, 610.04it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9433/118828 [00:14<02:51, 637.30it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9498/118828 [00:14<03:06, 585.76it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9569/118828 [00:14<03:24, 535.00it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9665/118828 [00:14<02:53, 627.48it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9737/118828 [00:14<03:05, 586.62it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9817/118828 [00:14<02:54, 625.16it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9882/118828 [00:15<03:10, 572.57it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9953/118828 [00:15<03:06, 583.13it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 10041/118828 [00:15<02:48, 645.82it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10108/118828 [00:15<02:57, 611.43it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10177/118828 [00:15<02:52, 631.45it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10242/118828 [00:15<03:18, 547.16it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10329/118828 [00:15<02:59, 603.59it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10392/118828 [00:15<03:00, 600.39it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10457/118828 [00:16<03:09, 570.62it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10529/118828 [00:16<03:02, 594.10it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10590/118828 [00:16<03:03, 589.03it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10657/118828 [00:16<03:03, 588.56it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10717/118828 [00:16<03:07, 575.19it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10817/118828 [00:16<02:49, 636.05it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10881/118828 [00:16<03:01, 594.06it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10953/118828 [00:16<02:54, 617.76it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11015/118828 [00:16<02:59, 599.71it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11076/118828 [00:17<02:59, 601.27it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11137/118828 [00:17<03:16, 547.28it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11217/118828 [00:17<02:55, 614.21it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11280/118828 [00:17<02:59, 599.36it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11353/118828 [00:17<02:49, 634.04it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11418/118828 [00:17<03:12, 558.82it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11513/118828 [00:17<03:02, 589.54it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11593/118828 [00:17<02:54, 613.09it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11657/118828 [00:18<03:24, 524.00it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11745/118828 [00:18<02:56, 607.20it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11817/118828 [00:18<02:53, 616.06it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 11889/118828 [00:18<02:55, 610.51it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 11953/118828 [00:18<02:55, 608.08it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12017/118828 [00:18<02:53, 614.26it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12081/118828 [00:18<03:05, 575.80it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12153/118828 [00:18<02:55, 608.61it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12215/118828 [00:18<03:02, 584.18it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12289/118828 [00:19<03:01, 585.82it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12349/118828 [00:19<03:08, 563.79it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12425/118828 [00:19<02:55, 606.35it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12505/118828 [00:19<02:42, 654.25it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12572/118828 [00:19<02:48, 629.49it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12641/118828 [00:19<02:44, 645.68it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12707/118828 [00:19<02:58, 595.55it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12785/118828 [00:19<02:58, 594.20it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12846/118828 [00:20<02:59, 591.04it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12906/118828 [00:20<03:04, 572.81it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12964/118828 [00:20<03:11, 552.34it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13033/118828 [00:20<02:59, 589.58it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13105/118828 [00:20<03:00, 584.98it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13169/118828 [00:20<03:00, 584.98it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13257/118828 [00:20<02:39, 660.86it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13324/118828 [00:20<03:26, 511.52it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13409/118828 [00:20<02:58, 589.80it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13474/118828 [00:21<03:01, 580.62it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13545/118828 [00:21<02:58, 589.78it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13633/118828 [00:21<02:51, 613.95it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13697/118828 [00:21<03:08, 558.07it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13793/118828 [00:21<02:40, 652.45it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13862/118828 [00:21<03:06, 562.78it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13929/118828 [00:21<03:33, 491.31it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14057/118828 [00:22<02:49, 618.74it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14137/118828 [00:22<02:46, 627.77it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14203/118828 [00:22<03:06, 560.32it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14289/118828 [00:22<02:49, 618.14it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14354/118828 [00:22<02:49, 617.77it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14425/118828 [00:22<02:52, 604.54it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14487/118828 [00:22<02:52, 604.79it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14553/118828 [00:22<02:49, 615.17it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14625/118828 [00:23<02:44, 632.04it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14689/118828 [00:23<03:08, 552.00it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14777/118828 [00:23<02:52, 604.71it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14841/118828 [00:23<03:06, 556.83it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 14935/118828 [00:23<02:39, 652.98it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15004/118828 [00:23<02:53, 599.89it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15067/118828 [00:23<03:02, 569.46it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15137/118828 [00:23<03:05, 560.00it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15209/118828 [00:24<02:57, 582.63it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15305/118828 [00:24<02:42, 636.56it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15370/118828 [00:24<02:43, 631.05it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15434/118828 [00:24<02:51, 602.62it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15495/118828 [00:24<02:59, 575.10it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15577/118828 [00:24<02:50, 606.93it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15649/118828 [00:24<02:48, 611.44it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15711/118828 [00:24<02:56, 582.85it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15801/118828 [00:24<02:41, 639.69it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15866/118828 [00:25<02:56, 581.84it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15937/118828 [00:25<02:50, 604.56it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15999/118828 [00:25<02:56, 583.30it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16065/118828 [00:25<03:01, 566.40it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16137/118828 [00:25<03:00, 570.18it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16217/118828 [00:25<02:50, 603.30it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16313/118828 [00:25<02:28, 688.22it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16383/118828 [00:25<02:46, 616.08it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16457/118828 [00:26<02:43, 627.16it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16522/118828 [00:26<02:59, 569.23it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16601/118828 [00:26<02:56, 579.87it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16681/118828 [00:26<02:46, 614.39it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16744/118828 [00:26<02:49, 600.76it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16825/118828 [00:26<02:46, 610.83it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16887/118828 [00:26<02:49, 600.86it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16953/118828 [00:26<02:46, 612.14it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17015/118828 [00:27<02:51, 592.75it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17075/118828 [00:27<02:53, 587.96it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17134/118828 [00:27<03:19, 508.52it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17233/118828 [00:27<02:49, 601.14it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17295/118828 [00:27<02:50, 596.28it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17356/118828 [00:27<03:07, 542.11it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17449/118828 [00:27<02:45, 613.26it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17512/118828 [00:27<03:06, 544.66it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17601/118828 [00:28<03:00, 561.91it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17689/118828 [00:28<02:43, 619.42it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17753/118828 [00:28<02:48, 598.71it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17849/118828 [00:28<02:33, 659.28it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17916/118828 [00:28<03:05, 545.42it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17993/118828 [00:28<02:52, 585.90it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18057/118828 [00:28<02:48, 598.12it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18121/118828 [00:28<02:47, 601.94it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18185/118828 [00:29<02:52, 584.46it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18273/118828 [00:29<02:37, 639.30it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18338/118828 [00:29<02:37, 640.02it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18403/118828 [00:29<02:36, 640.87it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18468/118828 [00:29<02:48, 594.41it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18537/118828 [00:29<02:41, 620.27it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18600/118828 [00:29<02:56, 568.76it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18673/118828 [00:29<02:46, 600.67it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18735/118828 [00:29<02:55, 571.34it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18825/118828 [00:30<02:34, 645.27it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18891/118828 [00:30<03:00, 552.46it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18949/118828 [00:30<03:24, 487.88it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19057/118828 [00:30<02:42, 613.36it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19129/118828 [00:30<02:38, 630.43it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19196/118828 [00:30<02:37, 631.44it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19262/118828 [00:30<02:40, 620.81it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19326/118828 [00:30<02:44, 603.43it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19393/118828 [00:31<02:41, 615.87it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19456/118828 [00:31<02:41, 616.12it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19519/118828 [00:31<02:53, 572.27it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19585/118828 [00:31<02:53, 570.81it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19649/118828 [00:31<02:50, 581.14it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19713/118828 [00:31<02:54, 569.32it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19771/118828 [00:31<02:58, 554.42it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19833/118828 [00:31<02:56, 561.62it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19913/118828 [00:31<02:43, 603.68it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19974/118828 [00:32<03:02, 540.33it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20030/118828 [00:32<03:02, 541.80it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20105/118828 [00:32<02:52, 570.71it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20163/118828 [00:32<03:10, 516.84it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20265/118828 [00:32<02:47, 587.02it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20353/118828 [00:32<02:29, 656.71it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20421/118828 [00:32<02:39, 616.96it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20497/118828 [00:32<02:36, 627.03it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20561/118828 [00:33<02:38, 619.14it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20633/118828 [00:33<02:33, 638.94it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20698/118828 [00:33<03:05, 527.66it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20769/118828 [00:33<03:03, 533.15it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20857/118828 [00:33<02:39, 613.05it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20922/118828 [00:33<02:44, 596.49it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20984/118828 [00:33<02:50, 575.48it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21043/118828 [00:33<02:50, 574.28it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21129/118828 [00:33<02:38, 614.97it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21192/118828 [00:34<02:47, 582.47it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21265/118828 [00:34<02:49, 575.67it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21337/118828 [00:34<02:39, 612.26it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21401/118828 [00:34<02:39, 610.12it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21473/118828 [00:34<02:43, 595.29it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21545/118828 [00:34<02:37, 619.32it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21608/118828 [00:34<02:43, 594.81it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21673/118828 [00:34<02:40, 603.86it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21737/118828 [00:35<02:43, 595.22it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21809/118828 [00:35<02:44, 591.50it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21869/118828 [00:35<02:46, 581.46it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21929/118828 [00:35<02:47, 578.47it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 21993/118828 [00:35<02:47, 577.48it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22057/118828 [00:35<02:52, 562.06it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22121/118828 [00:35<02:46, 580.77it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22193/118828 [00:35<02:39, 604.92it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22257/118828 [00:35<02:42, 592.94it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22345/118828 [00:36<02:32, 632.71it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22409/118828 [00:36<02:34, 623.41it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22473/118828 [00:36<02:36, 615.63it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22537/118828 [00:36<02:38, 606.91it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22601/118828 [00:36<02:52, 558.80it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22681/118828 [00:36<02:51, 561.97it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22769/118828 [00:36<02:32, 629.06it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22833/118828 [00:36<02:40, 597.18it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22894/118828 [00:36<02:42, 591.28it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22954/118828 [00:37<02:54, 549.35it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23025/118828 [00:37<02:48, 567.09it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23121/118828 [00:37<02:38, 604.64it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23193/118828 [00:37<02:40, 597.65it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23273/118828 [00:37<02:31, 630.29it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23337/118828 [00:37<02:47, 569.10it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23418/118828 [00:37<02:31, 629.62it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23483/118828 [00:37<02:50, 559.89it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23553/118828 [00:38<02:41, 590.74it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23617/118828 [00:38<02:47, 569.59it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23689/118828 [00:38<02:36, 608.74it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23752/118828 [00:38<02:38, 599.76it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23814/118828 [00:38<02:37, 603.56it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23876/118828 [00:38<03:08, 504.93it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23969/118828 [00:38<02:51, 553.17it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24057/118828 [00:38<02:31, 625.82it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24123/118828 [00:39<02:53, 547.37it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24217/118828 [00:39<02:32, 619.35it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24283/118828 [00:39<02:40, 590.07it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24345/118828 [00:39<02:38, 597.05it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24407/118828 [00:39<02:37, 599.44it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24473/118828 [00:39<02:33, 614.95it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24536/118828 [00:39<02:42, 579.70it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24609/118828 [00:39<02:54, 540.91it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24681/118828 [00:40<02:54, 538.54it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24745/118828 [00:40<02:47, 562.44it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24809/118828 [00:40<02:52, 545.21it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24881/118828 [00:40<02:40, 585.46it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24941/118828 [00:40<02:40, 585.79it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25001/118828 [00:40<02:41, 579.46it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25065/118828 [00:40<02:46, 564.23it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25137/118828 [00:40<02:35, 602.15it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25198/118828 [00:40<02:42, 575.53it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25281/118828 [00:41<02:34, 606.98it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25342/118828 [00:41<02:37, 592.37it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25409/118828 [00:41<02:40, 580.54it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25468/118828 [00:41<02:40, 579.93it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25537/118828 [00:41<02:41, 577.10it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25595/118828 [00:41<02:53, 536.27it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25681/118828 [00:41<02:39, 585.22it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25740/118828 [00:41<02:46, 560.07it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25809/118828 [00:42<02:49, 548.05it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25864/118828 [00:42<02:51, 543.60it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25945/118828 [00:42<02:38, 586.64it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26004/118828 [00:42<02:42, 570.83it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26073/118828 [00:42<02:38, 586.09it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26132/118828 [00:42<02:38, 583.36it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26193/118828 [00:42<02:37, 589.92it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26253/118828 [00:42<02:46, 556.72it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26321/118828 [00:42<02:48, 547.65it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26409/118828 [00:43<02:25, 635.85it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26474/118828 [00:43<02:44, 561.75it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26553/118828 [00:43<02:28, 620.41it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26618/118828 [00:43<02:47, 549.34it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26697/118828 [00:43<02:36, 588.99it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26761/118828 [00:43<02:36, 586.78it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26825/118828 [00:43<02:39, 578.61it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26884/118828 [00:43<02:40, 572.90it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26945/118828 [00:43<02:45, 555.12it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27025/118828 [00:44<02:47, 546.97it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27097/118828 [00:44<02:40, 570.18it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27155/118828 [00:44<02:41, 566.95it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27225/118828 [00:44<02:46, 548.56it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27321/118828 [00:44<02:23, 637.57it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27386/118828 [00:44<02:46, 549.58it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27473/118828 [00:44<02:28, 616.53it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27538/118828 [00:45<02:41, 564.13it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27609/118828 [00:45<02:32, 598.24it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27672/118828 [00:45<02:51, 530.81it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27745/118828 [00:45<02:41, 563.09it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27809/118828 [00:45<02:43, 556.56it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27881/118828 [00:45<02:35, 585.47it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 27953/118828 [00:45<02:36, 578.96it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28033/118828 [00:45<02:24, 628.66it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28098/118828 [00:45<02:39, 567.26it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28169/118828 [00:46<02:39, 567.03it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28227/118828 [00:46<02:40, 565.89it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28297/118828 [00:46<02:38, 570.09it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28369/118828 [00:46<02:37, 575.25it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28433/118828 [00:46<02:40, 563.96it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28497/118828 [00:46<02:43, 554.12it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28561/118828 [00:46<02:46, 543.44it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28617/118828 [00:46<02:44, 546.96it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28705/118828 [00:47<02:29, 603.66it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28769/118828 [00:47<02:30, 599.52it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28833/118828 [00:47<02:30, 599.48it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28893/118828 [00:47<02:32, 588.91it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28953/118828 [00:47<02:39, 564.26it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29025/118828 [00:47<02:40, 557.89it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29097/118828 [00:47<02:34, 581.20it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29161/118828 [00:47<02:50, 527.12it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29257/118828 [00:47<02:28, 603.58it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29319/118828 [00:48<02:35, 576.04it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29385/118828 [00:48<02:31, 591.37it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29445/118828 [00:48<02:41, 555.11it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29521/118828 [00:48<02:37, 568.79it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29579/118828 [00:48<02:45, 539.28it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29657/118828 [00:48<02:30, 591.29it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29717/118828 [00:48<02:40, 555.21it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29777/118828 [00:48<02:45, 537.26it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29857/118828 [00:49<02:42, 548.93it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29929/118828 [00:49<02:54, 509.51it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30041/118828 [00:49<02:23, 617.33it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30105/118828 [00:49<02:25, 611.05it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30177/118828 [00:49<02:30, 589.45it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30237/118828 [00:49<02:31, 585.28it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30313/118828 [00:49<02:33, 577.32it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30372/118828 [00:49<02:42, 544.77it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30441/118828 [00:50<02:38, 558.92it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30521/118828 [00:50<02:23, 614.83it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30584/118828 [00:50<02:37, 560.43it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30673/118828 [00:50<02:27, 596.41it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30734/118828 [00:50<02:49, 520.01it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30817/118828 [00:50<02:33, 574.77it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30877/118828 [00:50<02:32, 577.39it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30953/118828 [00:51<02:52, 509.77it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31073/118828 [00:51<02:15, 649.50it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31143/118828 [00:51<02:33, 569.53it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31209/118828 [00:51<02:39, 550.52it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31289/118828 [00:51<02:26, 596.88it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31352/118828 [00:51<02:33, 568.28it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31449/118828 [00:51<02:27, 591.75it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31510/118828 [00:51<02:41, 540.11it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31593/118828 [00:52<02:37, 553.32it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31657/118828 [00:52<02:34, 563.31it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31721/118828 [00:52<02:37, 554.38it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31809/118828 [00:52<02:19, 624.59it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31873/118828 [00:52<02:38, 548.22it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31953/118828 [00:52<02:23, 606.86it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32017/118828 [00:52<02:34, 561.73it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32105/118828 [00:52<02:31, 572.64it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32177/118828 [00:53<02:30, 576.26it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32241/118828 [00:53<02:26, 589.85it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32305/118828 [00:53<02:30, 576.44it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32377/118828 [00:53<02:31, 571.14it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32457/118828 [00:53<02:17, 626.63it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32521/118828 [00:53<02:45, 522.33it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32609/118828 [00:53<02:22, 604.42it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32674/118828 [00:53<02:31, 569.91it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32753/118828 [00:54<02:23, 600.07it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32816/118828 [00:54<02:26, 587.15it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32877/118828 [00:54<02:27, 583.03it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32937/118828 [00:54<02:35, 553.11it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33001/118828 [00:54<02:34, 555.47it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33058/118828 [00:54<02:40, 532.94it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33137/118828 [00:54<02:25, 588.43it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33197/118828 [00:54<02:29, 571.91it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33265/118828 [00:55<02:28, 574.70it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33323/118828 [00:55<02:33, 557.27it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33393/118828 [00:55<02:27, 580.19it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33457/118828 [00:55<02:23, 596.48it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33517/118828 [00:55<02:26, 583.90it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33576/118828 [00:55<02:31, 563.95it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33641/118828 [00:55<02:42, 524.66it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33721/118828 [00:55<02:25, 584.81it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33785/118828 [00:55<02:25, 584.84it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33849/118828 [00:56<02:30, 563.12it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33913/118828 [00:56<02:27, 574.95it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33985/118828 [00:56<02:19, 609.52it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34047/118828 [00:56<02:26, 577.46it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34106/118828 [00:56<02:29, 568.54it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34169/118828 [00:56<02:41, 523.39it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34257/118828 [00:56<02:23, 590.34it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34321/118828 [00:56<02:31, 558.11it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34393/118828 [00:56<02:21, 598.23it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34454/118828 [00:57<02:30, 559.57it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34529/118828 [00:57<02:25, 578.81it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34588/118828 [00:57<02:26, 575.02it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34657/118828 [00:57<02:26, 576.36it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34715/118828 [00:57<02:32, 552.62it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34793/118828 [00:57<02:29, 563.26it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34857/118828 [00:57<02:35, 540.14it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34945/118828 [00:57<02:22, 586.95it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 35009/118828 [00:58<02:22, 586.66it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35068/118828 [00:58<02:26, 570.85it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35126/118828 [00:58<02:28, 564.87it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35183/118828 [00:58<02:33, 544.01it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35238/118828 [00:58<02:40, 519.63it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35313/118828 [00:58<02:31, 552.18it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35385/118828 [00:58<02:21, 588.24it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35445/118828 [00:58<02:25, 574.84it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35521/118828 [00:58<02:25, 572.29it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35579/118828 [00:59<02:30, 553.72it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35649/118828 [00:59<02:25, 572.64it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35707/118828 [00:59<02:27, 563.17it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35785/118828 [00:59<02:34, 538.52it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35865/118828 [00:59<02:20, 591.02it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35929/118828 [00:59<02:27, 561.36it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36001/118828 [00:59<02:31, 546.18it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36073/118828 [00:59<02:20, 587.81it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36145/118828 [01:00<02:21, 582.90it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36209/118828 [01:00<02:42, 507.34it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36313/118828 [01:00<02:13, 618.77it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36379/118828 [01:00<02:23, 573.61it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36449/118828 [01:00<02:21, 581.97it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36510/118828 [01:00<02:23, 575.15it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36577/118828 [01:00<02:30, 547.96it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36665/118828 [01:00<02:22, 577.23it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36724/118828 [01:01<02:27, 555.38it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36809/118828 [01:01<02:11, 623.66it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36873/118828 [01:01<02:34, 531.85it/s]
# Dual-gate cointegration (EG + Johansen):  31%|███       | 36953/118828 [01:01<02:19, 587.72it/s]
# ...
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108316/118828 [03:12<00:18, 562.21it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108385/118828 [03:12<00:19, 546.43it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108441/118828 [03:12<00:19, 522.24it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108545/118828 [03:12<00:18, 544.93it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108633/118828 [03:13<00:16, 611.75it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108696/118828 [03:13<00:18, 549.24it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108777/118828 [03:13<00:16, 601.08it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108839/118828 [03:13<00:17, 564.13it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108905/118828 [03:13<00:17, 575.06it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108964/118828 [03:13<00:17, 566.09it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109033/118828 [03:13<00:16, 581.07it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109092/118828 [03:13<00:18, 540.59it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109169/118828 [03:13<00:16, 586.01it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109229/118828 [03:14<00:17, 552.38it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109297/118828 [03:14<00:16, 574.19it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109356/118828 [03:14<00:17, 555.96it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109413/118828 [03:14<00:16, 553.94it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109469/118828 [03:14<00:17, 549.01it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109529/118828 [03:14<00:16, 562.07it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109586/118828 [03:14<00:17, 521.91it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109657/118828 [03:14<00:16, 567.51it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109715/118828 [03:15<00:17, 518.31it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109793/118828 [03:15<00:16, 533.52it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109881/118828 [03:15<00:14, 613.10it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 109944/118828 [03:15<00:15, 585.17it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110004/118828 [03:15<00:15, 563.53it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110062/118828 [03:15<00:15, 565.17it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110120/118828 [03:15<00:15, 554.19it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110177/118828 [03:15<00:15, 556.49it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110241/118828 [03:15<00:15, 561.13it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110313/118828 [03:16<00:14, 574.60it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110377/118828 [03:16<00:14, 568.92it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110441/118828 [03:16<00:14, 570.96it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110505/118828 [03:16<00:14, 573.87it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110563/118828 [03:16<00:15, 546.01it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110633/118828 [03:16<00:14, 572.44it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110691/118828 [03:16<00:15, 528.36it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110761/118828 [03:16<00:14, 558.02it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110818/118828 [03:16<00:14, 548.73it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110889/118828 [03:17<00:13, 568.78it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110947/118828 [03:17<00:14, 540.71it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111033/118828 [03:17<00:13, 596.45it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111093/118828 [03:17<00:14, 537.63it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111169/118828 [03:17<00:13, 588.71it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111230/118828 [03:17<00:13, 557.23it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111297/118828 [03:17<00:13, 572.62it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111361/118828 [03:17<00:12, 588.82it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111421/118828 [03:18<00:13, 544.59it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111477/118828 [03:18<00:13, 535.05it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111545/118828 [03:18<00:13, 553.14it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111601/118828 [03:18<00:13, 547.17it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111673/118828 [03:18<00:12, 560.54it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111730/118828 [03:18<00:12, 554.30it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111801/118828 [03:18<00:13, 538.64it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111865/118828 [03:18<00:13, 524.08it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111937/118828 [03:18<00:12, 570.43it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112001/118828 [03:19<00:11, 569.91it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112073/118828 [03:19<00:11, 597.42it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112137/118828 [03:19<00:11, 587.87it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112197/118828 [03:19<00:11, 571.47it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112257/118828 [03:19<00:11, 564.74it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112321/118828 [03:19<00:11, 546.82it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112409/118828 [03:19<00:10, 628.51it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112473/118828 [03:19<00:12, 512.00it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112569/118828 [03:20<00:11, 567.38it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112641/118828 [03:20<00:11, 552.67it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112705/118828 [03:20<00:11, 534.69it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112777/118828 [03:20<00:10, 578.08it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112837/118828 [03:20<00:10, 565.51it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112905/118828 [03:20<00:10, 591.87it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112966/118828 [03:20<00:10, 565.03it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113033/118828 [03:20<00:09, 580.35it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113092/118828 [03:20<00:10, 570.35it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113161/118828 [03:21<00:09, 586.35it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113225/118828 [03:21<00:09, 569.66it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113297/118828 [03:21<00:09, 578.36it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113361/118828 [03:21<00:10, 542.87it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113441/118828 [03:21<00:08, 599.94it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113502/118828 [03:21<00:09, 573.65it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113561/118828 [03:21<00:09, 546.05it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113625/118828 [03:21<00:09, 553.26it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113689/118828 [03:22<00:09, 564.92it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113753/118828 [03:22<00:09, 526.01it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113841/118828 [03:22<00:08, 583.85it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113900/118828 [03:22<00:08, 567.66it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113969/118828 [03:22<00:09, 530.91it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114049/118828 [03:22<00:08, 585.36it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114109/118828 [03:22<00:08, 558.62it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114185/118828 [03:22<00:08, 568.36it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114243/118828 [03:23<00:08, 571.14it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114313/118828 [03:23<00:07, 580.01it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114372/118828 [03:23<00:07, 566.43it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114433/118828 [03:23<00:07, 574.26it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114491/118828 [03:23<00:08, 533.56it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114561/118828 [03:23<00:07, 574.51it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114620/118828 [03:23<00:07, 541.76it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114681/118828 [03:23<00:07, 536.25it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114753/118828 [03:23<00:06, 584.43it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114813/118828 [03:24<00:07, 561.88it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114889/118828 [03:24<00:07, 532.07it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114969/118828 [03:24<00:06, 574.09it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115028/118828 [03:24<00:07, 525.77it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115105/118828 [03:24<00:06, 582.86it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115166/118828 [03:24<00:06, 562.77it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115233/118828 [03:24<00:06, 563.76it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115291/118828 [03:24<00:07, 465.82it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115393/118828 [03:25<00:06, 567.84it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115453/118828 [03:25<00:06, 556.44it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115529/118828 [03:25<00:05, 587.57it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115593/118828 [03:25<00:05, 556.21it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115665/118828 [03:25<00:05, 589.89it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115745/118828 [03:25<00:05, 598.01it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115806/118828 [03:25<00:05, 539.09it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115905/118828 [03:25<00:04, 597.26it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115966/118828 [03:26<00:05, 500.04it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116057/118828 [03:26<00:04, 584.75it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116137/118828 [03:26<00:04, 600.54it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116200/118828 [03:26<00:04, 576.17it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116281/118828 [03:26<00:04, 611.93it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116344/118828 [03:26<00:04, 569.76it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116417/118828 [03:26<00:04, 551.99it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116474/118828 [03:27<00:04, 540.33it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116545/118828 [03:27<00:03, 583.28it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116605/118828 [03:27<00:03, 559.51it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116673/118828 [03:27<00:03, 571.64it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116731/118828 [03:27<00:03, 564.97it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116801/118828 [03:27<00:03, 569.32it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116859/118828 [03:27<00:03, 541.39it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116914/118828 [03:27<00:03, 543.62it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116977/118828 [03:27<00:03, 523.64it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117049/118828 [03:28<00:03, 568.73it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117107/118828 [03:28<00:03, 555.95it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117169/118828 [03:28<00:02, 567.32it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117227/118828 [03:28<00:03, 533.05it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117289/118828 [03:28<00:02, 545.67it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117369/118828 [03:28<00:02, 584.29it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117428/118828 [03:28<00:02, 517.05it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117497/118828 [03:28<00:02, 557.60it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117555/118828 [03:28<00:02, 553.04it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117625/118828 [03:29<00:02, 501.00it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117705/118828 [03:29<00:01, 567.37it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117785/118828 [03:29<00:01, 612.27it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117849/118828 [03:29<00:01, 541.55it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117906/118828 [03:29<00:01, 487.34it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117958/118828 [03:29<00:01, 473.42it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118009/118828 [03:29<00:01, 465.79it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118065/118828 [03:29<00:01, 484.21it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118115/118828 [03:30<00:01, 463.27it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118177/118828 [03:30<00:01, 372.94it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118281/118828 [03:30<00:01, 464.57it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118330/118828 [03:30<00:01, 448.60it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118433/118828 [03:30<00:00, 560.67it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118492/118828 [03:30<00:00, 462.20it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118593/118828 [03:31<00:00, 533.47it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118650/118828 [03:31<00:00, 472.22it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118737/118828 [03:31<00:00, 533.51it/s]
# Total pairs screened : 118,828
# Dual-gate pass (verdict=='pass'): 6102
#                      eg_t          eg_p  eg_pass   joh_stat  joh_pass verdict
# ticker1 ticker2
# NCLH    SHOP    -6.892330  1.544746e-08     True  37.268515      True    pass
#         TRMB    -6.774412  2.923744e-08     True  42.340817      True    pass
#         ZBRA    -6.725933  3.793752e-08     True  36.397732      True    pass
#         XYZ     -6.691579  4.559848e-08     True  34.453662      True    pass
#         SBUX    -6.533492  1.055287e-07     True  38.528619      True    pass

# %% [markdown]
# ## 2.2 Pre-scoring: rank candidates for Kalman filtering
#
# We rank all pairs by a composite rank score (EG p-value + Johansen statistic) and
# take the top 200 as candidates for the computationally expensive Kalman step.

# %%
tmp = summary_dual.copy()
tmp["rank_eg"]  = tmp["eg_p"].rank(method="average", ascending=True)
tmp["rank_joh"] = tmp["joh_stat"].rank(method="average", ascending=False)
tmp["pre_score"] = 0.5 * (tmp["rank_eg"] / tmp["rank_eg"].max()
                         + tmp["rank_joh"] / tmp["rank_joh"].max())
prelim     = tmp.sort_values("pre_score", ascending=True)
candidates = prelim.head(200).index.to_list()
print(f"Candidates selected for Kalman filtering: {len(candidates)}")
# Out:
# Candidates selected for Kalman filtering: 200

# %% [markdown]
# # 3. Kalman Filter Hedge Estimation & Stationarity Scoring
#
# ## 3.1 Kalman filter model overview
#
# We estimate a **time-varying** hedge ratio $\beta_t$ via a linear Gaussian state-space model.
#
# **State (random walk):**
# $$
# \theta_t = \begin{bmatrix}\beta_t \\ \alpha_t\end{bmatrix}, \qquad
# \theta_t = \theta_{t-1} + w_t, \quad w_t \sim \mathcal{N}(0, Q)
# $$
#
# **Observation:**
# $$
# y_t = \alpha_t + \beta_t x_t + v_t, \quad v_t \sim \mathcal{N}(0, R)
# $$
#
# Parameters $Q$ and $R$ are learned by EM; the recursion is then run in **filter mode**
# (the causal forward pass) for both the in-sample residuals and the OOS evaluation. The RTS
# smoother is never used: it conditions the state at bar $t$ on the whole sample, which would
# leak the future into the residual a signal reads.

# %%
from pairs import fit_kalman_hedge, summarize_spread_stationarity_joblib

states_tr, params_tr = fit_kalman_hedge(
    df_train,
    pairs=candidates,
    mode="filter",   # causal: the smoother would let each state see the future
    em_iters=5,
    q=1e-5,
    n_workers=None,
    chunksize=100,
    show_progress=True,
    return_params=True,
)
print(f"Kalman states computed for {len(states_tr)} pairs")
# Out:
# Kalman (α_t, β_t):   0%|          | 0/200 [00:00<?, ?it/s]
# Kalman (α_t, β_t):   1%|          | 2/200 [00:03<05:28,  1.66s/it]
# Kalman (α_t, β_t):   3%|▎         | 6/200 [00:03<01:27,  2.22it/s]
# Kalman (α_t, β_t):  11%|█         | 22/200 [00:03<00:16, 10.91it/s]
# Kalman (α_t, β_t):  15%|█▌        | 30/200 [00:03<00:11, 15.25it/s]
# Kalman (α_t, β_t):  18%|█▊        | 37/200 [00:04<00:13, 11.88it/s]
# Kalman (α_t, β_t):  22%|██▏       | 44/200 [00:04<00:09, 15.95it/s]
# Kalman (α_t, β_t):  25%|██▌       | 50/200 [00:05<00:13, 11.25it/s]
# Kalman (α_t, β_t):  27%|██▋       | 54/200 [00:05<00:11, 12.63it/s]
# Kalman (α_t, β_t):  30%|███       | 60/200 [00:05<00:08, 16.51it/s]
# Kalman (α_t, β_t):  32%|███▏      | 64/200 [00:06<00:08, 16.48it/s]
# Kalman (α_t, β_t):  34%|███▍      | 68/200 [00:06<00:12, 10.47it/s]
# Kalman (α_t, β_t):  38%|███▊      | 77/200 [00:07<00:07, 16.11it/s]
# Kalman (α_t, β_t):  40%|████      | 81/200 [00:07<00:10, 11.64it/s]
# Kalman (α_t, β_t):  42%|████▏     | 84/200 [00:08<00:10, 11.04it/s]
# Kalman (α_t, β_t):  46%|████▌     | 91/200 [00:08<00:06, 16.26it/s]
# Kalman (α_t, β_t):  48%|████▊     | 95/200 [00:08<00:05, 18.14it/s]
# Kalman (α_t, β_t):  50%|████▉     | 99/200 [00:09<00:09, 10.47it/s]
# Kalman (α_t, β_t):  51%|█████     | 102/200 [00:09<00:08, 11.57it/s]
# Kalman (α_t, β_t):  55%|█████▍    | 109/200 [00:09<00:05, 17.30it/s]
# Kalman (α_t, β_t):  56%|█████▋    | 113/200 [00:10<00:07, 11.47it/s]
# Kalman (α_t, β_t):  58%|█████▊    | 116/200 [00:10<00:08, 10.46it/s]
# Kalman (α_t, β_t):  62%|██████▏   | 123/200 [00:10<00:04, 16.06it/s]
# Kalman (α_t, β_t):  64%|██████▎   | 127/200 [00:10<00:04, 17.60it/s]
# Kalman (α_t, β_t):  66%|██████▌   | 131/200 [00:11<00:07,  9.43it/s]
# Kalman (α_t, β_t):  70%|██████▉   | 139/200 [00:11<00:04, 15.15it/s]
# Kalman (α_t, β_t):  72%|███████▏  | 143/200 [00:12<00:03, 15.67it/s]
# Kalman (α_t, β_t):  74%|███████▎  | 147/200 [00:12<00:05, 10.12it/s]
# Kalman (α_t, β_t):  76%|███████▌  | 152/200 [00:13<00:03, 13.17it/s]
# Kalman (α_t, β_t):  78%|███████▊  | 157/200 [00:13<00:02, 15.72it/s]
# Kalman (α_t, β_t):  80%|████████  | 160/200 [00:13<00:02, 13.82it/s]
# Kalman (α_t, β_t):  82%|████████▏ | 163/200 [00:14<00:03, 10.18it/s]
# Kalman (α_t, β_t):  84%|████████▍ | 168/200 [00:14<00:02, 13.88it/s]
# Kalman (α_t, β_t):  86%|████████▌ | 171/200 [00:14<00:01, 15.24it/s]
# Kalman (α_t, β_t):  87%|████████▋ | 174/200 [00:14<00:01, 14.62it/s]
# Kalman (α_t, β_t):  88%|████████▊ | 177/200 [00:15<00:01, 11.81it/s]
# Kalman (α_t, β_t):  90%|████████▉ | 179/200 [00:15<00:02,  9.87it/s]
# Kalman (α_t, β_t):  90%|█████████ | 181/200 [00:15<00:01, 10.80it/s]
# Kalman (α_t, β_t):  93%|█████████▎| 186/200 [00:15<00:00, 15.80it/s]
# Kalman (α_t, β_t):  95%|█████████▌| 190/200 [00:15<00:00, 16.52it/s]
# Kalman (α_t, β_t):  96%|█████████▋| 193/200 [00:16<00:00, 14.74it/s]
# Kalman (α_t, β_t):  98%|█████████▊| 195/200 [00:16<00:00, 12.14it/s]
# Kalman (α_t, β_t): 100%|██████████| 200/200 [00:16<00:00, 17.68it/s]
# Kalman states computed for 200 pairs

# %% [markdown]
# ## 3.2 Spread stationarity diagnostics
#
# For each pair we run:
# 1. **ADF** (Augmented Dickey-Fuller) — reject $H_0$ of unit root → spread is I(0)
# 2. **KPSS** — fail to reject $H_0$ of stationarity → spread is I(0)
#
# **Verdict**: `stationary` if ADF rejects AND KPSS does not reject; `non-stationary` if vice versa;
# `inconclusive` otherwise.
#
# Additional diagnostics: **half-life** (AR(1) proxy for mean-reversion speed) and
# **residual sigma** (spread volatility).

# %%
summary_stationarity = summarize_spread_stationarity_joblib(
    states_tr, alpha=0.05, regression="c", chunksize=256, show_progress=True
)
print(f"\n{len(summary_stationarity)} pairs tested")
summary_stationarity.head(10)
# Out:
# Testing stationarity:   0%|          | 0/200 [00:00<?, ?it/s]
# Testing stationarity:   1%|          | 2/200 [00:00<01:29,  2.21it/s]
# Testing stationarity:  28%|██▊       | 57/200 [00:01<00:01, 76.84it/s]
# Testing stationarity:  68%|██████▊   | 136/200 [00:01<00:00, 192.81it/s]
# 200 pairs tested
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# NCLH    ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
#         VICI    -12.742477  8.883603e-24   0.554256  0.029447  1.525712
# CCL     NWS     -10.183337  6.606414e-18   0.907258  0.010000  2.153599
#         NWSA     -9.949875  2.531373e-17   0.929327  0.010000  2.286437
# NCLH    WY       -9.567755  2.332259e-16   0.562237  0.027649  1.378453
# CCL     GM       -9.044586  5.026671e-15   0.691584  0.014311  0.927928
#         COF      -8.909964  1.111177e-14   0.852376  0.010000  0.733056
#         DLR      -8.896328  1.204185e-14   0.465979  0.049329  0.613365
#         CRM      -8.822649  1.859301e-14   0.677932  0.015552  0.698914
# NCLH    TDY      -8.631832  5.727872e-14   0.465533  0.049430  0.602453
#
#                  resid_sigma    shapre       verdict
# ticker1 ticker2
# NCLH    ZBH         0.272626 -0.013607  inconclusive
#         VICI        0.703102 -0.056798  inconclusive
# CCL     NWS         0.772486 -0.077707  inconclusive
#         NWSA        0.798079 -0.080570  inconclusive
# NCLH    WY          0.645115 -0.048115  inconclusive
# CCL     GM          0.380726  0.012253  inconclusive
#         COF         0.276555 -0.015717  inconclusive
#         DLR         0.215440 -0.041952  inconclusive
#         CRM         0.246573 -0.042969  inconclusive
# NCLH    TDY         0.235948 -0.017003  inconclusive

# %% [markdown]
# ## 3.3 Composite scoring
#
# Convert heterogeneous metrics into comparable z-scores (higher = better), then take a
# weighted sum:
#
# | Metric | Transform | Direction |
# |--------|-----------|-----------|
# | ADF p-value | $-\log_{10}(p)$ then $Z(\cdot)$ | smaller p → better |
# | KPSS p-value | $Z(p)$ | larger p → better |
# | Half-life | $-\log(1+\text{hl})$ then $Z(\cdot)$ | shorter → better |
# | Residual sigma | $Z(-\sigma)$ | smaller → better |
# | Sharpe (train) | $Z(\text{Sharpe})$ | higher → better |
#
# > ⚠️ **The Sharpe row does not currently contribute.** The summary function emits the column as
# > `shapre`, while the scoring cell reads `sharpe_train` through `.get(..., 0.0)`, so the lookup
# > returns a constant zero and its $z$-score vanishes. The ranking is driven by the other **four**
# > metrics. Fixing the name would change the shortlist, so it is recorded rather than patched.

# %%
from pairs.stats import Z

final_df = summary_stationarity.copy()
for col in ["adf_p", "kpss_p", "halflife", "resid_sigma", "sharpe_train"]:
    if col in final_df.columns:
        final_df[col] = pd.to_numeric(final_df[col], errors="coerce")

sharpe_series = final_df.get("sharpe_train", pd.Series(0.0, index=final_df.index))
p_adf   = final_df["adf_p"].clip(lower=1e-300, upper=1.0)
p_kpss  = final_df["kpss_p"].clip(lower=1e-300, upper=1.0)
hl_safe = final_df["halflife"].clip(lower=0)

components = {
    "adf":    Z(-np.log10(p_adf)),
    "kpss":   Z(p_kpss),
    "hl":     Z(-np.log1p(hl_safe)),
    "sigma":  Z(-final_df["resid_sigma"]),
    "sharpe": Z(sharpe_series),
}
weights = {k: 1.0 for k in components}
final_df["score"] = sum(weights[k] * components[k] for k in components)
ranked = final_df.sort_values("score", ascending=False)
ranked.head(10)
# Out:
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# BKNG    MA      -26.184819  0.000000e+00   0.107466  0.100000  0.374708
# AVGO    RL      -20.604764  0.000000e+00   0.038229  0.100000  0.461536
# NCLH    REG     -23.778528  0.000000e+00   0.244832  0.100000  0.886268
# HSIC    PLD     -20.181146  0.000000e+00   0.026152  0.100000  0.827721
# NCLH    ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
# BA      JKHY    -20.661471  0.000000e+00   0.197209  0.100000  0.670420
# CRM     EQIX    -17.680054  3.611653e-30   0.036575  0.100000  0.204733
# NCLH    SBAC     -9.112234  3.375238e-15   0.339735  0.100000  0.564747
#         VRSN     -9.163560  2.495410e-15   0.294318  0.100000  0.634927
#         WEC      -9.174016  2.346550e-15   0.271572  0.100000  0.688455
#
#                  resid_sigma    shapre       verdict     score
# ticker1 ticker2
# BKNG    MA          0.363197 -0.001418    stationary  8.740745
# AVGO    RL          0.540440 -0.009011    stationary  8.091029
# NCLH    REG         0.384512 -0.032411    stationary  7.376821
# HSIC    PLD         0.547642 -0.006295    stationary  7.144610
# NCLH    ZBH         0.272626 -0.013607  inconclusive  6.826828
# BA      JKHY        1.547649 -0.002096    stationary  5.291302
# CRM     EQIX        0.306883 -0.001555    stationary  3.965976
# NCLH    SBAC        0.202152 -0.022734    stationary  2.809744
#         VRSN        0.223048 -0.033330    stationary  2.583264
#         WEC         0.292847 -0.028991    stationary  2.294248

# %%
ranked['score'].reset_index(drop=True).plot(
    figsize=(12, 4), grid=True,
    title="Composite score — candidates ranked best → worst",
    xlabel="Rank", ylabel="Score",
)
plt.axhline(-3, color="red", linestyle="--", lw=1.5, label="threshold = −3")
plt.legend(); plt.tight_layout(); plt.show()

# %%
ranked_positive = ranked[ranked["score"] > -3]
robust_pairs    = ranked_positive.index
print(f"Candidates: {len(candidates)}  →  Robust pairs (score > −3): {len(robust_pairs)}")
# Out:
# Candidates: 200  →  Robust pairs (score > −3): 185

# %% [markdown]
# ## 3.4 Pre-filter candidates (composite score)
#
# The composite score from §3.3 is **only a cheap pre-filter** — it narrows the robust pairs down to a short list of candidates. It does **not** pick the traded pair: selecting the single best *in-sample* score is exactly the overfitting trap we want to avoid.
#
# The final pair is chosen in **§3.5** by **walk-forward cross-fold stability**, using only training-span data (2020–2025). The 2026 window (§4b) is never consulted for selection — it stays a genuine held-out test.

# %%
# Composite score is a CHEAP PRE-FILTER only — it does NOT pick the final pair.
# Take the top-N robust candidates; the walk-forward driver in §3.5 selects among them.
N_CANDIDATES = 15
wf_candidates = list(robust_pairs[:N_CANDIDATES])

print(f"Pre-filtered to top {len(wf_candidates)} candidates by composite score "
      f"(of {len(robust_pairs)} robust pairs). Final pick is deferred to §3.5.")
for i, (t1, t2) in enumerate(wf_candidates, 1):
    print(f"  {i:2d}. {t1:6s}/{t2:6s}  score={ranked.loc[(t1, t2), 'score']:.3f}")
# Out:
# Pre-filtered to top 15 candidates by composite score (of 185 robust pairs). Final pick is deferred to §3.5.
#    1. BKNG  /MA      score=8.741
#    2. AVGO  /RL      score=8.091
#    3. NCLH  /REG     score=7.377
#    4. HSIC  /PLD     score=7.145
#    5. NCLH  /ZBH     score=6.827
#    6. BA    /JKHY    score=5.291
#    7. CRM   /EQIX    score=3.966
#    8. NCLH  /SBAC    score=2.810
#    9. NCLH  /VRSN    score=2.583
#   10. NCLH  /WEC     score=2.294
#   11. NCLH  /SJM     score=2.247
#   12. NCLH  /WTW     score=2.229
#   13. NCLH  /PNW     score=2.208
#   14. NCLH  /SPG     score=2.185
#   15. NCLH  /NTRS    score=2.095

# %% [markdown]
# ## 3.5 Walk-forward selection driver  ← *this* picks the traded pair
#
# We run walk-forward validation (rolling train/test folds over the 2020–2025 training span) on **each** pre-filtered candidate and rank by the **median per-fold Sharpe**. Median rewards pairs whose edge is *consistent across folds* rather than pairs that got one lucky window. `MIN_TOTAL_TRADES` screens out pairs too inactive to judge.
#
# This is the holdout principle done correctly for time series: **selection happens on validation folds**; the 2026 test set in §4b is never touched here. The top-ranked pair becomes `ticker1, ticker2` for everything downstream.
#
# The z-score look-back for each test fold is estimated from the *training* fold's residual, which also warms up the rolling window — the test fold never informs its own z-score (no in-fold look-ahead).

# %%
# === Walk-forward selection driver (parallel across candidates) =============
# Each candidate's walk-forward run is independent, so we fan them out with joblib.
# walk_forward_backtest is itself serial (no nested parallelism) and the fit uses the
# single-pair _kalman_dynamic_hedge (no internal process pool) — so the only thing to
# guard against is BLAS thread oversubscription. Pin threads to 1 (as the Kalman module
# does internally) before the worker processes are spawned.
import os
for _v in ("OPENBLAS_NUM_THREADS", "MKL_NUM_THREADS", "NUMEXPR_NUM_THREADS", "OMP_NUM_THREADS"):
    os.environ.setdefault(_v, "1")

from joblib import Parallel, delayed
from pairs import walk_forward_backtest, filter_kf_on_new
from pairs.models.kalman import _kalman_dynamic_hedge
from pairs.strategies.signals import generate_pair_signals, estimate_halflife_window
from pairs.strategies.evaluate import evaluate_pair_signals

MIN_TOTAL_TRADES = 12   # skip candidates too inactive to rank reliably
N_JOBS = -1             # -1 = all cores; each job is one candidate's walk-forward

prices_wide_tr = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values("datetime"),
    columns=df_filtered.index.get_level_values("ticker"),
    values="close",
)

def _sel_fit_fn(df_train):
    # Filtered (causal) states so the residual history handed to the test fold has the same
    # statistical properties as the causal test-fold residual; the EM fit and the exported
    # end state are unaffected by the choice of mode.
    _, _, states, params = _kalman_dynamic_hedge(
        "P1", "P2", df_train, q=1e-5, em_iters=5, mode="filter", return_params=True)
    if states is None or params is None:
        return None
    # The z-score look-back is chosen from the TRAINING residual, and that residual is carried
    # along as warm-up history — the test fold never informs its own z-score (no look-ahead).
    params = dict(params)
    params["z_window"]  = estimate_halflife_window(states["resid"])
    params["z_history"] = states["resid"]
    return params

def _sel_signal_fn(df_test, params):
    frozen = {"F": params["F"], "Q": params["Q"], "R": params["R"]}
    last_state = (params["last_state_mean"], params["last_state_cov"])
    states_te, _ = filter_kf_on_new(
        df_test["P1"], df_test["P2"],
        frozen=frozen, last_state=last_state, mode="filter")  # causal, no look-ahead
    df_pair_fold = df_test[["P1", "P2"]].join(states_te[["beta", "resid"]], how="inner")
    return generate_pair_signals(
        df_pair_fold, z_method="robust",
        z_window=params["z_window"], z_history=params["z_history"],   # from the training fold
        z_entry=2.0, z_exit=0.5, z_stop=4.0, capital_per_pair=10_000)

def _sel_eval_fn(df_test, signals):
    _, _, summary = evaluate_pair_signals(
        df_test[["P1", "P2"]], signals,
        cost_bps=1, borrow_bps_per_year=50, days_per_year=252, bars_per_year=252)
    return summary

def _wf_one(t1, t2, df_wf_c, score):
    """Run walk-forward for one candidate; return ('ok', row) / ('error', ...) / None."""
    try:
        res = walk_forward_backtest(
            df_wf_c, train_bars=504, test_bars=126, step_bars=63,
            fit_fn=_sel_fit_fn, signal_fn=_sel_signal_fn, eval_fn=_sel_eval_fn,
            verbose=False)
    except Exception as e:
        return ("error", t1, t2, str(e))
    if res is None or len(res) == 0:
        return None
    s = res["sharpe"].to_numpy(dtype=float)
    n_tr = res["n_trades"].to_numpy(dtype=float)
    return ("ok", {
        "ticker1": t1, "ticker2": t2,
        "wf_sharpe_median": np.nanmedian(s),
        "wf_sharpe_mean":   np.nanmean(s),
        "wf_sharpe_std":    np.nanstd(s),
        "pct_pos_folds":    float(np.mean(s > 0)) if np.isfinite(s).any() else np.nan,
        "wf_trades_total":  int(np.nansum(n_tr)),
        "n_folds":          int(np.isfinite(s).sum()),
        "composite_score":  float(score),
    }, res)

# Build the (small) per-candidate inputs up front; skip pairs with too little history.
_tasks = []
for (t1, t2) in wf_candidates:
    df_wf_c = prices_wide_tr[[t1, t2]].rename(columns={t1: "P1", t2: "P2"}).dropna()
    if len(df_wf_c) < 504 + 126:        # not enough history for even one fold
        continue
    _tasks.append((t1, t2, df_wf_c, float(ranked.loc[(t1, t2), "score"])))

_results = Parallel(n_jobs=N_JOBS, prefer="processes")(
    delayed(_wf_one)(t1, t2, df_wf_c, score) for (t1, t2, df_wf_c, score) in _tasks
)

rows = []
wf_by_pair = {}            # keep each candidate's full per-fold results for reuse
for r in _results:
    if r is None:
        continue
    if r[0] == "error":
        print(f"  skip {r[1]}/{r[2]}: {r[3]}")
        continue
    rows.append(r[1])
    wf_by_pair[(r[1]["ticker1"], r[1]["ticker2"])] = r[2]

wf_selection = pd.DataFrame(rows).set_index(["ticker1", "ticker2"])
wf_selection = wf_selection[wf_selection["wf_trades_total"] >= MIN_TOTAL_TRADES]
wf_selection = wf_selection.sort_values("wf_sharpe_median", ascending=False)

print(f"Ranked {len(wf_selection)} candidates by walk-forward median fold Sharpe "
      f"(>= {MIN_TOTAL_TRADES} total trades):\n")
print(wf_selection.head(10).to_string(float_format="{:.3f}".format))

ticker1, ticker2 = wf_selection.index[0]
wf_results = wf_by_pair[(ticker1, ticker2)]   # winner's folds, for the detail plot below
print(f"\nWalk-forward-selected pair: {ticker1} / {ticker2}")
print("(Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)")
# Out:
# Ranked 15 candidates by walk-forward median fold Sharpe (>= 12 total trades):
#
#                  wf_sharpe_median  wf_sharpe_mean  wf_sharpe_std  pct_pos_folds  wf_trades_total  n_folds  composite_score
# ticker1 ticker2
# BKNG    MA                  1.167           1.094          1.128          0.812              122       16            8.741
# NCLH    SPG                 0.618           0.644          1.249          0.750              120       16            2.185
#         REG                 0.602           0.307          1.481          0.688              118       16            7.377
#         NTRS                0.475           0.416          1.451          0.625              136       16            2.095
#         SJM                 0.366           0.349          1.392          0.688              135       16            2.247
# AVGO    RL                  0.287           0.236          1.044          0.562              104       16            8.091
# NCLH    WTW                 0.280          -0.023          1.679          0.625              126       16            2.229
#         PNW                 0.239          -0.221          1.870          0.500              122       16            2.208
# CRM     EQIX               -0.044           0.181          0.995          0.438              122       16            3.966
# NCLH    SBAC               -0.176          -0.113          1.487          0.438              132       16            2.810
#
# Walk-forward-selected pair: BKNG / MA
# (Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)

# %% [markdown]
# ### 3.5.1 Walk-forward detail for the selected pair
#
# §3.5 ranked the shortlist by **median per-fold Sharpe** and selected the pair above. Below is that pair's full per-fold walk-forward distribution — the validation evidence behind the choice, reusing the folds already computed (no recomputation). A tight, mostly-positive distribution is what we want; one that swings sign across folds means the edge is fragile.

# %%
# Per-fold walk-forward detail for the SELECTED pair — reuses wf_results from §3.5
# (no recomputation). nan-robust stats (a zero-trade fold yields a NaN Sharpe).
from pairs.validation.walk_forward import summarize_walk_forward

print(f"=== Walk-forward folds for selected pair {ticker1}/{ticker2} ===\n")
print(summarize_walk_forward(wf_results).to_string(float_format="{:.3f}".format))

fig, axes = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle(f"Walk-Forward Validation: {ticker1}/{ticker2}  "
             f"(train=504d, test=126d, step=63d)", fontsize=13)

sharpes  = wf_results["sharpe"].to_numpy(dtype=float)
ann_rets = wf_results["ann_return"].to_numpy(dtype=float) * 100
dds      = wf_results["max_drawdown_pct"].abs().to_numpy(dtype=float) * 100
n_trades = wf_results["n_trades"].to_numpy(dtype=float)
folds    = wf_results.index.values

def _bar(ax, vals, title, ylabel, pos_neg=True):
    colors = ["green" if v > 0 else "red" for v in vals] if pos_neg else "salmon"
    ax.bar(folds, vals, color=colors, alpha=0.75, edgecolor="white")
    ax.axhline(0, color="black", lw=0.8)
    ax.axhline(np.nanmean(vals), color="navy", linestyle="--", lw=1.5,
               label=f"Mean={np.nanmean(vals):.2f}")
    ax.set_xlabel("Fold"); ax.set_ylabel(ylabel); ax.set_title(title); ax.legend()

_bar(axes[0, 0], sharpes,  "Per-Fold Sharpe Ratio",      "Sharpe")
_bar(axes[0, 1], ann_rets, "Per-Fold Annualised Return", "Ann. Return (%)")
_bar(axes[1, 0], dds,      "Per-Fold Max Drawdown",      "Max Drawdown (%)", pos_neg=False)
_bar(axes[1, 1], n_trades, "Per-Fold Trade Count",       "Trades", pos_neg=False)
plt.tight_layout(); plt.show()

pct_pos = float(np.mean(sharpes > 0)) * 100
print(f"\nFolds with positive Sharpe : {pct_pos:.0f}%  ({int((sharpes > 0).sum())}/{len(sharpes)})")
print(f"Median fold Sharpe         : {np.nanmedian(sharpes):.2f}")
print(f"Mean fold Sharpe           : {np.nanmean(sharpes):.2f}  (std={np.nanstd(sharpes):.2f})")
# Out:
# === Walk-forward folds for selected pair BKNG/MA ===
#
#                   mean   std  median    min    max
# sharpe           1.094 1.165   1.167 -0.931  3.054
# ann_return       0.063 0.071   0.055 -0.049  0.175
# max_drawdown_pct 0.024 0.015   0.018  0.008  0.065
# n_trades         7.625 2.553   8.000  3.000 11.000
# hit_rate         0.714 0.171   0.697  0.333  1.000
# profit_factor      inf   NaN   4.408  0.332    inf
# Folds with positive Sharpe : 81%  (13/16)
# Median fold Sharpe         : 1.17
# Mean fold Sharpe           : 1.09  (std=1.13)

# %% [markdown]
# # 4. In-Sample Signal Generation & Evaluation (2020–2025)
#
# ## 4.1 Build the pair-aligned DataFrame

# %%
df_kf = states_tr[(ticker1, ticker2)]

prices = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values('datetime'),
    columns=df_filtered.index.get_level_values('ticker'),
    values='close',
)

df_pair = pd.DataFrame({
    'P1': prices[ticker1],
    'P2': prices[ticker2],
}).join(df_kf[['beta', 'resid']])

print(f"Training pair frame: {df_pair.index[0].date()} → {df_pair.index[-1].date()}, "
      f"{len(df_pair):,} bars")
df_pair.tail(3)
# Out:
# Training pair frame: 2020-01-02 → 2025-12-31, 1,508 bars
#                     P1          P2      beta     resid
# datetime
# 2025-12-29  217.653198  577.900024  0.343690  0.062141
# 2025-12-30  217.085999  577.419983  0.343163 -0.035799
# 2025-12-31  214.213196  570.880005  0.342126 -0.071359

# %% [markdown]
# ## 4.2 Generate trading signals
#
# Signal logic:
# - **Entry**: |z| > `z_entry` (default 2.0) — spread is extreme
# - **Exit** : |z| < `z_exit`  (default 0.5) — spread has mean-reverted
# - **Stop** : |z| > `z_stop`  (default 4.0) — spread is diverging
#
# Z-score is computed with the *robust* method (median/MAD) which is less sensitive to outliers.

# %%
from pairs.strategies import generate_pair_signals

signals = generate_pair_signals(
    df_pair,
    z_method="robust",
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
    max_hold_bars=None,
    cooldown_bars=0,
)
signals.tail(5)
# Out:
#                    z  pos   n1   n2  entry   exit   stop
# datetime
# 2025-12-24 -0.428719    0  0.0  0.0  False  False  False
# 2025-12-26 -0.191140    0  0.0  0.0  False  False  False
# 2025-12-29 -0.015958    0  0.0  0.0  False  False  False
# 2025-12-30 -0.196630    0  0.0  0.0  False  False  False
# 2025-12-31 -0.362246    0  0.0  0.0  False  False  False

# %% [markdown]
# ## 4.3 Visualise in-sample trades

# %%
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair, signals,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4.4 In-sample performance metrics

# %%
from pairs import evaluate_pair_signals

daily_tr, trades_tr, summary_tr = evaluate_pair_signals(
    df_pair, signals,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== In-Sample Performance (2020-01-02 → 2025-12-31) ===")
print(pd.Series(summary_tr).to_string())
# Out:
# === In-Sample Performance (2020-01-02 → 2025-12-31) ===
# start                       2020-01-02 00:00:00
# end                         2025-12-31 00:00:00
# bars                                       1508
# capital_base                        10004.60448
# gross_pnl                           1992.901453
# net_pnl                             1794.505533
# ann_return                              0.02869
# sharpe                                 0.515717
# max_drawdown                         872.099587
# max_drawdown_pct                       0.084032
# avg_gross_exposure                  1698.151802
# avg_exposure_utilization               0.999857
# turnover_annualized                   28.824608
# n_trades                                     85
# hit_rate                                    0.6
# avg_win                               97.572684
# avg_loss                             -91.079731
# profit_factor                          1.606933
# avg_hold_bars                          3.011765
# med_hold_bars                               2.0
# ann_vol                                0.058121
# sortino                                0.805237
# gross_return_chain                     1.208153
# net_return_chain                       1.184438
# avg_daily_dollars_traded            1144.360333
# impact_cost_total                           0.0

# %%
# Equity curve with drawdown shading
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(13, 7), sharex=True,
                                gridspec_kw={"height_ratios": [3, 1]})

ax1.plot(daily_tr.index, daily_tr["equity"], color="steelblue", lw=1.5, label="Equity")
ax1.fill_between(daily_tr.index, daily_tr["equity"],
                 daily_tr["equity"] + daily_tr["drawdown"],   # drawdown is negative
                 alpha=0.25, color="red", label="Drawdown")
ax1.set_ylabel("Equity ($)"); ax1.set_title(f"In-Sample Equity Curve — {ticker1}/{ticker2}")
ax1.legend()

ax2.fill_between(daily_tr.index, daily_tr["drawdown_pct"] * 100, 0,
                 alpha=0.6, color="red")
ax2.set_ylabel("Drawdown (%)"); ax2.set_xlabel("Date")
plt.tight_layout(); plt.show()

# %% [markdown]
# # 4b. Out-of-Sample Evaluation (2026-01-01 → 2026-06-25)
#
# ## 4b.1 Download OOS price data

# %%
start_test = "2026-01-01"
end_test   = "2026-06-25"

_oos_cache = CACHE / f"nb03_oos_{ticker1}_{ticker2}_{start_test}_{end_test}.parquet"
if _oos_cache.exists():
    df_test, failed = pd.read_parquet(_oos_cache), []
else:
    df_test, failed = load_prices('openbb', [ticker1, ticker2], start_test, end_test, return_failed=True)
    df_test.to_parquet(_oos_cache)
print(f"OOS data: {len(df_test):,} rows, {df_test.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# OOS data: 240 rows, 2 tickers

# %% [markdown]
# ## 4b.2 Continue Kalman filter on OOS window (no look-ahead)
#
# We freeze the parameters $(F, Q, R)$ learned during training and **continue filtering**
# from the last train state.  The smoother is NOT used on OOS data — only the causal filter.
#
# The OOS z-score uses a look-back chosen from — and warmed up on — the causal *training-window* residual under the same frozen parameters, so the OOS window never informs its own z-score.

# %%
from pairs import filter_kf_on_new

pair = (ticker1, ticker2)
frozen = {k: params_tr[pair][k] for k in ("F", "Q", "R")}
last_state = (params_tr[pair]["last_state_mean"], params_tr[pair]["last_state_cov"])

P1_new = df_test.loc[(ticker1,), 'close']
P2_new = df_test.loc[(ticker2,), 'close']

states_te, _ = filter_kf_on_new(
    P1_new, P2_new,
    frozen=frozen,
    last_state=last_state,
    init_cov=1e6,
    mode="filter",
)

prices_te = df_test.pivot_table(
    index=df_test.index.get_level_values("datetime"),
    columns=df_test.index.get_level_values("ticker"),
    values="close",
)
df_pair_te = states_te.join(
    prices_te[[ticker1, ticker2]].rename(columns={ticker1: "P1", ticker2: "P2"}),
    how="inner",
)
print(f"OOS pair frame: {df_pair_te.index[0].date()} → {df_pair_te.index[-1].date()}, "
      f"{len(df_pair_te):,} bars")
# Out:
# OOS pair frame: 2026-01-02 → 2026-06-25, 120 bars

# %%
# z-score look-back and warm-up history from the causal TRAINING residual under the frozen
# parameters — the OOS window never informs its own z-score (no in-window look-ahead).
states_hist, _ = filter_kf_on_new(
    df_pair["P1"], df_pair["P2"],
    frozen=frozen, last_state=None, init_cov=1e6, mode="filter",
)
z_window_tr = estimate_halflife_window(states_hist["resid"])
print(f"z-score window from training residual: {z_window_tr} bars")

signals_te = generate_pair_signals(
    df_pair_te,
    z_method="robust",
    z_window=z_window_tr, z_history=states_hist["resid"],
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
)
daily_te, trades_te, summary_te = evaluate_pair_signals(
    df_pair_te[["P1", "P2"]], signals_te,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===")
print(pd.Series(summary_te).to_string())
# Out:
# z-score window from training residual: 30 bars
# === Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===
# start                       2026-01-02 00:00:00
# end                         2026-06-25 00:00:00
# bars                                        120
# capital_base                        9994.934405
# gross_pnl                            829.810073
# net_pnl                              800.118659
# ann_return                             0.181645
# sharpe                                 3.499967
# max_drawdown                         142.512322
# max_drawdown_pct                       0.013461
# avg_gross_exposure                  2168.820124
# avg_exposure_utilization               1.001501
# turnover_annualized                   56.810331
# n_trades                                     13
# hit_rate                               0.846154
# avg_win                                77.07732
# avg_loss                             -52.197106
# profit_factor                          8.121624
# avg_hold_bars                          1.923077
# med_hold_bars                               2.0
# ann_vol                                0.048032
# sortino                                9.020344
# gross_return_chain                     1.085939
# net_return_chain                       1.082724
# avg_daily_dollars_traded            2253.236251
# impact_cost_total                           0.0

# %% [markdown]
# ## 4b.3 Visualise OOS trades
#
# The same view as the in-sample plot (§4.3), now on the 2026 held-out window. Reading it next to §4.3 makes the shorter window concrete: 13 holding periods here against 85 across the five-year training span — though over only 120 bars, so the *rate* of trading is actually higher out of sample.

# %%
# Same plot as in-sample (§4.3), applied to the OOS pair frame & signals.
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair_te, signals_te,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4b.4 In-sample vs OOS comparison
#
# > ⚠️ **Caution**: The OOS window contains only **13 trades** over 120 bars. A hit rate of
# > 84.6% on 13 observations is statistically uninformative — the 95% binomial CI spans roughly
# > (55%, 98%). Note the direction: the OOS Sharpe (3.50) is *higher* than the in-sample figure
# > (0.52), which is not evidence that the strategy improved. The standard error of an annualised
# > Sharpe over 120 bars is about 1.4, so 3.50 is a high-variance draw, not a result.

# %%
comparison = pd.DataFrame({
    "In-sample (2020-2025)": pd.Series(summary_tr),
    "OOS (2026)":            pd.Series(summary_te),
}).loc[["sharpe", "ann_return", "max_drawdown_pct", "n_trades", "hit_rate", "profit_factor"]]
comparison.loc["ann_return"] = comparison.loc["ann_return"] * 100   # → %
comparison.index = ["Sharpe", "Ann. Return (%)", "Max Drawdown (%)", "Trades", "Hit Rate", "Profit Factor"]
print(comparison.to_string(float_format="{:.3f}".format))
# Out:
#                  In-sample (2020-2025) OOS (2026)
# Sharpe                           0.516      3.500
# Ann. Return (%)                  2.869     18.164
# Max Drawdown (%)                 0.084      0.013
# Trades                              85         13
# Hit Rate                         0.600      0.846
# Profit Factor                    1.607      8.122

# %% [markdown]
# # 8. Limitations and Honest Assessment
#
# ## 8.1 What the results cannot tell us
#
# The traded pair was chosen (§3.5) from a shortlist that itself survived a composite stationarity filter over a very large number of simultaneously-tested pairs. Read the performance with these caveats:
#
# - **Selection bias (identical to nb02, not amplified).** Dropping Benjamini-Hochberg marks far more pairs `pass`, but the candidate set is a rank cut on raw p-values that BH does not reorder, so this notebook's shortlist, selected pair and results match `pairs_trading_02_yahoo.ipynb` exactly (§0). The selection bias is real and is the same in both. To make the ablation bite, gate candidates on `verdict` before the rank cut.
# - **Low OOS trade count.** The OOS window produces only a handful of trades (13 for the selected BKNG/MA pair) — far below the ~50 needed for statistical power. A high hit rate on a few trades is uninformative.
# - **Single-window Sharpe is noise in both directions.** In-sample Sharpe is systematically optimistic, so the OOS figure is *usually* lower — but in this run it is higher (0.52 → 3.50) on 13 trades in half a year. Neither single window is informative: the fold distribution in §3.5 is.
# - **Optimistic cost model.** The in-sample/OOS evaluation uses a flat `cost_bps` with no market impact, fill/queue uncertainty, or borrow-availability variability.
# - **Single-pair analysis.** A live strategy trades a *portfolio* of pairs — introducing cross-pair residual correlation, portfolio-level drawdown management, and signal interaction effects not captured here.
#
# ## 8.2 What the evidence does support
#
# 1. A working end-to-end pipeline (data → cointegration → Kalman hedge → signals → evaluation) with **causal OOS continuation** (no look-ahead: the Kalman state is carried forward, and the z-score look-back and its warm-up come from training data, never from the window being scored).
# 2. **Honest pair selection**: the traded pair is chosen by walk-forward cross-fold stability (§3.5), not by in-sample ranking — and the held-out window is never used for selection.
# 3. **Multiple-testing _not_ corrected**: this variant omits BH FDR (the deliberate difference from nb02), so statistically spurious pairs that BH would remove stay in the candidate set.
# 4. **Honest degradation disclosure**: the OOS Sharpe is reported, not hidden, and the walk-forward distribution (§3.5.1) shows the spread across folds rather than one window.
#
# ## 8.3 Gap-to-production
#
# | Gap | Required mitigation |
# |-----|---------------------|
# | Selection bias | Strict hold-out from inception; **add BH FDR** (omitted here — see nb02) + walk-forward selection |
# | Low OOS N | Longer OOS window; portfolio of 10+ pairs |
# | No market impact | Square-root impact model + capacity analysis |
# | Single-regime OOS | Rolling re-estimation in live trading |
# | No portfolio risk mgmt | Residual-vol position sizing; cross-pair correlation |
# | Borrow / execution | Pre-borrow checks; limit-order fill model |
