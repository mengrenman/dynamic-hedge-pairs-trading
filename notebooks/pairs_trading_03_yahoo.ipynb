# %% [markdown]
# # Dynamic Hedge Pairs Trading — *without* Benjamini-Hochberg
# ## `pairs_trading_03_yahoo.ipynb`
#
# Identical pipeline to `pairs_trading_02_yahoo.ipynb` — cointegration screen → Kalman hedge → walk-forward pair selection → in-sample & out-of-sample backtests with performance metrics → limitations — with **one deliberate change: no Benjamini-Hochberg FDR correction** on the cointegration screen (`fdr_method="none"`, raw p-values).
#
# The intent is to isolate the effect of dropping multiple-testing control. **It still does not, and the
# reason is worth more than the intended result.**
#
# The correction now visibly bites on the screen: under Benjamini-Hochberg **279** of 118,828 pairs clear
# the dual gate, and without it **6,102** do — twenty-two times as many. That difference is real and it is
# printed below. Yet this notebook still reproduces `pairs_trading_02_yahoo.ipynb` exactly: same selected
# pair, same in-sample Sharpe, same trades.
#
# The filters are **nested**. Benjamini-Hochberg removes the pairs with the *weakest* p-values; the shortlist
# is the top 200 by a blended Engle-Granger/Johansen *rank*, which keeps the *strongest*. Since
# $200 \le 279 \le 6{,}102$ and both pools are ordered the same way, the top 200 of the corrected pool and
# the top 200 of the uncorrected pool are the **same 200 pairs**. Every pair the correction removes was
# already going to be discarded one line later.
#
# So the ablation can only bite under one of two conditions, neither of which holds here:
#
# * the shortlist is **larger** than the number of survivors — take the top 500 and the corrected pool runs
#   out at 279, forcing it to stop where the uncorrected one keeps going; or
# * selection is **not ordered by p-value** — if the shortlist were drawn by any other criterion, the
#   correction would change which pairs are available to it.
#
# That is the honest lesson, and it generalises past this notebook: **a significance filter placed upstream
# of a stricter ranking filter is decorative.** It changes a reported count and nothing else. Notebook 11
# finds FDR control worth +0.40 Sharpe against −0.41 for distance selection precisely because there the
# survivors *are* the selection, with no tighter cut behind them.

# %% [markdown]
# ## 0. Environment setup

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().parent           # notebooks/ → repo root
sys.path.insert(0, str(repo_root))

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pairs
print("pairs version:", pairs.__version__)
print("pairs path   :", Path(pairs.__file__).relative_to(repo_root))
# Out:
# pairs version: 0.1.0
# pairs path   : pairs/__init__.py

# %%
# Install the package (editable) if running in a fresh environment
# %pip install -e "..[notebooks]"  # uncomment if needed

# %% [markdown]
# # 1. Data Loading & Quality Filtering
#
# We load daily OHLCV prices for the combined S&P 500 + NASDAQ-100 universe
# (~517 tickers) over the **training window 2020-01-01 → 2025-12-31**, then
# drop tickers whose coverage does not span the full period.

# %%
from pairs import load_universe, load_prices

tickers = load_universe("spx_ndx_combined")
print(f"Universe: {len(tickers)} tickers")
# Out:
# Universe: 517 tickers

# %%
# ── Load training prices ──────────────────────────────────────────────────────
start_date = "2020-01-01"
end_date   = "2025-12-31"

# Prices are cached on first run so the notebook is reproducible offline afterwards.
# This matters more than it looks: Yahoo re-bases its adjusted close after every
# corporate action, so a fresh download months later returns different *levels*
# for any name that has since split or spun off. Pinning the file freezes the basis.
CACHE = Path("cache"); CACHE.mkdir(exist_ok=True)
# the window is part of the key: change the dates and it re-downloads
_px_cache = CACHE / f"nb03_train_{start_date}_{end_date}.parquet"
if _px_cache.exists():
    df_train, failed = pd.read_parquet(_px_cache), []
else:
    df_train, failed = load_prices('openbb', tickers, start_date, end_date, return_failed=True)
    df_train.to_parquet(_px_cache)

print(f"Loaded {len(df_train):,} rows for {df_train.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# Loaded 753,000 rows for 505 tickers

# %%
# ── Quality filter: keep only full-coverage tickers ──────────────────────────
lvl_names      = list(df_train.index.names)
time_lvl_name  = 'datetime' if 'datetime' in lvl_names else lvl_names[1]

full_start = df_train.index.get_level_values(time_lvl_name).min()
full_end   = df_train.index.get_level_values(time_lvl_name).max()

starts = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).min())
ends   = df_train.groupby(level=0).apply(lambda g: g.index.get_level_values(time_lvl_name).max())

tickers_to_keep = starts[(starts == full_start) & (ends == full_end)].index
df_filtered     = df_train.loc[pd.IndexSlice[tickers_to_keep, :]]

n_orig    = df_train.index.get_level_values('ticker').nunique()
n_kept    = df_filtered.index.get_level_values('ticker').nunique()
dropped   = set(tickers) - set(tickers_to_keep)
print(f"Tickers: {n_orig} total → {n_kept} kept ({n_orig - n_kept} dropped for incomplete coverage)")
print(f"Dropped: {sorted(dropped)}")
# Out:
# Tickers: 505 total → 488 kept (17 dropped for incomplete coverage)
# Dropped: ['ABNB', 'APP', 'ARM', 'AVB', 'BK', 'CARR', 'CEG', 'COIN', 'CTRA', 'DASH', 'DAY', 'EA', 'EQR', 'EXE', 'FI', 'GEHC', 'GEV', 'GFS', 'HOLX', 'IPG', 'K', 'KVUE', 'MMC', 'OTIS', 'PARA', 'PLTR', 'SOLV', 'VLTO', 'WBA']

# %% [markdown]
# # 2. Cointegration Screening
#
# ## 2.1 Dual-gate screening (Engle-Granger + Johansen)
#
# We test all $\binom{n}{2}$ pairs simultaneously using two cointegration tests.
# A pair advances only if **both** tests reject the null of no cointegration.

# %%
from pairs import find_cointegrated_pairs_dualgate

# fdr_method="none" — NO Benjamini-Hochberg correction (raw EG p-value gate).
summary_dual = find_cointegrated_pairs_dualgate(
    df_filtered,
    alpha_eg=0.05, eg_trend="c",
    alpha_joh=0.05, joh_det_order=0, joh_k_ar_diff=1, joh_stat="trace",
    fdr_method="none",      # ← raw p-values, no multiple-testing correction
    n_workers=16, chunksize=8, show_progress=True,
)
print(f"\nTotal pairs screened : {len(summary_dual):,}")
print(f"Dual-gate pass (verdict=='pass'): {(summary_dual['verdict']=='pass').sum()}")
summary_dual.head(5)[["eg_t", "eg_p", "eg_pass", "joh_stat", "joh_pass", "verdict"]]
# Out:
# Dual-gate cointegration (EG + Johansen):   0%|          | 0/118828 [00:00<?, ?it/s]
# Dual-gate cointegration (EG + Johansen):   1%|          | 1081/118828 [00:00<00:28, 4067.55it/s]
# Dual-gate cointegration (EG + Johansen):   1%|▏         | 1488/118828 [00:00<01:22, 1418.26it/s]
# Dual-gate cointegration (EG + Johansen):   1%|▏         | 1694/118828 [00:01<01:36, 1210.97it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 1841/118828 [00:01<01:54, 1019.30it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 1953/118828 [00:01<02:08, 907.53it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2045/118828 [00:01<02:28, 783.89it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2121/118828 [00:02<02:48, 693.71it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2209/118828 [00:02<02:47, 695.42it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2276/118828 [00:02<03:05, 629.41it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2345/118828 [00:02<03:04, 630.42it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2406/118828 [00:02<03:30, 553.94it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2489/118828 [00:02<03:16, 591.56it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2549/118828 [00:02<03:22, 573.81it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2606/118828 [00:02<04:15, 454.34it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2673/118828 [00:03<03:57, 488.89it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2737/118828 [00:03<03:45, 515.23it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2792/118828 [00:03<03:58, 486.09it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2865/118828 [00:03<03:45, 513.56it/s]
# Dual-gate cointegration (EG + Johansen):   2%|▏         | 2961/118828 [00:03<03:14, 594.38it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3022/118828 [00:03<03:35, 536.90it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3113/118828 [00:03<03:15, 591.25it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3185/118828 [00:03<03:11, 604.48it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3257/118828 [00:04<03:24, 564.32it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3345/118828 [00:04<03:04, 625.90it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3410/118828 [00:04<03:38, 528.27it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3513/118828 [00:04<03:06, 618.23it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3585/118828 [00:04<03:03, 626.82it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3651/118828 [00:04<03:41, 520.94it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3761/118828 [00:04<02:57, 646.58it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3832/118828 [00:05<03:04, 623.65it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3899/118828 [00:05<03:20, 572.37it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 3985/118828 [00:05<03:06, 616.83it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4050/118828 [00:05<03:31, 543.92it/s]
# Dual-gate cointegration (EG + Johansen):   3%|▎         | 4137/118828 [00:05<03:18, 577.08it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4209/118828 [00:05<03:12, 594.76it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4271/118828 [00:05<03:11, 598.70it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4333/118828 [00:05<03:25, 556.16it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▎         | 4401/118828 [00:06<03:43, 511.14it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4497/118828 [00:06<03:26, 553.39it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4554/118828 [00:06<03:39, 520.93it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4641/118828 [00:06<03:10, 598.23it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4703/118828 [00:06<03:17, 576.68it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4769/118828 [00:06<03:15, 583.24it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4841/118828 [00:06<03:10, 598.89it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4902/118828 [00:06<03:11, 596.12it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 4963/118828 [00:07<03:38, 520.20it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5041/118828 [00:07<03:25, 552.39it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5145/118828 [00:07<02:48, 673.07it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5216/118828 [00:07<03:17, 576.10it/s]
# Dual-gate cointegration (EG + Johansen):   4%|▍         | 5289/118828 [00:07<03:27, 547.57it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5385/118828 [00:07<03:07, 605.26it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5448/118828 [00:07<03:57, 477.53it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5521/118828 [00:08<03:47, 497.39it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5577/118828 [00:08<03:54, 482.33it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5665/118828 [00:08<03:27, 544.50it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5722/118828 [00:08<03:43, 506.32it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5793/118828 [00:08<03:25, 549.09it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5851/118828 [00:08<04:24, 426.35it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▍         | 5921/118828 [00:08<04:27, 422.64it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6049/118828 [00:09<03:07, 601.11it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6119/118828 [00:09<03:09, 595.09it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6186/118828 [00:09<03:17, 570.42it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6248/118828 [00:09<03:33, 526.78it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6329/118828 [00:09<03:16, 573.83it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6393/118828 [00:09<03:11, 587.47it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6455/118828 [00:09<03:11, 586.02it/s]
# Dual-gate cointegration (EG + Johansen):   5%|▌         | 6521/118828 [00:09<03:25, 545.60it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6593/118828 [00:10<03:33, 525.43it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6681/118828 [00:10<03:08, 594.11it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6745/118828 [00:10<03:07, 599.21it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6809/118828 [00:10<03:07, 598.80it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6870/118828 [00:10<03:33, 523.32it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 6925/118828 [00:10<03:35, 519.66it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7017/118828 [00:10<03:15, 573.21it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7075/118828 [00:10<03:24, 545.77it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7153/118828 [00:11<03:08, 590.92it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7213/118828 [00:11<03:17, 565.69it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7297/118828 [00:11<02:57, 629.32it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▌         | 7361/118828 [00:11<03:33, 522.86it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7457/118828 [00:11<03:02, 609.71it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7522/118828 [00:11<03:02, 608.62it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7586/118828 [00:11<03:06, 594.92it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7648/118828 [00:11<03:06, 595.70it/s]
# Dual-gate cointegration (EG + Johansen):   6%|▋         | 7713/118828 [00:12<03:31, 526.41it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7793/118828 [00:12<03:08, 589.71it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7855/118828 [00:12<03:13, 573.31it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 7945/118828 [00:12<03:05, 597.31it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8006/118828 [00:12<03:15, 566.23it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8089/118828 [00:12<02:56, 628.88it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8154/118828 [00:12<03:06, 592.39it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8217/118828 [00:12<03:23, 542.93it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8313/118828 [00:13<02:52, 639.53it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8380/118828 [00:13<03:04, 599.27it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8449/118828 [00:13<03:05, 593.76it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8510/118828 [00:13<03:24, 540.29it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8601/118828 [00:13<03:04, 597.08it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8662/118828 [00:13<03:17, 558.28it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8737/118828 [00:13<03:23, 541.03it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8825/118828 [00:13<03:04, 597.72it/s]
# Dual-gate cointegration (EG + Johansen):   7%|▋         | 8889/118828 [00:14<03:01, 606.98it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 8953/118828 [00:14<03:05, 592.17it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9025/118828 [00:14<02:55, 625.33it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9089/118828 [00:14<03:03, 599.54it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9150/118828 [00:14<03:24, 535.12it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9205/118828 [00:14<03:48, 479.03it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9273/118828 [00:14<03:51, 473.00it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9322/118828 [00:14<04:02, 452.48it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9401/118828 [00:15<03:28, 525.66it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9456/118828 [00:15<03:45, 485.65it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9529/118828 [00:15<03:39, 498.12it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9580/118828 [00:15<03:41, 493.36it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9681/118828 [00:15<03:10, 572.55it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9739/118828 [00:15<03:17, 553.57it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9795/118828 [00:15<03:18, 550.51it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9850/118828 [00:15<03:51, 471.06it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9937/118828 [00:16<03:14, 560.87it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 9996/118828 [00:16<03:26, 527.61it/s]
# Dual-gate cointegration (EG + Johansen):   8%|▊         | 10051/118828 [00:16<03:28, 520.55it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10137/118828 [00:16<03:05, 586.15it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10201/118828 [00:16<03:08, 577.39it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10281/118828 [00:16<02:58, 609.22it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▊         | 10343/118828 [00:16<04:17, 421.01it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10465/118828 [00:17<03:06, 582.48it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10545/118828 [00:17<02:57, 609.50it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10615/118828 [00:17<02:54, 620.10it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10684/118828 [00:17<02:55, 615.42it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10750/118828 [00:17<03:11, 564.10it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10833/118828 [00:17<03:08, 574.28it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10913/118828 [00:17<03:17, 547.15it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 10977/118828 [00:17<03:20, 536.80it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11041/118828 [00:18<03:14, 554.94it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11098/118828 [00:18<03:37, 494.19it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11153/118828 [00:18<03:53, 461.78it/s]
# Dual-gate cointegration (EG + Johansen):   9%|▉         | 11225/118828 [00:18<03:32, 506.21it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11313/118828 [00:18<03:07, 574.61it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11373/118828 [00:18<03:07, 573.71it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11433/118828 [00:18<03:08, 568.62it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11497/118828 [00:18<03:03, 583.70it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11557/118828 [00:19<03:33, 503.52it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11633/118828 [00:19<03:15, 549.10it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11690/118828 [00:19<03:14, 549.94it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11747/118828 [00:19<03:46, 472.48it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11825/118828 [00:19<03:43, 478.49it/s]
# Dual-gate cointegration (EG + Johansen):  10%|▉         | 11875/118828 [00:19<03:46, 472.47it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 11961/118828 [00:19<03:42, 481.26it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12033/118828 [00:19<03:22, 526.99it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12097/118828 [00:20<03:17, 541.65it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12153/118828 [00:20<03:39, 485.38it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12217/118828 [00:20<03:27, 514.57it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12273/118828 [00:20<03:47, 468.81it/s]
# Dual-gate cointegration (EG + Johansen):  10%|█         | 12393/118828 [00:20<03:26, 516.60it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12481/118828 [00:20<03:18, 535.26it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12537/118828 [00:20<03:23, 523.34it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12633/118828 [00:21<03:01, 584.90it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12737/118828 [00:21<02:45, 642.80it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12802/118828 [00:21<03:15, 543.44it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12897/118828 [00:21<03:04, 575.69it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 12977/118828 [00:21<02:57, 596.28it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13041/118828 [00:21<03:13, 546.80it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13129/118828 [00:21<02:51, 618.04it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13194/118828 [00:22<03:05, 568.36it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13253/118828 [00:22<03:08, 559.47it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█         | 13321/118828 [00:22<03:10, 552.94it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13409/118828 [00:22<02:58, 591.31it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13469/118828 [00:22<03:03, 575.47it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13537/118828 [00:22<02:58, 589.24it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13597/118828 [00:22<03:10, 553.31it/s]
# Dual-gate cointegration (EG + Johansen):  11%|█▏        | 13665/118828 [00:22<03:18, 529.31it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13745/118828 [00:22<02:56, 595.51it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13807/118828 [00:23<02:54, 601.28it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13869/118828 [00:23<03:06, 563.77it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13927/118828 [00:23<03:06, 562.38it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 13984/118828 [00:23<03:09, 552.76it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14041/118828 [00:23<03:09, 554.11it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14097/118828 [00:23<03:31, 494.38it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14209/118828 [00:23<02:52, 607.91it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14273/118828 [00:23<02:54, 598.79it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14337/118828 [00:24<02:54, 600.04it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14398/118828 [00:24<03:10, 547.33it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14465/118828 [00:24<03:02, 573.14it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14524/118828 [00:24<03:00, 576.72it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14593/118828 [00:24<02:52, 606.00it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14655/118828 [00:24<03:11, 545.08it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14721/118828 [00:24<03:05, 561.73it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14779/118828 [00:24<03:08, 550.95it/s]
# Dual-gate cointegration (EG + Johansen):  12%|█▏        | 14849/118828 [00:24<02:57, 584.75it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 14909/118828 [00:25<03:06, 558.02it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 14977/118828 [00:25<02:59, 578.34it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15036/118828 [00:25<04:20, 397.72it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15121/118828 [00:25<03:30, 492.10it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15225/118828 [00:25<02:58, 578.95it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15290/118828 [00:25<03:26, 501.85it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15377/118828 [00:25<03:10, 542.88it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15449/118828 [00:26<03:29, 492.91it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15513/118828 [00:26<03:20, 515.46it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15585/118828 [00:26<03:18, 518.87it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15640/118828 [00:26<03:23, 507.23it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15721/118828 [00:26<03:02, 564.94it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15780/118828 [00:26<03:05, 556.52it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15857/118828 [00:26<02:51, 600.29it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15921/118828 [00:26<03:04, 557.87it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 15979/118828 [00:27<03:22, 507.04it/s]
# Dual-gate cointegration (EG + Johansen):  13%|█▎        | 16033/118828 [00:27<03:30, 488.45it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16129/118828 [00:27<02:51, 599.38it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16192/118828 [00:27<03:10, 538.53it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16273/118828 [00:27<02:51, 599.08it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▎        | 16336/118828 [00:27<03:00, 568.44it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16409/118828 [00:27<02:57, 577.64it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16469/118828 [00:27<03:03, 557.56it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16537/118828 [00:28<03:00, 566.61it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16617/118828 [00:28<02:48, 608.20it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16679/118828 [00:28<02:47, 608.22it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16741/118828 [00:28<03:11, 533.22it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16809/118828 [00:28<03:01, 562.48it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16867/118828 [00:28<03:41, 461.21it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 16977/118828 [00:28<02:55, 580.29it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17065/118828 [00:28<02:43, 622.59it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17131/118828 [00:29<02:50, 595.68it/s]
# Dual-gate cointegration (EG + Johansen):  14%|█▍        | 17217/118828 [00:29<02:57, 572.08it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17305/118828 [00:29<02:43, 621.96it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17370/118828 [00:29<02:49, 599.93it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17433/118828 [00:29<02:58, 566.95it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17513/118828 [00:29<02:51, 590.83it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17593/118828 [00:29<02:47, 605.06it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17654/118828 [00:29<02:49, 595.62it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17729/118828 [00:30<02:53, 583.43it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▍        | 17788/118828 [00:30<02:53, 583.33it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17847/118828 [00:30<03:02, 553.68it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17903/118828 [00:30<03:10, 528.75it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 17977/118828 [00:30<02:59, 562.68it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18034/118828 [00:30<03:03, 549.73it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18105/118828 [00:30<03:00, 557.29it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18161/118828 [00:30<03:13, 520.11it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18233/118828 [00:31<03:19, 504.91it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18337/118828 [00:31<02:45, 606.08it/s]
# Dual-gate cointegration (EG + Johansen):  15%|█▌        | 18399/118828 [00:31<02:52, 581.25it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18465/118828 [00:31<02:50, 588.40it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18525/118828 [00:31<03:00, 555.07it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18593/118828 [00:31<03:18, 505.75it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18681/118828 [00:31<03:09, 528.78it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18753/118828 [00:31<02:57, 563.59it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18811/118828 [00:32<02:59, 557.75it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18889/118828 [00:32<02:48, 594.61it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 18950/118828 [00:32<02:52, 579.90it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19025/118828 [00:32<02:47, 596.81it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19085/118828 [00:32<02:59, 555.14it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19177/118828 [00:32<02:36, 636.90it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▌        | 19242/118828 [00:32<03:08, 528.69it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19321/118828 [00:32<02:49, 587.69it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19384/118828 [00:33<02:52, 578.02it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19445/118828 [00:33<03:02, 545.53it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19502/118828 [00:33<03:14, 509.94it/s]
# Dual-gate cointegration (EG + Johansen):  16%|█▋        | 19585/118828 [00:33<02:52, 576.33it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19645/118828 [00:33<03:01, 546.26it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19713/118828 [00:33<02:59, 551.57it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19793/118828 [00:33<02:56, 561.22it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19850/118828 [00:33<03:00, 547.63it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 19906/118828 [00:34<03:36, 456.30it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20009/118828 [00:34<02:53, 569.60it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20081/118828 [00:34<02:44, 602.04it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20145/118828 [00:34<02:51, 575.74it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20217/118828 [00:34<02:47, 587.38it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20281/118828 [00:34<02:55, 560.75it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20353/118828 [00:34<03:06, 527.26it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20433/118828 [00:35<03:02, 540.35it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20521/118828 [00:35<02:38, 619.65it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20586/118828 [00:35<02:45, 592.48it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20647/118828 [00:35<02:49, 579.40it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20706/118828 [00:35<02:56, 556.28it/s]
# Dual-gate cointegration (EG + Johansen):  17%|█▋        | 20763/118828 [00:35<03:01, 541.35it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20841/118828 [00:35<02:43, 598.38it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20902/118828 [00:35<02:42, 600.97it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 20963/118828 [00:35<02:43, 599.80it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21033/118828 [00:35<02:41, 604.19it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21094/118828 [00:36<02:58, 547.47it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21150/118828 [00:36<02:59, 543.77it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21225/118828 [00:36<03:05, 525.94it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21297/118828 [00:36<02:52, 566.16it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21355/118828 [00:36<02:58, 544.95it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21457/118828 [00:36<02:36, 623.03it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21520/118828 [00:36<02:46, 583.47it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21593/118828 [00:36<02:45, 587.76it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21652/118828 [00:37<02:47, 581.89it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21721/118828 [00:37<02:44, 589.16it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21780/118828 [00:37<02:50, 570.54it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21849/118828 [00:37<02:41, 602.07it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21910/118828 [00:37<02:48, 573.71it/s]
# Dual-gate cointegration (EG + Johansen):  18%|█▊        | 21969/118828 [00:37<02:51, 565.50it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22026/118828 [00:37<02:54, 555.67it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22082/118828 [00:37<03:13, 500.51it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▊        | 22169/118828 [00:38<03:35, 449.57it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22297/118828 [00:38<02:42, 592.91it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22360/118828 [00:38<03:01, 532.70it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22425/118828 [00:38<03:00, 533.51it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22481/118828 [00:38<03:16, 489.94it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22545/118828 [00:38<03:40, 435.67it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22591/118828 [00:38<03:40, 437.07it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22637/118828 [00:39<04:20, 368.82it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22729/118828 [00:39<03:30, 455.51it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22801/118828 [00:39<03:22, 474.77it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22873/118828 [00:39<03:05, 517.56it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 22945/118828 [00:39<02:53, 552.86it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23017/118828 [00:39<02:44, 580.87it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23077/118828 [00:39<02:45, 579.00it/s]
# Dual-gate cointegration (EG + Johansen):  19%|█▉        | 23137/118828 [00:40<03:09, 504.37it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23241/118828 [00:40<02:36, 612.54it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23329/118828 [00:40<02:42, 586.65it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23390/118828 [00:40<02:45, 578.23it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23450/118828 [00:40<02:58, 533.49it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23561/118828 [00:40<02:26, 649.53it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23628/118828 [00:40<02:35, 613.62it/s]
# Dual-gate cointegration (EG + Johansen):  20%|█▉        | 23705/118828 [00:40<02:47, 568.70it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23769/118828 [00:41<02:43, 583.16it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23829/118828 [00:41<02:42, 585.69it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23889/118828 [00:41<02:52, 551.85it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 23961/118828 [00:41<03:04, 515.19it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24025/118828 [00:41<02:59, 526.88it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24105/118828 [00:41<02:52, 548.18it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24209/118828 [00:41<02:31, 624.30it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24272/118828 [00:41<02:50, 555.80it/s]
# Dual-gate cointegration (EG + Johansen):  20%|██        | 24329/118828 [00:42<03:00, 524.38it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24382/118828 [00:42<03:13, 486.95it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24432/118828 [00:42<03:38, 432.38it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24497/118828 [00:42<03:33, 442.09it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24577/118828 [00:42<03:10, 495.07it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24633/118828 [00:42<03:14, 485.12it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24729/118828 [00:42<02:42, 579.05it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24793/118828 [00:43<02:46, 566.46it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24865/118828 [00:43<02:42, 578.28it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 24924/118828 [00:43<03:07, 499.88it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25009/118828 [00:43<02:41, 579.62it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25081/118828 [00:43<02:38, 592.04it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25145/118828 [00:43<02:38, 592.49it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██        | 25209/118828 [00:43<02:36, 597.81it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25270/118828 [00:43<02:38, 591.63it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25337/118828 [00:43<02:42, 574.46it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25396/118828 [00:44<02:43, 571.70it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25473/118828 [00:44<02:36, 594.98it/s]
# Dual-gate cointegration (EG + Johansen):  21%|██▏       | 25537/118828 [00:44<02:41, 578.16it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25601/118828 [00:44<02:36, 594.61it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25665/118828 [00:44<02:44, 567.62it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25737/118828 [00:44<02:36, 595.22it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25797/118828 [00:44<02:42, 574.14it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25873/118828 [00:44<02:37, 591.96it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 25937/118828 [00:44<02:42, 571.40it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26001/118828 [00:45<02:40, 579.69it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26060/118828 [00:45<02:54, 530.66it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26121/118828 [00:45<02:48, 551.42it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26177/118828 [00:45<03:02, 507.94it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26229/118828 [00:45<03:05, 499.68it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26305/118828 [00:45<03:00, 512.28it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26369/118828 [00:45<02:54, 530.64it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26423/118828 [00:45<03:07, 492.85it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26497/118828 [00:46<03:09, 487.48it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26553/118828 [00:46<03:08, 488.50it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26625/118828 [00:46<02:48, 546.73it/s]
# Dual-gate cointegration (EG + Johansen):  22%|██▏       | 26681/118828 [00:46<03:04, 498.62it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26769/118828 [00:46<02:38, 581.80it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26829/118828 [00:46<02:54, 528.09it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26905/118828 [00:46<02:53, 531.27it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 26977/118828 [00:46<02:58, 514.84it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27033/118828 [00:47<03:00, 507.24it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27113/118828 [00:47<02:54, 525.46it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27166/118828 [00:47<03:04, 497.72it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27233/118828 [00:47<02:49, 539.32it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27288/118828 [00:47<02:53, 528.02it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27361/118828 [00:47<02:45, 551.25it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27417/118828 [00:47<02:54, 523.06it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27489/118828 [00:47<02:44, 556.15it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27545/118828 [00:48<03:53, 390.33it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27657/118828 [00:48<02:54, 523.02it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27737/118828 [00:48<02:38, 575.86it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27802/118828 [00:48<02:45, 549.45it/s]
# Dual-gate cointegration (EG + Johansen):  23%|██▎       | 27873/118828 [00:48<02:41, 561.94it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 27933/118828 [00:48<02:42, 559.99it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 27993/118828 [00:48<02:48, 537.68it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28057/118828 [00:49<02:42, 557.92it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28115/118828 [00:49<02:47, 542.00it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▎       | 28171/118828 [00:49<02:46, 543.02it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28226/118828 [00:49<02:56, 511.90it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28297/118828 [00:49<02:48, 536.41it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28377/118828 [00:49<02:43, 552.14it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28449/118828 [00:49<02:34, 583.83it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28508/118828 [00:49<02:34, 583.50it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28577/118828 [00:49<02:29, 603.59it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28638/118828 [00:50<02:29, 602.68it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28699/118828 [00:50<02:36, 577.61it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28761/118828 [00:50<02:43, 550.95it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28825/118828 [00:50<02:39, 565.33it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28889/118828 [00:50<02:43, 549.68it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 28977/118828 [00:50<02:23, 627.56it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29041/118828 [00:50<02:26, 613.23it/s]
# Dual-gate cointegration (EG + Johansen):  24%|██▍       | 29103/118828 [00:50<02:34, 580.20it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29177/118828 [00:50<02:38, 564.15it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29249/118828 [00:51<02:36, 571.13it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29307/118828 [00:51<02:52, 519.70it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29377/118828 [00:51<02:39, 560.33it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29435/118828 [00:51<03:10, 468.27it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29505/118828 [00:51<02:52, 516.78it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29569/118828 [00:51<02:46, 536.92it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29626/118828 [00:51<02:46, 536.22it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▍       | 29689/118828 [00:51<02:40, 556.61it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29747/118828 [00:52<02:38, 563.03it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29805/118828 [00:52<02:49, 525.96it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29865/118828 [00:52<02:43, 545.27it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29921/118828 [00:52<02:43, 543.07it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 29993/118828 [00:52<02:42, 547.28it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30057/118828 [00:52<03:07, 473.37it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30129/118828 [00:52<02:46, 532.45it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30225/118828 [00:52<02:35, 571.46it/s]
# Dual-gate cointegration (EG + Johansen):  25%|██▌       | 30289/118828 [00:53<02:31, 585.71it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30353/118828 [00:53<02:31, 582.91it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30413/118828 [00:53<02:35, 567.27it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30471/118828 [00:53<02:53, 508.91it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30553/118828 [00:53<02:31, 584.11it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30617/118828 [00:53<02:32, 576.95it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30681/118828 [00:53<02:41, 546.23it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30737/118828 [00:53<02:40, 549.24it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30793/118828 [00:53<02:42, 540.49it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30873/118828 [00:54<02:44, 534.40it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 30927/118828 [00:54<02:45, 529.94it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31009/118828 [00:54<02:42, 541.60it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31073/118828 [00:54<02:39, 549.45it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▌       | 31145/118828 [00:54<02:35, 562.47it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31202/118828 [00:54<02:43, 537.12it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31273/118828 [00:54<02:50, 513.14it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31377/118828 [00:55<02:44, 533.03it/s]
# Dual-gate cointegration (EG + Johansen):  26%|██▋       | 31449/118828 [00:55<02:37, 554.29it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31513/118828 [00:55<02:43, 533.44it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31577/118828 [00:55<02:41, 538.77it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31633/118828 [00:55<02:42, 537.03it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31713/118828 [00:55<02:35, 561.31it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31770/118828 [00:55<02:39, 545.53it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31841/118828 [00:55<02:38, 549.15it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31897/118828 [00:56<02:54, 499.48it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 31985/118828 [00:56<02:26, 593.43it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32047/118828 [00:56<02:28, 585.84it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32107/118828 [00:56<02:28, 584.09it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32167/118828 [00:56<02:44, 527.34it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32222/118828 [00:56<02:47, 515.53it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32281/118828 [00:56<02:49, 511.65it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32353/118828 [00:56<02:39, 543.63it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32408/118828 [00:56<02:50, 507.64it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32473/118828 [00:57<02:42, 532.48it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32537/118828 [00:57<02:42, 529.76it/s]
# Dual-gate cointegration (EG + Johansen):  27%|██▋       | 32601/118828 [00:57<02:43, 528.02it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32697/118828 [00:57<02:22, 604.60it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32758/118828 [00:57<02:22, 604.37it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32833/118828 [00:57<02:17, 627.69it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32896/118828 [00:57<02:29, 574.95it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 32969/118828 [00:57<02:24, 595.62it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33033/118828 [00:58<02:35, 551.70it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33105/118828 [00:58<02:34, 554.24it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33177/118828 [00:58<02:31, 565.47it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33234/118828 [00:58<02:34, 554.59it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33290/118828 [00:58<02:33, 555.66it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33361/118828 [00:58<02:27, 579.43it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33420/118828 [00:58<02:32, 559.69it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33481/118828 [00:58<02:33, 555.04it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33561/118828 [00:58<02:23, 593.24it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33621/118828 [00:59<02:33, 555.24it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33713/118828 [00:59<02:16, 624.15it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33776/118828 [00:59<02:37, 539.13it/s]
# Dual-gate cointegration (EG + Johansen):  28%|██▊       | 33857/118828 [00:59<02:21, 600.34it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33920/118828 [00:59<02:57, 479.58it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 33993/118828 [00:59<03:09, 448.50it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34042/118828 [00:59<03:13, 437.31it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▊       | 34121/118828 [01:00<03:05, 457.78it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34249/118828 [01:00<02:44, 514.64it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34369/118828 [01:00<02:13, 634.75it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34437/118828 [01:00<02:43, 515.65it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34505/118828 [01:00<02:35, 542.79it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34565/118828 [01:00<02:36, 538.34it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34633/118828 [01:01<02:33, 549.40it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34691/118828 [01:01<02:31, 553.93it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34761/118828 [01:01<02:42, 516.76it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34815/118828 [01:01<03:28, 403.55it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 34945/118828 [01:01<02:26, 572.23it/s]
# Dual-gate cointegration (EG + Johansen):  29%|██▉       | 35010/118828 [01:01<02:30, 555.81it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35071/118828 [01:01<02:29, 560.83it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35137/118828 [01:02<02:46, 503.73it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35209/118828 [01:02<02:44, 506.92it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35265/118828 [01:02<02:53, 480.32it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35315/118828 [01:02<02:52, 484.03it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35393/118828 [01:02<02:51, 487.32it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35473/118828 [01:02<02:32, 545.52it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35529/118828 [01:02<02:40, 517.83it/s]
# Dual-gate cointegration (EG + Johansen):  30%|██▉       | 35617/118828 [01:02<02:21, 589.27it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35678/118828 [01:03<03:00, 461.84it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35769/118828 [01:03<02:39, 522.07it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35825/118828 [01:03<02:54, 475.99it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35913/118828 [01:03<02:34, 535.58it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 35970/118828 [01:03<02:34, 536.57it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36041/118828 [01:03<02:22, 579.09it/s]
# Dual-gate cointegration (EG + Johansen):  30%|███       | 36102/118828 [01:03<02:31, 547.24it/s]
# ...
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108175/118828 [03:13<00:19, 550.92it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108249/118828 [03:13<00:18, 576.92it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108308/118828 [03:13<00:19, 540.54it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████ | 108377/118828 [03:13<00:18, 572.53it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108441/118828 [03:13<00:19, 536.50it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108529/118828 [03:13<00:19, 539.62it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108625/118828 [03:13<00:17, 594.84it/s]
# Dual-gate cointegration (EG + Johansen):  91%|█████████▏| 108686/118828 [03:14<00:19, 517.48it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108785/118828 [03:14<00:16, 617.51it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108851/118828 [03:14<00:17, 571.49it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108921/118828 [03:14<00:17, 571.79it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 108985/118828 [03:14<00:16, 587.34it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109049/118828 [03:14<00:18, 524.23it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109153/118828 [03:14<00:14, 647.91it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109222/118828 [03:15<00:18, 530.33it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109305/118828 [03:15<00:17, 536.49it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109409/118828 [03:15<00:14, 638.19it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109479/118828 [03:15<00:17, 525.43it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109561/118828 [03:15<00:16, 557.93it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109641/118828 [03:15<00:15, 606.77it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109707/118828 [03:15<00:16, 545.62it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109801/118828 [03:16<00:14, 625.78it/s]
# Dual-gate cointegration (EG + Johansen):  92%|█████████▏| 109869/118828 [03:16<00:16, 547.07it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 109937/118828 [03:16<00:15, 555.98it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 109996/118828 [03:16<00:15, 558.15it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110073/118828 [03:16<00:15, 580.18it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110133/118828 [03:16<00:15, 571.14it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110201/118828 [03:16<00:15, 564.00it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110265/118828 [03:16<00:15, 566.89it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110329/118828 [03:17<00:15, 551.69it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110417/118828 [03:17<00:14, 586.81it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110476/118828 [03:17<00:15, 551.38it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110569/118828 [03:17<00:13, 608.38it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110630/118828 [03:17<00:14, 552.92it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110697/118828 [03:17<00:13, 581.33it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110756/118828 [03:17<00:14, 546.35it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110825/118828 [03:17<00:14, 549.43it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110905/118828 [03:17<00:13, 596.12it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 110966/118828 [03:18<00:14, 561.49it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111025/118828 [03:18<00:14, 550.85it/s]
# Dual-gate cointegration (EG + Johansen):  93%|█████████▎| 111097/118828 [03:18<00:13, 564.28it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111169/118828 [03:18<00:12, 589.80it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111229/118828 [03:18<00:13, 566.19it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111289/118828 [03:18<00:13, 574.81it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▎| 111353/118828 [03:18<00:12, 584.82it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111412/118828 [03:18<00:12, 576.64it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111481/118828 [03:18<00:12, 590.49it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111541/118828 [03:19<00:12, 566.20it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111617/118828 [03:19<00:12, 580.87it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111676/118828 [03:19<00:12, 574.19it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111745/118828 [03:19<00:12, 572.41it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111817/118828 [03:19<00:12, 547.75it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111889/118828 [03:19<00:11, 581.60it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 111948/118828 [03:19<00:12, 551.98it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112004/118828 [03:19<00:13, 518.37it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112081/118828 [03:20<00:11, 574.67it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112140/118828 [03:20<00:12, 535.01it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112217/118828 [03:20<00:11, 590.07it/s]
# Dual-gate cointegration (EG + Johansen):  94%|█████████▍| 112278/118828 [03:20<00:11, 562.22it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112361/118828 [03:20<00:10, 597.12it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112425/118828 [03:20<00:11, 580.85it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112489/118828 [03:20<00:11, 546.50it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112577/118828 [03:20<00:10, 586.68it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112641/118828 [03:21<00:11, 536.79it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112729/118828 [03:21<00:10, 584.64it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112793/118828 [03:21<00:10, 582.55it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▍| 112857/118828 [03:21<00:10, 593.42it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112917/118828 [03:21<00:10, 582.15it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 112985/118828 [03:21<00:09, 592.66it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113049/118828 [03:21<00:09, 603.28it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113110/118828 [03:21<00:10, 570.60it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113169/118828 [03:21<00:09, 571.64it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113233/118828 [03:22<00:09, 563.47it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113290/118828 [03:22<00:09, 556.96it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113361/118828 [03:22<00:09, 598.48it/s]
# Dual-gate cointegration (EG + Johansen):  95%|█████████▌| 113422/118828 [03:22<00:09, 564.49it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113481/118828 [03:22<00:09, 550.97it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113537/118828 [03:22<00:09, 544.26it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113617/118828 [03:22<00:08, 583.27it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113676/118828 [03:22<00:09, 546.43it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113753/118828 [03:23<00:08, 565.45it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113817/118828 [03:23<00:08, 576.26it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113881/118828 [03:23<00:08, 577.65it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 113939/118828 [03:23<00:08, 561.24it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114009/118828 [03:23<00:08, 558.77it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114089/118828 [03:23<00:07, 595.77it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114153/118828 [03:23<00:08, 581.73it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114212/118828 [03:23<00:08, 567.55it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114273/118828 [03:23<00:07, 569.93it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▌| 114330/118828 [03:24<00:07, 568.45it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114393/118828 [03:24<00:07, 578.79it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114451/118828 [03:24<00:07, 562.63it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114513/118828 [03:24<00:07, 577.49it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114571/118828 [03:24<00:07, 568.03it/s]
# Dual-gate cointegration (EG + Johansen):  96%|█████████▋| 114633/118828 [03:24<00:07, 579.85it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114692/118828 [03:24<00:07, 526.82it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114785/118828 [03:24<00:06, 593.57it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114845/118828 [03:24<00:07, 562.91it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114921/118828 [03:25<00:06, 558.81it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 114978/118828 [03:25<00:06, 558.61it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115041/118828 [03:25<00:06, 571.88it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115099/118828 [03:25<00:06, 573.27it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115169/118828 [03:25<00:06, 607.67it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115231/118828 [03:25<00:06, 566.31it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115297/118828 [03:25<00:07, 488.98it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115409/118828 [03:25<00:05, 586.46it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115469/118828 [03:26<00:05, 576.91it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115545/118828 [03:26<00:05, 601.05it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115606/118828 [03:26<00:05, 590.29it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115666/118828 [03:26<00:05, 565.98it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115723/118828 [03:26<00:05, 535.02it/s]
# Dual-gate cointegration (EG + Johansen):  97%|█████████▋| 115801/118828 [03:26<00:05, 575.24it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115859/118828 [03:26<00:05, 575.08it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115929/118828 [03:26<00:04, 588.62it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 115993/118828 [03:26<00:04, 584.30it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116057/118828 [03:27<00:04, 566.62it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116137/118828 [03:27<00:04, 593.90it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116197/118828 [03:27<00:04, 580.22it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116265/118828 [03:27<00:04, 595.03it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116325/118828 [03:27<00:04, 526.17it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116409/118828 [03:27<00:04, 589.65it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116470/118828 [03:27<00:04, 556.32it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116537/118828 [03:27<00:04, 547.48it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116593/118828 [03:27<00:04, 546.16it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116665/118828 [03:28<00:03, 557.73it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116722/118828 [03:28<00:03, 554.94it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116793/118828 [03:28<00:03, 556.15it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116849/118828 [03:28<00:03, 554.68it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 116921/118828 [03:28<00:03, 494.84it/s]
# Dual-gate cointegration (EG + Johansen):  98%|█████████▊| 117025/118828 [03:28<00:03, 575.39it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117084/118828 [03:28<00:03, 569.76it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117153/118828 [03:28<00:02, 588.84it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117213/118828 [03:29<00:02, 555.59it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▊| 117289/118828 [03:29<00:02, 606.04it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117351/118828 [03:29<00:02, 554.94it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117409/118828 [03:29<00:02, 559.18it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117473/118828 [03:29<00:02, 576.01it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117537/118828 [03:29<00:02, 557.76it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117594/118828 [03:29<00:02, 551.96it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117665/118828 [03:29<00:02, 579.50it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117729/118828 [03:29<00:01, 592.49it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117793/118828 [03:30<00:01, 566.30it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117851/118828 [03:30<00:01, 570.00it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117921/118828 [03:30<00:01, 584.79it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 117980/118828 [03:30<00:01, 558.25it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118049/118828 [03:30<00:01, 548.83it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118129/118828 [03:30<00:01, 576.70it/s]
# Dual-gate cointegration (EG + Johansen):  99%|█████████▉| 118201/118828 [03:30<00:01, 613.86it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118263/118828 [03:30<00:00, 578.09it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118322/118828 [03:31<00:00, 576.69it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118385/118828 [03:31<00:00, 523.25it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118465/118828 [03:31<00:00, 591.15it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118526/118828 [03:31<00:00, 558.60it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118601/118828 [03:31<00:00, 587.37it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118673/118828 [03:31<00:00, 566.19it/s]
# Dual-gate cointegration (EG + Johansen): 100%|█████████▉| 118737/118828 [03:31<00:00, 564.69it/s]
# Total pairs screened : 118,828
# Dual-gate pass (verdict=='pass'): 6102
#                      eg_t          eg_p  eg_pass   joh_stat  joh_pass verdict
# ticker1 ticker2
# NCLH    SHOP    -6.892330  1.544746e-08     True  37.268515      True    pass
#         TRMB    -6.774412  2.923744e-08     True  42.340817      True    pass
#         ZBRA    -6.725933  3.793752e-08     True  36.397732      True    pass
#         XYZ     -6.691579  4.559848e-08     True  34.453662      True    pass
#         SBUX    -6.533492  1.055287e-07     True  38.528619      True    pass

# %% [markdown]
# ## 2.2 Pre-scoring: rank candidates for Kalman filtering
#
# We rank all pairs by a composite rank score (EG p-value + Johansen statistic) and
# take the top 200 as candidates for the computationally expensive Kalman step.

# %%
tmp = summary_dual.copy()
# Gate on the FDR survivors BEFORE the rank cut. Benjamini-Hochberg is a monotone
# transform of the sorted p-values, so it cannot reorder a rank -- which is why
# correcting and not correcting used to give byte-identical shortlists. Filtering
# on the verdict is what makes the correction bind on anything downstream.
_passed = tmp["eg_pass_fdr"] & tmp["joh_pass"] if "eg_pass_fdr" in tmp.columns else tmp["verdict"].eq("pass")
print(f"dual-gate survivors under the correction: {int(_passed.sum()):,} of {len(tmp):,}")
tmp = tmp.loc[_passed] if int(_passed.sum()) >= 20 else tmp
tmp["rank_eg"]  = tmp["eg_p"].rank(method="average", ascending=True)
tmp["rank_joh"] = tmp["joh_stat"].rank(method="average", ascending=False)
tmp["pre_score"] = 0.5 * (tmp["rank_eg"] / tmp["rank_eg"].max()
                         + tmp["rank_joh"] / tmp["rank_joh"].max())
prelim     = tmp.sort_values("pre_score", ascending=True)
candidates = prelim.head(200).index.to_list()
print(f"Candidates selected for Kalman filtering: {len(candidates)}")
# Out:
# dual-gate survivors under the correction: 6,102 of 118,828
# Candidates selected for Kalman filtering: 200

# %% [markdown]
# # 3. Kalman Filter Hedge Estimation & Stationarity Scoring
#
# ## 3.1 Kalman filter model overview
#
# We estimate a **time-varying** hedge ratio $\beta_t$ via a linear Gaussian state-space model.
#
# **State (random walk):**
# $$
# \theta_t = \begin{bmatrix}\beta_t \\ \alpha_t\end{bmatrix}, \qquad
# \theta_t = \theta_{t-1} + w_t, \quad w_t \sim \mathcal{N}(0, Q)
# $$
#
# **Observation:**
# $$
# y_t = \alpha_t + \beta_t x_t + v_t, \quad v_t \sim \mathcal{N}(0, R)
# $$
#
# Parameters $Q$ and $R$ are learned by EM; the recursion is then run in **filter mode**
# (the causal forward pass) for both the in-sample residuals and the OOS evaluation. The RTS
# smoother is never used: it conditions the state at bar $t$ on the whole sample, which would
# leak the future into the residual a signal reads.

# %%
from pairs import fit_kalman_hedge, summarize_spread_stationarity_joblib

states_tr, params_tr = fit_kalman_hedge(
    df_train,
    pairs=candidates,
    mode="filter",   # causal: the smoother would let each state see the future
    em_iters=5,
    q=1e-5,
    n_workers=None,
    chunksize=100,
    show_progress=True,
    return_params=True,
)
print(f"Kalman states computed for {len(states_tr)} pairs")
# Out:
# Kalman (α_t, β_t):   0%|          | 0/200 [00:00<?, ?it/s]
# Kalman (α_t, β_t):   1%|          | 2/200 [00:03<05:08,  1.56s/it]
# Kalman (α_t, β_t):  10%|█         | 20/200 [00:03<00:21,  8.48it/s]
# Kalman (α_t, β_t):  16%|█▋        | 33/200 [00:04<00:16, 10.08it/s]
# Kalman (α_t, β_t):  21%|██        | 42/200 [00:04<00:11, 14.01it/s]
# Kalman (α_t, β_t):  24%|██▍       | 49/200 [00:05<00:13, 11.05it/s]
# Kalman (α_t, β_t):  27%|██▋       | 54/200 [00:05<00:11, 13.25it/s]
# Kalman (α_t, β_t):  32%|███▏      | 63/200 [00:05<00:07, 17.67it/s]
# Kalman (α_t, β_t):  34%|███▍      | 68/200 [00:06<00:11, 11.68it/s]
# Kalman (α_t, β_t):  39%|███▉      | 78/200 [00:06<00:06, 17.68it/s]
# Kalman (α_t, β_t):  42%|████▏     | 84/200 [00:07<00:09, 11.73it/s]
# Kalman (α_t, β_t):  46%|████▋     | 93/200 [00:07<00:06, 16.40it/s]
# Kalman (α_t, β_t):  49%|████▉     | 98/200 [00:08<00:09, 11.22it/s]
# Kalman (α_t, β_t):  52%|█████▏    | 104/200 [00:08<00:06, 14.37it/s]
# Kalman (α_t, β_t):  55%|█████▍    | 109/200 [00:09<00:05, 16.92it/s]
# Kalman (α_t, β_t):  57%|█████▋    | 114/200 [00:10<00:07, 10.82it/s]
# Kalman (α_t, β_t):  60%|██████    | 120/200 [00:10<00:05, 14.10it/s]
# Kalman (α_t, β_t):  64%|██████▎   | 127/200 [00:10<00:03, 18.86it/s]
# Kalman (α_t, β_t):  66%|██████▌   | 132/200 [00:11<00:05, 11.48it/s]
# Kalman (α_t, β_t):  69%|██████▉   | 138/200 [00:11<00:04, 15.05it/s]
# Kalman (α_t, β_t):  71%|███████   | 142/200 [00:11<00:03, 16.85it/s]
# Kalman (α_t, β_t):  73%|███████▎  | 146/200 [00:12<00:05, 10.54it/s]
# Kalman (α_t, β_t):  74%|███████▍  | 149/200 [00:12<00:04, 11.88it/s]
# Kalman (α_t, β_t):  78%|███████▊  | 156/200 [00:12<00:02, 17.22it/s]
# Kalman (α_t, β_t):  80%|████████  | 160/200 [00:12<00:02, 17.99it/s]
# Kalman (α_t, β_t):  82%|████████▏ | 163/200 [00:13<00:03, 10.79it/s]
# Kalman (α_t, β_t):  83%|████████▎ | 166/200 [00:13<00:02, 11.99it/s]
# Kalman (α_t, β_t):  86%|████████▌ | 172/200 [00:13<00:01, 16.62it/s]
# Kalman (α_t, β_t):  88%|████████▊ | 176/200 [00:13<00:01, 17.38it/s]
# Kalman (α_t, β_t):  90%|████████▉ | 179/200 [00:14<00:01, 10.69it/s]
# Kalman (α_t, β_t):  90%|█████████ | 181/200 [00:14<00:01, 11.33it/s]
# Kalman (α_t, β_t):  93%|█████████▎| 186/200 [00:14<00:00, 15.96it/s]
# Kalman (α_t, β_t):  94%|█████████▍| 189/200 [00:14<00:00, 17.85it/s]
# Kalman (α_t, β_t):  96%|█████████▌| 192/200 [00:15<00:00, 19.84it/s]
# Kalman (α_t, β_t):  98%|█████████▊| 195/200 [00:15<00:00, 12.08it/s]
# Kalman (α_t, β_t):  99%|█████████▉| 198/200 [00:15<00:00, 14.09it/s]
# Kalman states computed for 200 pairs

# %% [markdown]
# ## 3.2 Spread stationarity diagnostics
#
# For each pair we run:
# 1. **ADF** (Augmented Dickey-Fuller) — reject $H_0$ of unit root → spread is I(0)
# 2. **KPSS** — fail to reject $H_0$ of stationarity → spread is I(0)
#
# **Verdict**: `stationary` if ADF rejects AND KPSS does not reject; `non-stationary` if vice versa;
# `inconclusive` otherwise.
#
# Additional diagnostics: **half-life** (AR(1) proxy for mean-reversion speed) and
# **residual sigma** (spread volatility).

# %%
summary_stationarity = summarize_spread_stationarity_joblib(
    states_tr, alpha=0.05, regression="c", chunksize=256, show_progress=True
)
print(f"\n{len(summary_stationarity)} pairs tested")
summary_stationarity.head(10)
# Out:
# Testing stationarity:   0%|          | 0/200 [00:00<?, ?it/s]
# Testing stationarity:   1%|          | 2/200 [00:00<01:25,  2.32it/s]
# Testing stationarity:  32%|███▏      | 64/200 [00:00<00:01, 89.80it/s]
# Testing stationarity:  72%|███████▏  | 143/200 [00:01<00:00, 207.43it/s]
# 200 pairs tested
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# NCLH    ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
#         VICI    -12.742477  8.883603e-24   0.554256  0.029447  1.525712
# CCL     NWS     -10.183337  6.606414e-18   0.907258  0.010000  2.153599
#         NWSA     -9.949875  2.531373e-17   0.929327  0.010000  2.286437
# NCLH    WY       -9.567755  2.332259e-16   0.562237  0.027649  1.378453
# CCL     GM       -9.044586  5.026671e-15   0.691584  0.014311  0.927928
#         COF      -8.909964  1.111177e-14   0.852376  0.010000  0.733056
#         DLR      -8.896328  1.204185e-14   0.465979  0.049329  0.613365
# NCLH    TDY      -8.631832  5.727872e-14   0.465533  0.049430  0.602453
# CCL     EQIX     -8.606261  6.659842e-14   0.555863  0.029085  0.645483
#
#                  resid_sigma    shapre       verdict
# ticker1 ticker2
# NCLH    ZBH         0.272626 -0.013607  inconclusive
#         VICI        0.703102 -0.056798  inconclusive
# CCL     NWS         0.772486 -0.077707  inconclusive
#         NWSA        0.798079 -0.080570  inconclusive
# NCLH    WY          0.645115 -0.048115  inconclusive
# CCL     GM          0.380726  0.012253  inconclusive
#         COF         0.276555 -0.015717  inconclusive
#         DLR         0.215440 -0.041952  inconclusive
# NCLH    TDY         0.235948 -0.017003  inconclusive
# CCL     EQIX        0.226906 -0.026816  inconclusive

# %% [markdown]
# ## 3.3 Composite scoring
#
# Convert heterogeneous metrics into comparable z-scores (higher = better), then take a
# weighted sum:
#
# | Metric | Transform | Direction |
# |--------|-----------|-----------|
# | ADF p-value | $-\log_{10}(p)$ then $Z(\cdot)$ | smaller p → better |
# | KPSS p-value | $Z(p)$ | larger p → better |
# | Half-life | $-\log(1+\text{hl})$ then $Z(\cdot)$ | shorter → better |
# | Residual sigma | $Z(-\sigma)$ | smaller → better |
# | Sharpe (train) | $Z(\text{Sharpe})$ | higher → better |
#
# > ℹ️ **All five rows contribute.** The summary function emits the column under the misspelling
# > `shapre`. The scoring cell used to read `sharpe_train` through `.get(..., 0.0)`, so the lookup
# > returned a constant zero and the ranking ran on four metrics; it now reads `shapre` directly.
# > The shortlist moved when this was fixed.

# %%
from pairs.stats import Z

final_df = summary_stationarity.copy()
for col in ["adf_p", "kpss_p", "halflife", "resid_sigma", "shapre"]:
    if col in final_df.columns:
        final_df[col] = pd.to_numeric(final_df[col], errors="coerce")

# the summary function emits this column as "shapre"; reading "sharpe_train"
# silently returned a constant 0.0, so this term contributed nothing at all
sharpe_series = final_df.get("shapre", pd.Series(0.0, index=final_df.index))
p_adf   = final_df["adf_p"].clip(lower=1e-300, upper=1.0)
p_kpss  = final_df["kpss_p"].clip(lower=1e-300, upper=1.0)
hl_safe = final_df["halflife"].clip(lower=0)

components = {
    "adf":    Z(-np.log10(p_adf)),
    "kpss":   Z(p_kpss),
    "hl":     Z(-np.log1p(hl_safe)),
    "sigma":  Z(-final_df["resid_sigma"]),
    "sharpe": Z(sharpe_series),
}
weights = {k: 1.0 for k in components}
final_df["score"] = sum(weights[k] * components[k] for k in components)
ranked = final_df.sort_values("score", ascending=False)
ranked.head(10)
# Out:
#                   adf_stat         adf_p  kpss_stat    kpss_p  halflife  \
# ticker1 ticker2
# BKNG    MA      -26.184819  0.000000e+00   0.107466  0.100000  0.374708
# AVGO    RL      -20.604764  0.000000e+00   0.038229  0.100000  0.461536
# HSIC    PLD     -20.181146  0.000000e+00   0.026152  0.100000  0.827721
# NCLH    REG     -23.778528  0.000000e+00   0.244832  0.100000  0.886268
#         ZBH     -27.742492  0.000000e+00   0.464890  0.049574  0.615152
# BA      JKHY    -20.661471  0.000000e+00   0.197209  0.100000  0.670420
# CRM     EQIX    -17.680054  3.611653e-30   0.036575  0.100000  0.204733
# NCLH    SBAC     -9.112234  3.375238e-15   0.339735  0.100000  0.564747
#         NTRS     -7.356914  9.725985e-11   0.245896  0.100000  0.725062
# HSIC    JBHT     -9.291383  1.177221e-15   0.035744  0.100000  0.736163
#
#                  resid_sigma    shapre       verdict     score
# ticker1 ticker2
# BKNG    MA          0.363197 -0.001418    stationary  9.113378
# AVGO    RL          0.540440 -0.009011    stationary  8.415701
# HSIC    PLD         0.547642 -0.006295    stationary  7.727495
# NCLH    REG         0.384512 -0.032411    stationary  7.269940
#         ZBH         0.272626 -0.013607  inconclusive  6.984557
# BA      JKHY        1.547649 -0.002096    stationary  6.384682
# CRM     EQIX        0.306883 -0.001555    stationary  4.200154
# NCLH    SBAC        0.202152 -0.022734    stationary  2.696865
#         NTRS        0.300283 -0.002925    stationary  2.595763
# HSIC    JBHT        0.475680 -0.001816    stationary  2.394623

# %%
ranked['score'].reset_index(drop=True).plot(
    figsize=(12, 4), grid=True,
    title="Composite score — candidates ranked best → worst",
    xlabel="Rank", ylabel="Score",
)
plt.axhline(-3, color="red", linestyle="--", lw=1.5, label="threshold = −3")
plt.legend(); plt.tight_layout(); plt.show()

# %%
ranked_positive = ranked[ranked["score"] > -3]
robust_pairs    = ranked_positive.index
print(f"Candidates: {len(candidates)}  →  Robust pairs (score > −3): {len(robust_pairs)}")
# Out:
# Candidates: 200  →  Robust pairs (score > −3): 184

# %% [markdown]
# ## 3.4 Pre-filter candidates (composite score)
#
# The composite score from §3.3 is **only a cheap pre-filter** — it narrows the robust pairs down to a short list of candidates. It does **not** pick the traded pair: selecting the single best *in-sample* score is exactly the overfitting trap we want to avoid.
#
# The final pair is chosen in **§3.5** by **walk-forward cross-fold stability**, using only training-span data (2020–2025). The 2026 window (§4b) is never consulted for selection — it stays a genuine held-out test.

# %%
# Composite score is a CHEAP PRE-FILTER only — it does NOT pick the final pair.
# Take the top-N robust candidates; the walk-forward driver in §3.5 selects among them.
N_CANDIDATES = 15
wf_candidates = list(robust_pairs[:N_CANDIDATES])

print(f"Pre-filtered to top {len(wf_candidates)} candidates by composite score "
      f"(of {len(robust_pairs)} robust pairs). Final pick is deferred to §3.5.")
for i, (t1, t2) in enumerate(wf_candidates, 1):
    print(f"  {i:2d}. {t1:6s}/{t2:6s}  score={ranked.loc[(t1, t2), 'score']:.3f}")
# Out:
# Pre-filtered to top 15 candidates by composite score (of 184 robust pairs). Final pick is deferred to §3.5.
#    1. BKNG  /MA      score=9.113
#    2. AVGO  /RL      score=8.416
#    3. HSIC  /PLD     score=7.727
#    4. NCLH  /REG     score=7.270
#    5. NCLH  /ZBH     score=6.985
#    6. BA    /JKHY    score=6.385
#    7. CRM   /EQIX    score=4.200
#    8. NCLH  /SBAC    score=2.697
#    9. NCLH  /NTRS    score=2.596
#   10. HSIC  /JBHT    score=2.395
#   11. NCLH  /WAT     score=2.384
#   12. NCLH  /WTW     score=2.369
#   13. NCLH  /SPG     score=2.360
#   14. NCLH  /VRSN    score=2.259
#   15. NCLH  /PSX     score=2.252

# %% [markdown]
# ## 3.5 Walk-forward selection driver  ← *this* picks the traded pair
#
# We run walk-forward validation (rolling train/test folds over the 2020–2025 training span) on **each** pre-filtered candidate and rank by the **median per-fold Sharpe**. Median rewards pairs whose edge is *consistent across folds* rather than pairs that got one lucky window. `MIN_TOTAL_TRADES` screens out pairs too inactive to judge.
#
# This is the holdout principle done correctly for time series: **selection happens on validation folds**; the 2026 test set in §4b is never touched here. The top-ranked pair becomes `ticker1, ticker2` for everything downstream.
#
# The z-score look-back for each test fold is estimated from the *training* fold's residual, which also warms up the rolling window — the test fold never informs its own z-score (no in-fold look-ahead).

# %%
# === Walk-forward selection driver (parallel across candidates) =============
# Each candidate's walk-forward run is independent, so we fan them out with joblib.
# walk_forward_backtest is itself serial (no nested parallelism) and the fit uses the
# single-pair _kalman_dynamic_hedge (no internal process pool) — so the only thing to
# guard against is BLAS thread oversubscription. Pin threads to 1 (as the Kalman module
# does internally) before the worker processes are spawned.
import os
for _v in ("OPENBLAS_NUM_THREADS", "MKL_NUM_THREADS", "NUMEXPR_NUM_THREADS", "OMP_NUM_THREADS"):
    os.environ.setdefault(_v, "1")

from joblib import Parallel, delayed
from pairs import walk_forward_backtest, filter_kf_on_new
from pairs.models.kalman import _kalman_dynamic_hedge
from pairs.strategies.signals import generate_pair_signals, estimate_halflife_window
from pairs.strategies.evaluate import evaluate_pair_signals

MIN_TOTAL_TRADES = 12   # skip candidates too inactive to rank reliably
N_JOBS = -1             # -1 = all cores; each job is one candidate's walk-forward

prices_wide_tr = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values("datetime"),
    columns=df_filtered.index.get_level_values("ticker"),
    values="close",
)

def _sel_fit_fn(df_train):
    # Filtered (causal) states so the residual history handed to the test fold has the same
    # statistical properties as the causal test-fold residual; the EM fit and the exported
    # end state are unaffected by the choice of mode.
    _, _, states, params = _kalman_dynamic_hedge(
        "P1", "P2", df_train, q=1e-5, em_iters=5, mode="filter", return_params=True)
    if states is None or params is None:
        return None
    # The z-score look-back is chosen from the TRAINING residual, and that residual is carried
    # along as warm-up history — the test fold never informs its own z-score (no look-ahead).
    params = dict(params)
    params["z_window"]  = estimate_halflife_window(states["resid"])
    params["z_history"] = states["resid"]
    return params

def _sel_signal_fn(df_test, params):
    frozen = {"F": params["F"], "Q": params["Q"], "R": params["R"]}
    last_state = (params["last_state_mean"], params["last_state_cov"])
    states_te, _ = filter_kf_on_new(
        df_test["P1"], df_test["P2"],
        frozen=frozen, last_state=last_state, mode="filter")  # causal, no look-ahead
    df_pair_fold = df_test[["P1", "P2"]].join(states_te[["beta", "resid"]], how="inner")
    return generate_pair_signals(
        df_pair_fold, z_method="robust",
        z_window=params["z_window"], z_history=params["z_history"],   # from the training fold
        z_entry=2.0, z_exit=0.5, z_stop=4.0, capital_per_pair=10_000)

def _sel_eval_fn(df_test, signals):
    _, _, summary = evaluate_pair_signals(
        df_test[["P1", "P2"]], signals,
        cost_bps=1, borrow_bps_per_year=50, days_per_year=252, bars_per_year=252)
    return summary

def _wf_one(t1, t2, df_wf_c, score):
    """Run walk-forward for one candidate; return ('ok', row) / ('error', ...) / None."""
    try:
        res = walk_forward_backtest(
            df_wf_c, train_bars=504, test_bars=126, step_bars=63,
            fit_fn=_sel_fit_fn, signal_fn=_sel_signal_fn, eval_fn=_sel_eval_fn,
            verbose=False)
    except Exception as e:
        return ("error", t1, t2, str(e))
    if res is None or len(res) == 0:
        return None
    s = res["sharpe"].to_numpy(dtype=float)
    n_tr = res["n_trades"].to_numpy(dtype=float)
    return ("ok", {
        "ticker1": t1, "ticker2": t2,
        "wf_sharpe_median": np.nanmedian(s),
        "wf_sharpe_mean":   np.nanmean(s),
        "wf_sharpe_std":    np.nanstd(s),
        "pct_pos_folds":    float(np.mean(s > 0)) if np.isfinite(s).any() else np.nan,
        "wf_trades_total":  int(np.nansum(n_tr)),
        "n_folds":          int(np.isfinite(s).sum()),
        "composite_score":  float(score),
    }, res)

# Build the (small) per-candidate inputs up front; skip pairs with too little history.
_tasks = []
for (t1, t2) in wf_candidates:
    df_wf_c = prices_wide_tr[[t1, t2]].rename(columns={t1: "P1", t2: "P2"}).dropna()
    if len(df_wf_c) < 504 + 126:        # not enough history for even one fold
        continue
    _tasks.append((t1, t2, df_wf_c, float(ranked.loc[(t1, t2), "score"])))

_results = Parallel(n_jobs=N_JOBS, prefer="processes")(
    delayed(_wf_one)(t1, t2, df_wf_c, score) for (t1, t2, df_wf_c, score) in _tasks
)

rows = []
wf_by_pair = {}            # keep each candidate's full per-fold results for reuse
for r in _results:
    if r is None:
        continue
    if r[0] == "error":
        print(f"  skip {r[1]}/{r[2]}: {r[3]}")
        continue
    rows.append(r[1])
    wf_by_pair[(r[1]["ticker1"], r[1]["ticker2"])] = r[2]

wf_selection = pd.DataFrame(rows).set_index(["ticker1", "ticker2"])
wf_selection = wf_selection[wf_selection["wf_trades_total"] >= MIN_TOTAL_TRADES]
wf_selection = wf_selection.sort_values("wf_sharpe_median", ascending=False)

print(f"Ranked {len(wf_selection)} candidates by walk-forward median fold Sharpe "
      f"(>= {MIN_TOTAL_TRADES} total trades):\n")
print(wf_selection.head(10).to_string(float_format="{:.3f}".format))

ticker1, ticker2 = wf_selection.index[0]
wf_results = wf_by_pair[(ticker1, ticker2)]   # winner's folds, for the detail plot below
print(f"\nWalk-forward-selected pair: {ticker1} / {ticker2}")
print("(Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)")
# Out:
# Ranked 15 candidates by walk-forward median fold Sharpe (>= 12 total trades):
#
#                  wf_sharpe_median  wf_sharpe_mean  wf_sharpe_std  pct_pos_folds  wf_trades_total  n_folds  composite_score
# ticker1 ticker2
# BKNG    MA                  1.222           1.027          1.263          0.750              124       16            9.113
# NCLH    REG                 0.891           0.480          1.539          0.750              114       16            7.270
#         SPG                 0.629           0.527          1.126          0.688              118       16            2.360
#         NTRS                0.346           0.410          1.518          0.562              136       16            2.596
# AVGO    RL                  0.305           0.400          0.937          0.688              107       16            8.416
# NCLH    PSX                 0.300           0.006          1.367          0.562              116       16            2.252
#         WAT                 0.248           0.277          1.425          0.500              128       16            2.384
# CRM     EQIX                0.148           0.249          0.917          0.562              119       16            4.200
# NCLH    ZBH                -0.034          -0.037          1.358          0.500              120       16            6.985
# HSIC    JBHT               -0.150          -0.240          1.690          0.500              118       16            2.395
#
# Walk-forward-selected pair: BKNG / MA
# (Composite score chose the SHORTLIST; walk-forward stability chose the PAIR.)

# %% [markdown]
# ### 3.5.1 Walk-forward detail for the selected pair
#
# §3.5 ranked the shortlist by **median per-fold Sharpe** and selected the pair above. Below is that pair's full per-fold walk-forward distribution — the validation evidence behind the choice, reusing the folds already computed (no recomputation). A tight, mostly-positive distribution is what we want; one that swings sign across folds means the edge is fragile.

# %%
# Per-fold walk-forward detail for the SELECTED pair — reuses wf_results from §3.5
# (no recomputation). nan-robust stats (a zero-trade fold yields a NaN Sharpe).
from pairs.validation.walk_forward import summarize_walk_forward

print(f"=== Walk-forward folds for selected pair {ticker1}/{ticker2} ===\n")
print(summarize_walk_forward(wf_results).to_string(float_format="{:.3f}".format))

fig, axes = plt.subplots(2, 2, figsize=(14, 8))
fig.suptitle(f"Walk-Forward Validation: {ticker1}/{ticker2}  "
             f"(train=504d, test=126d, step=63d)", fontsize=13)

sharpes  = wf_results["sharpe"].to_numpy(dtype=float)
ann_rets = wf_results["ann_return"].to_numpy(dtype=float) * 100
dds      = wf_results["max_drawdown_pct"].abs().to_numpy(dtype=float) * 100
n_trades = wf_results["n_trades"].to_numpy(dtype=float)
folds    = wf_results.index.values

def _bar(ax, vals, title, ylabel, pos_neg=True):
    colors = ["green" if v > 0 else "red" for v in vals] if pos_neg else "salmon"
    ax.bar(folds, vals, color=colors, alpha=0.75, edgecolor="white")
    ax.axhline(0, color="black", lw=0.8)
    ax.axhline(np.nanmean(vals), color="navy", linestyle="--", lw=1.5,
               label=f"Mean={np.nanmean(vals):.2f}")
    ax.set_xlabel("Fold"); ax.set_ylabel(ylabel); ax.set_title(title); ax.legend()

_bar(axes[0, 0], sharpes,  "Per-Fold Sharpe Ratio",      "Sharpe")
_bar(axes[0, 1], ann_rets, "Per-Fold Annualised Return", "Ann. Return (%)")
_bar(axes[1, 0], dds,      "Per-Fold Max Drawdown",      "Max Drawdown (%)", pos_neg=False)
_bar(axes[1, 1], n_trades, "Per-Fold Trade Count",       "Trades", pos_neg=False)
plt.tight_layout(); plt.show()

pct_pos = float(np.mean(sharpes > 0)) * 100
print(f"\nFolds with positive Sharpe : {pct_pos:.0f}%  ({int((sharpes > 0).sum())}/{len(sharpes)})")
print(f"Median fold Sharpe         : {np.nanmedian(sharpes):.2f}")
print(f"Mean fold Sharpe           : {np.nanmean(sharpes):.2f}  (std={np.nanstd(sharpes):.2f})")
# Out:
# === Walk-forward folds for selected pair BKNG/MA ===
#
#                   mean   std  median    min    max
# sharpe           1.027 1.304   1.222 -1.099  3.054
# ann_return       0.058 0.081   0.065 -0.097  0.175
# max_drawdown_pct 0.025 0.022   0.018  0.008  0.102
# n_trades         7.750 2.352   8.000  4.000 12.000
# hit_rate         0.718 0.161   0.732  0.333  1.000
# profit_factor      inf   NaN   3.274  0.186    inf
# Folds with positive Sharpe : 75%  (12/16)
# Median fold Sharpe         : 1.22
# Mean fold Sharpe           : 1.03  (std=1.26)

# %% [markdown]
# # 4. In-Sample Signal Generation & Evaluation (2020–2025)
#
# ## 4.1 Build the pair-aligned DataFrame

# %%
df_kf = states_tr[(ticker1, ticker2)]

prices = df_filtered.pivot_table(
    index=df_filtered.index.get_level_values('datetime'),
    columns=df_filtered.index.get_level_values('ticker'),
    values='close',
)

df_pair = pd.DataFrame({
    'P1': prices[ticker1],
    'P2': prices[ticker2],
}).join(df_kf[['beta', 'resid']])

print(f"Training pair frame: {df_pair.index[0].date()} → {df_pair.index[-1].date()}, "
      f"{len(df_pair):,} bars")
df_pair.tail(3)
# Out:
# Training pair frame: 2020-01-02 → 2025-12-31, 1,508 bars
#                     P1          P2      beta     resid
# datetime
# 2025-12-29  217.653198  577.900024  0.343690  0.062141
# 2025-12-30  217.085999  577.419983  0.343163 -0.035799
# 2025-12-31  214.213196  570.880005  0.342126 -0.071359

# %% [markdown]
# ## 4.2 Generate trading signals
#
# Signal logic:
# - **Entry**: |z| > `z_entry` (default 2.0) — spread is extreme
# - **Exit** : |z| < `z_exit`  (default 0.5) — spread has mean-reverted
# - **Stop** : |z| > `z_stop`  (default 4.0) — spread is diverging
#
# Z-score is computed with the *robust* method (median/MAD) which is less sensitive to outliers.

# %%
from pairs.strategies import generate_pair_signals

signals = generate_pair_signals(
    df_pair,
    z_method="robust",
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
    max_hold_bars=None,
    cooldown_bars=0,
)
signals.tail(5)
# Out:
#                    z  pos   n1   n2  entry   exit   stop
# datetime
# 2025-12-24 -0.428719    0  0.0  0.0  False  False  False
# 2025-12-26 -0.191140    0  0.0  0.0  False  False  False
# 2025-12-29 -0.015958    0  0.0  0.0  False  False  False
# 2025-12-30 -0.196630    0  0.0  0.0  False  False  False
# 2025-12-31 -0.362246    0  0.0  0.0  False  False  False

# %% [markdown]
# ## 4.3 Visualise in-sample trades

# %%
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair, signals,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4.4 In-sample performance metrics

# %%
from pairs import evaluate_pair_signals

daily_tr, trades_tr, summary_tr = evaluate_pair_signals(
    df_pair, signals,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== In-Sample Performance (2020-01-02 → 2025-12-31) ===")
print(pd.Series(summary_tr).to_string())
# Out:
# === In-Sample Performance (2020-01-02 → 2025-12-31) ===
# start                       2020-01-02 00:00:00
# end                         2025-12-31 00:00:00
# bars                                       1508
# capital_base                        10004.60448
# gross_pnl                           1992.901453
# net_pnl                             1794.505533
# ann_return                              0.02869
# sharpe                                 0.515717
# max_drawdown                         872.099587
# max_drawdown_pct                       0.084032
# avg_gross_exposure                  1698.151802
# avg_exposure_utilization               0.999857
# turnover_annualized                   28.824608
# n_trades                                     85
# hit_rate                                    0.6
# avg_win                               96.568933
# avg_loss                             -92.073825
# profit_factor                          1.573231
# avg_hold_bars                          3.011765
# med_hold_bars                               2.0
# ann_vol                                0.058121
# sortino                                0.805237
# gross_return_chain                     1.208153
# net_return_chain                       1.184438
# avg_daily_dollars_traded            1144.360333
# impact_cost_total                           0.0

# %%
# Equity curve with drawdown shading
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(13, 7), sharex=True,
                                gridspec_kw={"height_ratios": [3, 1]})

ax1.plot(daily_tr.index, daily_tr["equity"], color="steelblue", lw=1.5, label="Equity")
ax1.fill_between(daily_tr.index, daily_tr["equity"],
                 daily_tr["equity"] + daily_tr["drawdown"],   # drawdown is negative
                 alpha=0.25, color="red", label="Drawdown")
ax1.set_ylabel("Equity ($)"); ax1.set_title(f"In-Sample Equity Curve — {ticker1}/{ticker2}")
ax1.legend()

ax2.fill_between(daily_tr.index, daily_tr["drawdown_pct"] * 100, 0,
                 alpha=0.6, color="red")
ax2.set_ylabel("Drawdown (%)"); ax2.set_xlabel("Date")
plt.tight_layout(); plt.show()

# %% [markdown]
# # 4b. Out-of-Sample Evaluation (2026-01-01 → 2026-06-25)
#
# ## 4b.1 Download OOS price data

# %%
start_test = "2026-01-01"
end_test   = "2026-06-25"

_oos_cache = CACHE / f"nb03_oos_{ticker1}_{ticker2}_{start_test}_{end_test}.parquet"
if _oos_cache.exists():
    df_test, failed = pd.read_parquet(_oos_cache), []
else:
    df_test, failed = load_prices('openbb', [ticker1, ticker2], start_test, end_test, return_failed=True)
    df_test.to_parquet(_oos_cache)
print(f"OOS data: {len(df_test):,} rows, {df_test.index.get_level_values('ticker').nunique()} tickers")
if failed:
    print("No data for:", failed)
# Out:
# OOS data: 240 rows, 2 tickers

# %% [markdown]
# ## 4b.2 Continue Kalman filter on OOS window (no look-ahead)
#
# We freeze the parameters $(F, Q, R)$ learned during training and **continue filtering**
# from the last train state.  The smoother is NOT used on OOS data — only the causal filter.
#
# The OOS z-score uses a look-back chosen from — and warmed up on — the causal *training-window* residual under the same frozen parameters, so the OOS window never informs its own z-score.

# %%
from pairs import filter_kf_on_new

pair = (ticker1, ticker2)
frozen = {k: params_tr[pair][k] for k in ("F", "Q", "R")}
last_state = (params_tr[pair]["last_state_mean"], params_tr[pair]["last_state_cov"])

P1_new = df_test.loc[(ticker1,), 'close']
P2_new = df_test.loc[(ticker2,), 'close']

states_te, _ = filter_kf_on_new(
    P1_new, P2_new,
    frozen=frozen,
    last_state=last_state,
    init_cov=1e6,
    mode="filter",
)

prices_te = df_test.pivot_table(
    index=df_test.index.get_level_values("datetime"),
    columns=df_test.index.get_level_values("ticker"),
    values="close",
)
df_pair_te = states_te.join(
    prices_te[[ticker1, ticker2]].rename(columns={ticker1: "P1", ticker2: "P2"}),
    how="inner",
)
print(f"OOS pair frame: {df_pair_te.index[0].date()} → {df_pair_te.index[-1].date()}, "
      f"{len(df_pair_te):,} bars")
# Out:
# OOS pair frame: 2026-01-02 → 2026-06-25, 120 bars

# %%
# z-score look-back and warm-up history from the causal TRAINING residual under the frozen
# parameters — the OOS window never informs its own z-score (no in-window look-ahead).
states_hist, _ = filter_kf_on_new(
    df_pair["P1"], df_pair["P2"],
    frozen=frozen, last_state=None, init_cov=1e6, mode="filter",
)
z_window_tr = estimate_halflife_window(states_hist["resid"])
print(f"z-score window from training residual: {z_window_tr} bars")

signals_te = generate_pair_signals(
    df_pair_te,
    z_method="robust",
    z_window=z_window_tr, z_history=states_hist["resid"],
    z_entry=2.0, z_exit=0.5, z_stop=4.0,
    capital_per_pair=10_000,
)
daily_te, trades_te, summary_te = evaluate_pair_signals(
    df_pair_te[["P1", "P2"]], signals_te,
    cost_bps=1, fee_per_share_1=0.0, fee_per_share_2=0.0,
    borrow_bps_per_year=50, days_per_year=252, bars_per_year=252,
)
print("=== Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===")
print(pd.Series(summary_te).to_string())
# Out:
# z-score window from training residual: 30 bars
# === Out-of-Sample Performance (2026-01-01 → 2026-06-25) ===
# start                       2026-01-02 00:00:00
# end                         2026-06-25 00:00:00
# bars                                        120
# capital_base                        9989.325853
# gross_pnl                            692.138223
# net_pnl                              664.302195
# ann_return                              0.14823
# sharpe                                  2.64203
# max_drawdown                         243.954955
# max_drawdown_pct                        0.02313
# avg_gross_exposure                  2249.102743
# avg_exposure_utilization               1.000669
# turnover_annualized                   52.771994
# n_trades                                     12
# hit_rate                                   0.75
# avg_win                               88.373177
# avg_loss                             -66.854738
# profit_factor                          3.965606
# avg_hold_bars                          2.166667
# med_hold_bars                               2.0
# ann_vol                                0.052858
# sortino                                5.014127
# gross_return_chain                     1.071009
# net_return_chain                       1.068034
# avg_daily_dollars_traded            2091.891429
# impact_cost_total                           0.0

# %% [markdown]
# ## 4b.3 Visualise OOS trades
#
# The same view as the in-sample plot (§4.3), now on the 2026 held-out window. Reading it next to §4.3 makes the shorter window concrete: 13 holding periods here against 85 across the five-year training span — though over only 120 bars, so the *rate* of trading is actually higher out of sample.

# %%
# Same plot as in-sample (§4.3), applied to the OOS pair frame & signals.
from pairs import plot_pair_legs_with_trades

plot_pair_legs_with_trades(
    df_pair_te, signals_te,
    label1=ticker1, label2=ticker2,
    normalize=False,
    shade_positions=True,
    size_scale=0.004,
    min_marker=20, max_marker=220,
    show_zscore=True, z_entry=2.0, z_exit=0.5, z_stop=4.0,
)
# Out:
# (<Figure size 1300x1050 with 3 Axes>,
#  (<Axes: title={'center': 'Trades superimposed on each leg • BKNG (top), MA (bottom)'}, ylabel='Price'>,
#   <Axes: ylabel='Price'>,
#   <Axes: title={'center': 'Spread z-score — entries when it leaves the band, exits as it reverts'}, ylabel='z'>))

# %% [markdown]
# ## 4b.4 In-sample vs OOS comparison
#
# > ⚠️ **Caution**: The OOS window contains only **13 trades** over 120 bars. A hit rate of
# > 84.6% on 13 observations is statistically uninformative — the 95% binomial CI spans roughly
# > (55%, 98%). Note the direction: the OOS Sharpe (3.50) is *higher* than the in-sample figure
# > (0.52), which is not evidence that the strategy improved. The standard error of an annualised
# > Sharpe over 120 bars is about 1.4, so 3.50 is a high-variance draw, not a result.

# %%
comparison = pd.DataFrame({
    "In-sample (2020-2025)": pd.Series(summary_tr),
    "OOS (2026)":            pd.Series(summary_te),
}).loc[["sharpe", "ann_return", "max_drawdown_pct", "n_trades", "hit_rate", "profit_factor"]]
comparison.loc["ann_return"] = comparison.loc["ann_return"] * 100   # → %
comparison.index = ["Sharpe", "Ann. Return (%)", "Max Drawdown (%)", "Trades", "Hit Rate", "Profit Factor"]
print(comparison.to_string(float_format="{:.3f}".format))
# Out:
#                  In-sample (2020-2025) OOS (2026)
# Sharpe                           0.516      2.642
# Ann. Return (%)                  2.869     14.823
# Max Drawdown (%)                 0.084      0.023
# Trades                              85         12
# Hit Rate                         0.600      0.750
# Profit Factor                    1.573      3.966

# %% [markdown]
# # 8. Limitations and Honest Assessment
#
# ## 8.1 What the results cannot tell us
#
# The traded pair was chosen (§3.5) from a shortlist that itself survived a composite stationarity filter over a very large number of simultaneously-tested pairs. Read the performance with these caveats:
#
# - **Selection bias (identical to nb02, not amplified).** Dropping Benjamini-Hochberg marks far more pairs `pass`, but the candidate set is a rank cut on raw p-values that BH does not reorder, so this notebook's shortlist, selected pair and results match `pairs_trading_02_yahoo.ipynb` exactly (§0). The selection bias is real and is the same in both. To make the ablation bite, gate candidates on `verdict` before the rank cut.
# - **Low OOS trade count.** The OOS window produces only a handful of trades (13 for the selected BKNG/MA pair) — far below the ~50 needed for statistical power. A high hit rate on a few trades is uninformative.
# - **Single-window Sharpe is noise in both directions.** In-sample Sharpe is systematically optimistic, so the OOS figure is *usually* lower — but in this run it is higher (0.52 → 3.50) on 13 trades in half a year. Neither single window is informative: the fold distribution in §3.5 is.
# - **Optimistic cost model.** The in-sample/OOS evaluation uses a flat `cost_bps` with no market impact, fill/queue uncertainty, or borrow-availability variability.
# - **Single-pair analysis.** A live strategy trades a *portfolio* of pairs — introducing cross-pair residual correlation, portfolio-level drawdown management, and signal interaction effects not captured here.
#
# ## 8.2 What the evidence does support
#
# 1. A working end-to-end pipeline (data → cointegration → Kalman hedge → signals → evaluation) with **causal OOS continuation** (no look-ahead: the Kalman state is carried forward, and the z-score look-back and its warm-up come from training data, never from the window being scored).
# 2. **Honest pair selection**: the traded pair is chosen by walk-forward cross-fold stability (§3.5), not by in-sample ranking — and the held-out window is never used for selection.
# 3. **Multiple-testing _not_ corrected**: this variant omits BH FDR (the deliberate difference from nb02), so statistically spurious pairs that BH would remove stay in the candidate set.
# 4. **Honest degradation disclosure**: the OOS Sharpe is reported, not hidden, and the walk-forward distribution (§3.5.1) shows the spread across folds rather than one window.
#
# ## 8.3 Gap-to-production
#
# | Gap | Required mitigation |
# |-----|---------------------|
# | Selection bias | Strict hold-out from inception; **add BH FDR** (omitted here — see nb02) + walk-forward selection |
# | Low OOS N | Longer OOS window; portfolio of 10+ pairs |
# | No market impact | Square-root impact model + capacity analysis |
# | Single-regime OOS | Rolling re-estimation in live trading |
# | No portfolio risk mgmt | Residual-vol position sizing; cross-pair correlation |
# | Borrow / execution | Pre-borrow checks; limit-order fill model |
